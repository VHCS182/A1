# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import math
import random # necessário para utilizar o módulo random
from scipy.integrate import quad

# %%
#  DADOS - EXPERIMENTAL

CONTEXP000_CS137_0662 = 9454
CONTEXP002_CS137_0662 = 9485
CONTEXP008_CS137_0662 = 8606
CONTEXP014_CS137_0662 = 8225
CONTEXP000_AM241_00595 = 594
CONTEXP002_AM241_00595 = 548
CONTEXP008_AM241_00595 = 592
CONTEXP014_AM241_00595 = 224


# DADOS - TEORIA (PENCIL-BEAM)

CONTPBEAM000_CS137_0662 = 4403330
CONTPBEAM002_CS137_0662 = 4313390
CONTPBEAM008_CS137_0662 = 4026930
CONTPBEAM014_CS137_0662 = 3764660
CONTPBEAM000_AM241_00595 = 8056020
CONTPBEAM002_AM241_00595 = 7645430
CONTPBEAM008_AM241_00595 = 6531960
CONTPBEAM014_AM241_00595 = 5578480

# DADOS - TEORIA (ISOTRÓPICO)

CONTISO000_CS137_0662 = 3361
CONTISO002_CS137_0662 = 3200
CONTISO008_CS137_0662 = 3118
CONTISO014_CS137_0662 = 2807
CONTISO000_AM241_00595 = 7928
CONTISO002_AM241_00595 = 7477
CONTISO008_AM241_00595 = 6635
CONTISO014_AM241_00595 = 5901

# %%
# Calculo da Intensidade - Coeficiente Linear de Atenuação


# CS-137 (EXPERIMENTAL)


# I_CS137_PLA002

PICO1_PLACS002_EXP0662 = CONTEXP002_CS137_0662/CONTEXP000_CS137_0662
print(PICO1_PLACS002_EXP0662)

INVPICO1_PLACS002_EXP0662 = CONTEXP000_CS137_0662/CONTEXP002_CS137_0662
print(INVPICO1_PLACS002_EXP0662)

# I_CS137_PLA008

PICO1_PLACS008_EXP0662 = CONTEXP008_CS137_0662/CONTEXP000_CS137_0662
print(PICO1_PLACS008_EXP0662)

INVPICO1_PLACS008_EXP0662 = CONTEXP000_CS137_0662/CONTEXP008_CS137_0662
print(INVPICO1_PLACS008_EXP0662)

# I_CS137_PLA014

PICO1_PLACS014_EXP0662 = CONTEXP014_CS137_0662/CONTEXP000_CS137_0662
print(PICO1_PLACS014_EXP0662)

INVPICO1_PLACS014_EXP0662 = CONTEXP000_CS137_0662/CONTEXP014_CS137_0662
print(INVPICO1_PLACS014_EXP0662)
# Out:
# 1.0032790353289613
# 0.9967316816025303
# 0.91030251745293
# 1.0985359051824308
# 0.8700021155066638
# 1.1494224924012157

# %%
# Calculo da Intensidade - Coeficiente Linear de Atenuação

# AM-241 (EXPERIMENTAL)

# I_AM241_PLA002

PICO1_PLAAM002_EXP00595 = CONTEXP002_AM241_00595/CONTEXP000_AM241_00595
print(PICO1_PLAAM002_EXP00595)

INVPICO1_PLAAM002_EXP00595 = CONTEXP000_AM241_00595/CONTEXP002_AM241_00595
print(INVPICO1_PLAAM002_EXP00595)


# I_AM241_PLA008

PICO1_PLAAM008_EXP00595 = CONTEXP008_AM241_00595/CONTEXP000_AM241_00595
print(PICO1_PLAAM008_EXP00595)

INVPICO1_PLAAM008_EXP00595 = CONTEXP000_AM241_00595/CONTEXP008_AM241_00595
print(INVPICO1_PLAAM008_EXP00595)

# I_AM241_PLA014

PICO1_PLAAM014_EXP00595 = CONTEXP014_AM241_00595/CONTEXP000_AM241_00595
print(PICO1_PLAAM014_EXP00595)

INVPICO1_PLAAM014_EXP00595 = CONTEXP000_AM241_00595/CONTEXP014_AM241_00595
print(INVPICO1_PLAAM014_EXP00595)
# Out:
# 0.9225589225589226
# 1.083941605839416
# 0.9966329966329966
# 1.0033783783783783
# 0.3771043771043771
# 2.6517857142857144

# %%
#CS-137 (PENCIL BEAM)

PICO1_PLACS002_PBEAM0662=CONTPBEAM002_CS137_0662/CONTPBEAM000_CS137_0662
print(PICO1_PLACS002_PBEAM0662)

INVPICO1_PLACS002_PBEAM0662=CONTISO000_CS137_0662/CONTISO002_CS137_0662
print(INVPICO1_PLACS002_PBEAM0662)

PICO1_PLACS008_PBEAM0662=CONTPBEAM008_CS137_0662/CONTPBEAM000_CS137_0662
print(PICO1_PLACS008_PBEAM0662)

INVPICO1_PLACS008_PBEAM0662=CONTISO000_CS137_0662/CONTISO008_CS137_0662
print(INVPICO1_PLACS008_PBEAM0662)

PICO1_PLACS014_PBEAM0662=CONTPBEAM014_CS137_0662/CONTPBEAM000_CS137_0662
print(PICO1_PLACS014_PBEAM0662)

INVPICO1_PLACS014_PBEAM0662=CONTISO000_CS137_0662/CONTISO014_CS137_0662
print(INVPICO1_PLACS014_PBEAM0662)
# Out:
# 0.9795745492615816
# 1.0503125
# 0.9145192388487804
# 1.0779345734445158
# 0.8549574980753203
# 1.1973637335233345

# %%
#AM-241 (PENCIL BEAM)

PICO1_PLAAM002_PBEAM00595=CONTPBEAM002_AM241_00595/CONTPBEAM000_AM241_00595
print(PICO1_PLAAM002_PBEAM00595)

INVPICO1_PLAAM002_PBEAM00595=CONTPBEAM000_AM241_00595/CONTPBEAM002_AM241_00595
print(INVPICO1_PLAAM002_PBEAM00595)

PICO1_PLAAM008_PBEAM00595=CONTPBEAM008_AM241_00595/CONTPBEAM000_AM241_00595
print(PICO1_PLAAM008_PBEAM00595)

INVPICO1_PLAAM008_PBEAM00595=CONTPBEAM000_AM241_00595/CONTPBEAM008_AM241_00595
print(INVPICO1_PLAAM008_PBEAM00595)

PICO1_PLAAM014_PBEAM00595=CONTPBEAM014_AM241_00595/CONTPBEAM000_AM241_00595
print(PICO1_PLAAM014_PBEAM00595)

INVPICO1_PLAAM014_PBEAM00595=CONTPBEAM000_AM241_00595/CONTPBEAM014_AM241_00595
print(INVPICO1_PLAAM014_PBEAM00595)
# Out:
# 0.9490331453993411
# 1.0537039774087265
# 0.8108172521915288
# 1.233323535355391
# 0.6924610415565006
# 1.4441245643974703

# %%
# CÉSIO-137 (ISOTRÓPICO)

PICO1_PLACS002_ISO0662=CONTISO002_CS137_0662/CONTISO000_CS137_0662
print(PICO1_PLACS002_ISO0662)

INVPICO1_PLACS002_ISO0662=CONTISO000_CS137_0662/CONTISO002_CS137_0662
print(INVPICO1_PLACS002_ISO0662)

PICO1_PLACS008_ISO0662=CONTISO008_CS137_0662/CONTISO000_CS137_0662
print(PICO1_PLACS008_ISO0662)

INVPICO1_PLACS008_ISO0662=CONTISO000_CS137_0662/CONTISO008_CS137_0662
print(INVPICO1_PLACS008_ISO0662)

PICO1_PLACS014_ISO0662=CONTISO014_CS137_0662/CONTISO000_CS137_0662
print(PICO1_PLACS014_ISO0662)

INVPICO1_PLACS014_ISO0662=CONTISO000_CS137_0662/CONTISO014_CS137_0662
print(INVPICO1_PLACS014_ISO0662)
# Out:
# 0.9520975900029753
# 1.0503125
# 0.927700089259149
# 1.0779345734445158
# 0.8351681047307349
# 1.1973637335233345

# %%
#AM-241 (ISOTRÓPICO)

PICO1_PLAAM002_ISO00595=CONTISO002_AM241_00595/CONTISO000_AM241_00595
print(PICO1_PLAAM002_ISO00595)

INVPICO1_PLAAM002_ISO00595=CONTISO000_AM241_00595/CONTISO002_AM241_00595
print(INVPICO1_PLAAM002_ISO00595)

PICO1_PLAAM008_ISO00595=CONTISO008_AM241_00595/CONTISO000_AM241_00595
print(PICO1_PLAAM008_ISO00595)

INVPICO1_PLAAM008_ISO00595=CONTISO000_AM241_00595/CONTISO008_AM241_00595
print(INVPICO1_PLAAM008_ISO00595)

PICO1_PLAAM014_ISO00595=CONTISO014_AM241_00595/CONTISO000_AM241_00595
print(PICO1_PLAAM014_ISO00595)

INVPICO1_PLAAM014_ISO00595=CONTISO000_AM241_00595/CONTISO014_AM241_00595
print(INVPICO1_PLAAM014_ISO00595)
# Out:
# 0.9431130171543896
# 1.0603183094824127
# 0.8369071644803229
# 1.1948756593820649
# 0.7443239152371343
# 1.343501101508219

# %%
# lN (I/I0): CS-137 (EXPERIMENTAL)

LN_PICO1_PLACS002_EXP0662 = np.log(PICO1_PLACS002_EXP0662)
print(LN_PICO1_PLACS002_EXP0662)

LN_INVPICO1_PLACS002_EXP0662 = np.log(INVPICO1_PLACS002_EXP0662)
print(LN_INVPICO1_PLACS002_EXP0662)

LN_PICO1_PLACS008_EXP0662 = np.log(PICO1_PLACS008_EXP0662)
print(LN_PICO1_PLACS008_EXP0662)

LN_INVPICO1_PLACS008_EXP0662 = np.log(INVPICO1_PLACS008_EXP0662)
print(LN_INVPICO1_PLACS008_EXP0662)

LN_PICO1_PLACS014_EXP0662 = np.log(PICO1_PLACS014_EXP0662)
print(LN_PICO1_PLACS014_EXP0662)

LN_INVPICO1_PLACS014_EXP0662 = np.log(INVPICO1_PLACS014_EXP0662)
print(LN_INVPICO1_PLACS014_EXP0662)
# Out:
# 0.0032736710159329665
# -0.0032736710159328806
# -0.09397829795463669
# 0.09397829795463669
# -0.13925963571960903
# 0.13925963571960898

# %%
# lN (I/I0): AM-241 (EXPERIMENTAL)

LN_PICO1_PLAAM002_EXP00595 = np.log(PICO1_PLAAM002_EXP00595)
print(LN_PICO1_PLAAM002_EXP00595)

LN_INVPICO1_PLAAM002_EXP00595 = np.log(INVPICO1_PLAAM002_EXP00595)
print(LN_INVPICO1_PLAAM002_EXP00595)

LN_PICO1_PLAAM008_EXP00595 = np.log(PICO1_PLAAM008_EXP00595)
print(LN_PICO1_PLAAM008_EXP00595)

LN_INVPICO1_PLAAM008_EXP00595 = np.log(INVPICO1_PLAAM008_EXP00595)
print(LN_INVPICO1_PLAAM008_EXP00595)

LN_PICO1_PLAAM014_EXP00595 = np.log(PICO1_PLAAM014_EXP00595)
print(LN_PICO1_PLAAM014_EXP00595)

LN_INVPICO1_PLAAM014_EXP00595 = np.log(INVPICO1_PLAAM014_EXP00595)
print(LN_INVPICO1_PLAAM014_EXP00595)
# Out:
# -0.08060403241462938
# 0.08060403241462935
# -0.00337268447863923
# 0.003372684478639156
# -0.9752332675076051
# 0.9752332675076051

# %%
# lN (I/I0): CS-137 (PENCIL BEAM)

LN_PICO1_PLACS002_PBEAM0662 = np.log(PICO1_PLACS002_PBEAM0662)
print(LN_PICO1_PLACS002_PBEAM0662)

LN_INVPICO1_PLACS002_PBEAM0662 = np.log(INVPICO1_PLACS002_PBEAM0662)
print(LN_INVPICO1_PLACS002_PBEAM0662)

LN_PICO1_PLACS008_PBEAM0662 = np.log(PICO1_PLACS008_PBEAM0662)
print(LN_PICO1_PLACS008_PBEAM0662)

LN_INVPICO1_PLACS008_PBEAM0662 = np.log(INVPICO1_PLACS008_PBEAM0662)
print(LN_INVPICO1_PLACS008_PBEAM0662)

LN_PICO1_PLACS014_PBEAM0662 = np.log(PICO1_PLACS014_PBEAM0662)
print(LN_PICO1_PLACS014_PBEAM0662)

LN_INVPICO1_PLACS014_PBEAM0662 = np.log(INVPICO1_PLACS014_PBEAM0662)
print(LN_INVPICO1_PLACS014_PBEAM0662)
# Out:
# -0.020636934987259024
# 0.04908773893728773
# -0.08935677381232765
# 0.07504677810738393
# -0.1567035211343791
# 0.18012225136322313

# %%
# lN (I/I0): AM-241 (PENCIL BEAM)

LN_PICO1_PLAAM002_PBEAM00595 = np.log(PICO1_PLAAM002_PBEAM00595)
print(LN_PICO1_PLAAM002_PBEAM00595)

LN_INVPICO1_PLAAM002_PBEAM00595 = np.log(INVPICO1_PLAAM002_PBEAM00595)
print(LN_INVPICO1_PLAAM002_PBEAM00595)

LN_PICO1_PLAAM008_PBEAM00595 = np.log(PICO1_PLAAM008_PBEAM00595)
print(LN_PICO1_PLAAM008_PBEAM00595)

LN_INVPICO1_PLAAM008_PBEAM00595 = np.log(INVPICO1_PLAAM008_PBEAM00595)
print(LN_INVPICO1_PLAAM008_PBEAM00595)

LN_PICO1_PLAAM014_PBEAM00595 = np.log(PICO1_PLAAM014_PBEAM00595)
print(LN_PICO1_PLAAM014_PBEAM00595)

LN_INVPICO1_PLAAM014_PBEAM00595 = np.log(INVPICO1_PLAAM014_PBEAM00595)
print(LN_INVPICO1_PLAAM014_PBEAM00595)
# Out:
# -0.05231155432318328
# 0.05231155432318324
# -0.20971258664407325
# 0.20971258664407322
# -0.36750330018330973
# 0.3675033001833097

# %%
# lN (I/I0): CS-137 (ISOTROPICO)

#ln_ISOyCS137_0662 = [LN_PICOISO_PLACS002_0662, LN_PICOISO_PLACS008_0662, LN_PICOISO_PLACS014_0662]
#print(ln_ISOyCS137_0662)

LN_PICO1_PLACS002_ISO0662 = np.log(PICO1_PLACS002_ISO0662)
print(LN_PICO1_PLACS002_ISO0662)

LN_INVPICO1_PLACS002_ISO0662 = np.log(INVPICO1_PLACS002_ISO0662)
print(LN_INVPICO1_PLACS002_ISO0662)

LN_PICO1_PLACS008_ISO0662 = np.log(PICO1_PLACS008_ISO0662)
print(LN_PICO1_PLACS008_ISO0662)

LN_INVPICO1_PLACS008_ISO0662 = np.log(INVPICO1_PLACS008_ISO0662)
print(LN_INVPICO1_PLACS008_ISO0662)

LN_PICO1_PLACS014_ISO0662 = np.log(PICO1_PLACS014_ISO0662)
print(LN_PICO1_PLACS014_ISO0662)

LN_INVPICO1_PLACS014_ISO0662 = np.log(INVPICO1_PLACS014_ISO0662)
print(LN_INVPICO1_PLACS014_ISO0662)
# Out:
# -0.04908773893728771
# 0.04908773893728773
# -0.07504677810738386
# 0.07504677810738393
# -0.18012225136322318
# 0.18012225136322313

# %%
# lN (I/I0): AM-241 (ISOTROPICO)

#ln_ISOyAM_00595 = [LN_PICOISO_PLAAM002_00595, LN_PICOISO_PLAAM008_00595, LN_PICOISO_PLAAM014_00595]
#print(ln_ISOyAM_00595)

LN_PICO1_PLAAM002_ISO00595 = np.log(PICO1_PLAAM002_ISO00595)
print(LN_PICO1_PLAAM002_ISO00595)

LN_INVPICO1_PLAAM002_ISO00595 = np.log(INVPICO1_PLAAM002_ISO00595)
print(LN_INVPICO1_PLAAM002_ISO00595)

LN_PICO1_PLAAM008_ISO00595 = np.log(PICO1_PLAAM008_ISO00595)
print(LN_PICO1_PLAAM008_ISO00595)

LN_INVPICO1_PLAAM008_ISO00595 = np.log(INVPICO1_PLAAM008_ISO00595)
print(LN_INVPICO1_PLAAM008_ISO00595)

LN_PICO1_PLAAM014_ISO00595 = np.log(PICO1_PLAAM014_ISO00595)
print(LN_PICO1_PLAAM014_ISO00595)

LN_INVPICO1_PLAAM014_ISO00595 = np.log(INVPICO1_PLAAM014_ISO00595)
print(LN_INVPICO1_PLAAM014_ISO00595)
# Out:
# -0.05856915500990832
# 0.05856915500990833
# -0.17804212924351606
# 0.1780421292435161
# -0.2952789689526551
# 0.2952789689526552

# %%
# CS 137 - EXPERIMENTAL
 
# LOGARITMO NATURAL - np.log(I/I0)

ln_yCS137_EXP0662 = [LN_PICO1_PLACS002_EXP0662, LN_PICO1_PLACS008_EXP0662, LN_PICO1_PLACS014_EXP0662]
print(ln_yCS137_EXP0662)

#LOGARITMO NATURAL INVERSO - np.log(I0/I)

ln_INVyCS137_EXP0662 = [LN_INVPICO1_PLACS002_EXP0662, LN_INVPICO1_PLACS008_EXP0662, LN_INVPICO1_PLACS014_EXP0662]
print(ln_INVyCS137_EXP0662)
# Out:
# [0.0032736710159329665, -0.09397829795463669, -0.13925963571960903]
# [-0.0032736710159328806, 0.09397829795463669, 0.13925963571960898]

# %%
# AM-241 - EXPERIMENTAL

# LOGARITMO NATURAL - np.log(I/I0)

ln_yAM241_EXP00595 = [LN_PICO1_PLAAM002_EXP00595, LN_PICO1_PLAAM008_EXP00595, LN_PICO1_PLAAM014_EXP00595]
print(ln_yAM241_EXP00595)

#LOGARITMO NATURAL INVERSO - np.log(I0/I)

ln_INVyAM241_EXP00595 = [LN_INVPICO1_PLAAM002_EXP00595, LN_INVPICO1_PLAAM008_EXP00595, LN_INVPICO1_PLAAM014_EXP00595]
print(ln_INVyAM241_EXP00595)
# Out:
# [-0.08060403241462938, -0.00337268447863923, -0.9752332675076051]
# [0.08060403241462935, 0.003372684478639156, 0.9752332675076051]

# %%
# CS 137 - PENCIL BEAM
 

# LOGARITMO NATURAL - np.log(I/I0)

ln_yCS137_PBEAM0662 = [LN_PICO1_PLACS002_PBEAM0662, LN_PICO1_PLACS008_PBEAM0662, LN_PICO1_PLACS014_PBEAM0662]
print(ln_yCS137_PBEAM0662)

#LOGARITMO NATURAL INVERSO - np.log(I0/I)

ln_INVyCS137_PBEAM0662 = [LN_INVPICO1_PLACS002_PBEAM0662, LN_INVPICO1_PLACS008_PBEAM0662, LN_INVPICO1_PLACS014_PBEAM0662]
print(ln_INVyCS137_PBEAM0662)
# Out:
# [-0.020636934987259024, -0.08935677381232765, -0.1567035211343791]
# [0.04908773893728773, 0.07504677810738393, 0.18012225136322313]

# %%
# AM-241 - PENCIL BEAM

# LOGARITMO NATURAL - np.log(I/I0)

ln_yAM241_PBEAM00595 = [LN_PICO1_PLAAM002_PBEAM00595, LN_PICO1_PLAAM008_PBEAM00595, LN_PICO1_PLAAM014_PBEAM00595]
print(ln_yAM241_PBEAM00595)

#LOGARITMO NATURAL INVERSO - np.log(I0/I)

ln_INVyAM241_PBEAM00595 = [LN_INVPICO1_PLAAM002_PBEAM00595, LN_INVPICO1_PLAAM008_PBEAM00595, LN_INVPICO1_PLAAM014_PBEAM00595]
print(ln_INVyAM241_PBEAM00595)
# Out:
# [-0.05231155432318328, -0.20971258664407325, -0.36750330018330973]
# [0.05231155432318324, 0.20971258664407322, 0.3675033001833097]

# %%
# CS 137 - ISOTRÓPICO
 

# LOGARITMO NATURAL - np.log(I/I0)

ln_yCS137_ISO0662 = [LN_PICO1_PLACS002_ISO0662, LN_PICO1_PLACS008_ISO0662, LN_PICO1_PLACS014_ISO0662]
print(ln_yCS137_ISO0662)

#LOGARITMO NATURAL INVERSO - np.log(I0/I)

ln_INVyCS137_ISO0662 = [LN_INVPICO1_PLACS002_ISO0662, LN_INVPICO1_PLACS008_ISO0662, LN_INVPICO1_PLACS014_ISO0662]
print(ln_INVyCS137_ISO0662)
# Out:
# [-0.04908773893728771, -0.07504677810738386, -0.18012225136322318]
# [0.04908773893728773, 0.07504677810738393, 0.18012225136322313]

# %%
# AM-241 - ISOTRÓPICO

# LOGARITMO NATURAL - np.log(I/I0)

ln_yAM241_ISO00595 = [LN_PICO1_PLAAM002_ISO00595, LN_PICO1_PLAAM008_ISO00595, LN_PICO1_PLAAM014_ISO00595]
print(ln_yAM241_ISO00595)

#LOGARITMO NATURAL INVERSO - np.log(I0/I)

ln_INVyAM241_ISO00595 = [LN_INVPICO1_PLAAM002_ISO00595, LN_INVPICO1_PLAAM008_ISO00595, LN_INVPICO1_PLAAM014_ISO00595]
print(ln_INVyAM241_ISO00595)
# Out:
# [-0.05856915500990832, -0.17804212924351606, -0.2952789689526551]
# [0.05856915500990833, 0.1780421292435161, 0.2952789689526552]

# %%
# DADOS DE INTENSIDADE NORMALIZADOS (METROS)

X_002=0.2

X_008=0.8

X_014=1.2

CMESP_CS137_PLA002 = 0.2 # CENTIMETROS # 0.002  # METROS
CMESP_CS137_PLA008 = 0.8 # CENTIMETROS # 0.008 # METROS
CMESP_CS137_PLA014 = 1.4 # CENTIMETROS # 0.014 # METROS 

CMESP_AM241_PLA002 = 0.2 # CENTIMETROS # 0.002 # METROS 
CMESP_AM241_PLA008 = 0.8 # CENTIMETROS # 0.008  # METROS 
CMESP_AM241_PLA014 = 1.4 # CENTIMETROS # 0.014 # METROS 

xCS_ESPCM = [CMESP_CS137_PLA002, CMESP_CS137_PLA008, CMESP_CS137_PLA014]
print(xCS_ESPCM)
xAM_ESPCM =[CMESP_AM241_PLA002, CMESP_AM241_PLA008, CMESP_AM241_PLA014]
print(xAM_ESPCM)
# Out:
# [0.2, 0.8, 1.4]
# [0.2, 0.8, 1.4]

# %%
print("CONTEXP_CS137_0662")
#print(CONTEXP000_CS137_0662)
print(CONTEXP002_CS137_0662)
print(CONTEXP008_CS137_0662)
print(CONTEXP014_CS137_0662)
print("CONTEXP_AM241_00595")
#print(CONTEXP000_AM241_00595)
print(CONTEXP002_AM241_00595)
print(CONTEXP008_AM241_00595)
print(CONTEXP014_AM241_00595)

print("CONTPBEAM_CS137_0662")
#print(CONTPBEAM000_CS137_0662)
print(CONTPBEAM002_CS137_0662)
print(CONTPBEAM008_CS137_0662)
print(CONTPBEAM014_CS137_0662)
print("CONTPBEAM_AM241_00595")
#print(CONTPBEAM000_AM241_00595)
print(CONTPBEAM002_AM241_00595)
print(CONTPBEAM008_AM241_00595)
print(CONTPBEAM014_AM241_00595)

print("CONTISO_CS137_0662")
#print(CONTISO000_CS137_0662)
print(CONTISO002_CS137_0662)
print(CONTISO008_CS137_0662)
print(CONTISO014_CS137_0662)
print("CONTISO_AM241_00595")
#print(CONTISO000_AM241_00595)
print(CONTISO002_AM241_00595)
print(CONTISO008_AM241_00595)
print(CONTISO014_AM241_00595)

print("PICO1_PLACS_EXP0662")
print(PICO1_PLACS002_EXP0662)
print(PICO1_PLACS008_EXP0662)
print(PICO1_PLACS014_EXP0662)
print(INVPICO1_PLACS002_EXP0662)
print(INVPICO1_PLACS008_EXP0662)
print(INVPICO1_PLACS014_EXP0662)
print("PICO1_PLAAM_EXP00595")
print(PICO1_PLAAM002_EXP00595)
print(PICO1_PLAAM008_EXP00595)
print(PICO1_PLAAM014_EXP00595)
print(INVPICO1_PLAAM002_EXP00595)
print(INVPICO1_PLAAM008_EXP00595)
print(INVPICO1_PLAAM014_EXP00595)

print("PICO1_PLACS_PBEAM0662")
print(PICO1_PLACS002_PBEAM0662)
print(PICO1_PLACS008_PBEAM0662)
print(PICO1_PLACS014_PBEAM0662)
print(INVPICO1_PLACS002_PBEAM0662)
print(INVPICO1_PLACS008_PBEAM0662)
print(INVPICO1_PLACS014_PBEAM0662)
print("PICO1_PLAAM_PBEAM00595")
print(PICO1_PLAAM002_PBEAM00595)
print(PICO1_PLAAM008_PBEAM00595)
print(PICO1_PLAAM014_PBEAM00595)
print(INVPICO1_PLAAM002_PBEAM00595)
print(INVPICO1_PLAAM008_PBEAM00595)
print(INVPICO1_PLAAM014_PBEAM00595)

print("PICO1_PLACS_ISO0662")
print(PICO1_PLACS002_ISO0662)
print(PICO1_PLACS008_ISO0662)
print(PICO1_PLACS014_ISO0662)
print(INVPICO1_PLACS002_ISO0662)
print(INVPICO1_PLACS008_ISO0662)
print(INVPICO1_PLACS014_ISO0662)
print("PICO1_PLAAM_ISO00595")
print(PICO1_PLAAM002_ISO00595)
print(PICO1_PLAAM008_ISO00595)
print(PICO1_PLAAM014_ISO00595)
print(INVPICO1_PLAAM002_ISO00595)
print(INVPICO1_PLAAM008_ISO00595)
print(INVPICO1_PLAAM014_ISO00595)

print("LN_PICO1_PLACS_EXP0662")
print(LN_PICO1_PLACS002_EXP0662)
print(LN_PICO1_PLACS008_EXP0662)
print(LN_PICO1_PLACS014_EXP0662)
print(LN_INVPICO1_PLACS002_EXP0662)
print(LN_INVPICO1_PLACS008_EXP0662)
print(LN_INVPICO1_PLACS014_EXP0662)
print("LN_PICO1_PLAAM_EXP00595")
print(LN_PICO1_PLAAM002_EXP00595)
print(LN_PICO1_PLAAM008_EXP00595)
print(LN_PICO1_PLAAM014_EXP00595)
print(LN_INVPICO1_PLAAM002_EXP00595)
print(LN_INVPICO1_PLAAM008_EXP00595)
print(LN_INVPICO1_PLAAM014_EXP00595)
# Out:
# CONTEXP_CS137_0662
# 9485
# 8606
# 8225
# CONTEXP_AM241_00595
# 548
# 592
# 224
# CONTPBEAM_CS137_0662
# 4313390
# 4026930
# 3764660
# CONTPBEAM_AM241_00595
# 7645430
# 6531960
# 5578480
# CONTISO_CS137_0662
# 3200
# 3118
# 2807
# CONTISO_AM241_00595
# 7477
# 6635
# 5901
# PICO1_PLACS_EXP0662
# 1.0032790353289613
# 0.91030251745293
# 0.8700021155066638
# 0.9967316816025303
# 1.0985359051824308
# 1.1494224924012157
# PICO1_PLAAM_EXP00595
# 0.9225589225589226
# 0.9966329966329966
# 0.3771043771043771
# 1.083941605839416
# 1.0033783783783783
# 2.6517857142857144
# PICO1_PLACS_PBEAM0662
# 0.9795745492615816
# 0.9145192388487804
# 0.8549574980753203
# 1.0503125
# 1.0779345734445158
# 1.1973637335233345
# PICO1_PLAAM_PBEAM00595
# 0.9490331453993411
# 0.8108172521915288
# 0.6924610415565006
# 1.0537039774087265
# 1.233323535355391
# 1.4441245643974703
# PICO1_PLACS_ISO0662
# 0.9520975900029753
# 0.927700089259149
# 0.8351681047307349
# 1.0503125
# 1.0779345734445158
# 1.1973637335233345
# ...

# %%
# I/I0 EXP - VALOR 1 (CS137 - EXP) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.9505

Y1_EXP_CS002=-0.1111*PICO1_PLACS002_EXP0662+1.0167
print(Y1_EXP_CS002)
Y1_EXP_CS008=-0.1111*PICO1_PLACS008_EXP0662+1.0167
print(Y1_EXP_CS008)
Y1_EXP_CS014=-0.1111*PICO1_PLACS014_EXP0662+1.0167
print(Y1_EXP_CS014)

X1_EXP_CS002=np.abs((PICO1_PLACS002_EXP0662-1.0167)/-0.1111)
print(f'equação linear - espessura 0.2 mm:{X1_EXP_CS002}')
X1_EXP_CS008=np.abs((PICO1_PLACS008_EXP0662-1.0167)/-0.1111)
print(f'equação linear - espessura 0.8 mm:{X1_EXP_CS008}')
X1_EXP_CS014=np.abs((PICO1_PLACS014_EXP0662-1.0167)/-0.1111)
print(f'equação linear - espessura 1.4 mm:{X1_EXP_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################


# R**2 = 0.9997

#Y2_EXP_CS002=-0.068*np.log(X_002)+0.8938
#print(Y2_CS002)
#Y2_EXP_CS008=-0.068*np.log(X_008)+0.8938
#print(Y2_EXP_CS008)
#Y2_EXP_CS014=-0.068*np.log(X_014)+0.8938
#print(Y2_EXP_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

# Y3_EXP_CS002 = 0.0732*X_002**2-0.2281*X_002+1.046
# print(Y3_EXP_CS002)
# Y3_EXP_CS008 = 0.0732*X_008**2-0.2281*X_008+1.046
# print(Y3_EXP_CS008)
# Y3_EXP_CS014 = 0.0732*X_014**2-0.2281*X_014+1.046
# print(Y3_EXP_CS014)

x3_EXP_CS1 = 1.5580601092896174
print(f'equação quadrática - primeira raiz:{x3_EXP_CS1}')
x3_EXP_CS2 = 0
print(f'equação quadrática - segunda raiz:{x3_EXP_CS2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 0.9576

Y4_EXP_CS002=1.0185*np.exp(-0.119*X_002)
print(Y4_EXP_CS002)
Y4_EXP_CS008=1.0185*np.exp(-0.119*X_008)
print(Y4_EXP_CS008)
Y4_EXP_CS014=1.0185*np.exp(-0.119*X_014)
print(Y4_EXP_CS014)

X4_EXP_CS002=np.log(PICO1_PLACS002_EXP0662/1.0185)/(-0.119)
print(f'equação exponencial - espessura 0.2 mm:{X4_EXP_CS002}')
X4_EXP_CS008=np.log(PICO1_PLACS008_EXP0662/1.0185)/(-0.119)
print(f'equação exponencial - espessura 0.8 mm:{X4_EXP_CS008}')
X4_EXP_CS014=np.log(PICO1_PLACS014_EXP0662/1.0185)/(-0.119)
print(f'equação exponencial - espessura 1.4 mm:{X4_EXP_CS014}')

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #
# Out:
# 0.9052356991749523
# 0.9155653903109794
# 0.9200427649672096
# equação linear - espessura 0.2 mm:0.12080076211555889
# equação linear - espessura 0.8 mm:0.9576731102346528
# equação linear - espessura 1.4 mm:1.320413001740199
# equação quadrática - primeira raiz:1.5580601092896174
# equação quadrática - segunda raiz:0
# 0.9945458846757741
# 0.9260111130118343
# 0.882965594630847
# equação exponencial - espessura 0.2 mm:0.12653181234277716
# equação exponencial - espessura 0.8 mm:0.9437752490702533
# equação exponencial - espessura 1.4 mm:1.3242906924733824

# %%
#equação linear - espessura 0.2 mm:0.12080076211555889
#equação linear - espessura 0.8 mm:0.9576731102346528
#equação linear - espessura 1.4 mm:1.320413001740199

Y1_EXP_CS002=-0.1111*0.12080076211555889+1.0167
print(Y1_EXP_CS002)
Y1_EXP_CS008=-0.1111*0.9576731102346528+1.0167
print(Y1_EXP_CS008)
Y1_EXP_CS014=-0.1111*1.320413001740199+1.0167
print(Y1_EXP_CS014)
# Out:
# 1.0032790353289613
# 0.91030251745293
# 0.8700021155066638

# %%
### 'I/I0 (CS-137 EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N1 = len(x1)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals1 = y1 - (a1 * x1 + b1)


# Dados de exemplo
x1 = np.array([0.2, 0.8, 1.4])
y1 = np.array([1.0032790353289613
, 0.91030251745293
, 0.8700021155066638
])

#media de x
mean_x=np.mean(x1)

#media de y
mean_y=np.mean(y1)

# Variância de x
var_x = np.var(x1, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y1, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x1, y1, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a1 = cov_xy/var_x
print(a1)
b1 = mean_y - a1 * mean_x
print(b1)

# Desvio padrão de x e y
sd_x = np.std(x1, ddof=1)
print(sd_x)
sd_y = np.std(y1, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_1 = a1*sd_x/sd_y
print(f'Coeficiente de Pearson (R_1): {R_1}')
RR_1 = np.abs(R_1)
print(f'Coeficiente de Pearson (RR_1): {RR_1}')

# Resíduos
residuals1 = y1 - (a1 * x1 + b1)

# Número de observações
N1 = len(x1)

# Erro padrão residual (epsilon1)
epsilon1_1 = np.sqrt(np.sum(residuals1**2) / (N1 - 2))
print(f"epsilon1: {epsilon1_1}")

# Desvio padrão de x
#sd_x = np.std(x1, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a1 = epsilon1_1 / (sd_x * np.sqrt(N1))
print(f"erro de a: {error_a1}")

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_1 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_1}")
MODabs_eps2eps2_1 = np.abs(eps2eps2_1)
print(f'valor absoluto de eps2eps2: {eps2eps2_1}')
NN1=(N1 / (N1 - 2))
print(f"NN: {NN1}")
epsilon2_1 = np.sqrt(NN1 * MODabs_eps2eps2_1)
print(f"epsilon2: {epsilon2_1}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente angular (error_a)
INVstdx1=1/sd_x
errorerror_a1 = INVstdx1*(epsilon1_1 / (np.sqrt(N1)))
print(f"erro de a: {errorerror_a1}")
# Erro padrão do coeficiente angular (epsilon2)
epsilon2epsilon2_1 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {epsilon2epsilon2_1}")
MODabs_epsilon2epsilon2_1 = np.abs(epsilon2epsilon2_1)
print(f'valor absoluto de eps2eps2: {epsilon2epsilon2_1}')
NN1=(N1 / (N1 - 2))
print(f"NN: {NN1}")
epsilon2_1 = np.sqrt(NN1 * MODabs_eps2eps2_1)
print(f"epsilon2: {epsilon2_1}")

# Erro padrão do coeficiente linear (error_b)

bb1=np.mean(x1**2)
print(bb1)
error_b1 = error_a1 * np.sqrt(bb1)
print(error_b1)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a1}')
print(f'Coeficiente linear (b): {b1}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_1}')
print(f'Erro padrão residual (epsilon2): {epsilon2_1}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a1}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b1}')
# Out:
# 0.3599999999999999
# 0.004671915438450284
# -0.03998307594668924
# -0.1110640998519146
# 1.0167125026443835
# 0.5999999999999999
# 0.06835141138594202
# Coeficiente de Pearson (R_1): -0.9749390474891411
# Coeficiente de Pearson (RR_1): 0.9749390474891411
# epsilon1: 0.02150493427660285
# erro de a: 0.02069313265583645
# eps2eps2: 0.00023123109912050622
# valor absoluto de eps2eps2: 0.00023123109912050622
# NN: 3.0
# epsilon2: 0.026338057964882654
# erro de a: 0.020693132655836447
# eps2eps2: 0.00023123109912050622
# valor absoluto de eps2eps2: 0.00023123109912050622
# NN: 3.0
# epsilon2: 0.026338057964882654
# 0.8799999999999999
# 0.01941187910581043
# Coeficiente angular (a): -0.1110640998519146
# Coeficiente linear (b): 1.0167125026443835
# Erro padrão residual (epsilon1): 0.02150493427660285
# Erro padrão residual (epsilon2): 0.026338057964882654
# Erro associado ao coeficiente angular (error_a): 0.02069313265583645
# ...

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N01 = len(x01)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals01 = y01 - (a01 * x01 + b01)


# Dados de exemplo
x01 = np.array([0.2, 0.8, 1.4])
y01 = np.array([1.0032790353289613
, 0.91030251745293
, 0.8700021155066638
])

#media de x
mean_x=np.mean(x01)

#media de y
mean_y=np.mean(y01)

# Variância de x
var_x = np.var(x01, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y01, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x01, y01, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a01 = cov_xy/var_x
print(a01)
b01 = mean_y - a01 * mean_x
print(b01)

# Desvio padrão de x e y
sd_x = np.std(x01, ddof=1)
print(sd_x)
sd_y = np.std(y01, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_01 = a01*sd_x/sd_y
print(f'Coeficiente de Pearson (R_01): {R_01}')
RR_01 = np.abs(R_01)
print(f'Coeficiente de Pearson (RR_01): {RR_01}')

# Resíduos
residuals01 = y01 - (a01 * x01 + b01)

# Número de observações
N01 = len(x01)

# Erro padrão residual (epsilon1)
epsilon1_01 = np.sqrt(np.sum(residuals01**2) / (N01 - 2))
print(f"epsilon01: {epsilon1_01}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a01 = epsilon1_01 / (sd_x * np.sqrt(N01))
print(f'Erro de a (error_a01): {error_a01}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_01 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_01}")
MODabs_eps2eps2_01 = np.abs(eps2eps2_01)
print(f'valor absoluto de eps2eps2: {eps2eps2_01}')
NN01=(N01 / (N01 - 2))
print(f"NN: {NN01}")
epsilon2_01 = np.sqrt(NN01 * MODabs_eps2eps2_01)
print(f"epsilon2: {epsilon2_01}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_01 = np.sqrt(NN01 * eps2eps2_01)
print(f"epsilon3: {epsilon3_01}")

# Erro padrão do coeficiente angular (error_a)
error_aa01 = epsilon2_01 / (sd_x * np.sqrt(N01))
print(f'Erro de a (error_aa2): {error_aa01}')

# Erro padrão do coeficiente angular (error_a)
error_aaa01 = epsilon3_01 / (sd_x * np.sqrt(N01))
print(f'Erro de a (error_aaa2): {error_aaa01}')

# Erro padrão do coeficiente linear (error_b)

bb01=np.mean(x01**2)
print(bb01)
error_b01 = error_a01 * np.sqrt(bb01)
print(f'Erro de b (error_b01): {error_b01}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a01}')
print(f'Coeficiente linear (b): {b01}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_01}')
print(f'Erro padrão residual (epsilon2): {epsilon2_01}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a01}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa01}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa01}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b01}')
# Out:
# 0.3599999999999999
# 0.004671915438450284
# -0.03998307594668924
# -0.1110640998519146
# 1.0167125026443835
# 0.5999999999999999
# 0.06835141138594202
# Coeficiente de Pearson (R_01): -0.9749390474891411
# Coeficiente de Pearson (RR_01): 0.9749390474891411
# epsilon01: 0.02150493427660285
# Erro de a (error_a01): 0.02069313265583645
# eps2eps2: 0.00023123109912050622
# valor absoluto de eps2eps2: 0.00023123109912050622
# NN: 3.0
# epsilon2: 0.026338057964882654
# epsilon3: 0.026338057964882654
# Erro de a (error_aa2): 0.02534380809326162
# Erro de a (error_aaa2): 0.02534380809326162
# 0.8799999999999999
# Erro de b (error_b01): 0.01941187910581043
# Coeficiente angular (a): -0.1110640998519146
# Coeficiente linear (b): 1.0167125026443835
# Erro padrão residual (epsilon1): 0.02150493427660285
# Erro padrão residual (epsilon2): 0.026338057964882654
# Erro associado ao coeficiente angular (error_a): 0.02069313265583645
# ...

# %%
### 'I/I0 (CS-137 EXP)' ###

# (I/I0) EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1=-0.1110640998519146

# COEF B

b1=1.0167125026443835

# ERRO

erro_a1= 0.02069313265583645

erro_b1= 0.01941187910581043

# %%
### 'I/I0 (CS-137 EXP)' ###

# (I/I0) EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a01=-0.1110640998519146

# COEF B

b01=1.0167125026443835

# ERRO

erro_a01= 0.02534380809326162

erro_b01= 0.01941187910581043

# %%
import sklearn
from sklearn.linear_model import LinearRegression
#import numpy as np

# Dados de exemplo
#x01 = np.array([0.2, 0.8, 1.4])
#y01 = np.array([1.0032790353289613, 0.91030251745293, 0.8700021155066638])


# Dados de exemplo
X = np.array([[0.2], [0.8], [1.4]])  # Variável independente
y = np.array([1.0032790353289613, 0.91030251745293, 0.8700021155066638])  # Variável dependente

# Criando e ajustando o modelo de regressão linear
model = LinearRegression().fit(X, y)

# Coeficientes da reta
print("Coeficiente de inclinação (slope):", model.coef_[0])
print("Intercepto (intercept):", model.intercept_)

# Fazendo previsões
new_x = np.array([[6], [7], [8]])  # Novos dados de X para prever
predicted_y = model.predict(new_x)
print("Previsões para novos valores de X:", predicted_y)
# Out:
# Coeficiente de inclinação (slope): -0.1110640998519146
# Intercepto (intercept): 1.0167125026443835
# Previsões para novos valores de X: [0.3503279 0.2392638 0.1281997]

# %%
import numpy as np
from scipy.stats import linregress

# Dados de exemplo
x = np.array([0.2, 0.8, 1.4]) # Variável independente
y = np.array([1.0032790353289613, 0.91030251745293, 0.8700021155066638])  # Variável dependente

# Ajuste da regressão linear
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Coeficientes da reta
print("Coeficiente de inclinação (slope):", slope)
print("Intercepto (intercept):", intercept)

# Erros associados aos coeficientes
print("Erro padrão do coeficiente de inclinação:", std_err)

# Valor de R-quadrado
print("R-quadrado:", r_value**2)

# Valor-p para teste de significância do coeficiente de inclinação
print("Valor-p:", p_value)


# Erro padrão do coeficiente linear (error_b)
bb=np.mean(x**2)
print(bb)
error_b = std_err * np.sqrt(bb)
print(f'padrão do Intercepto (intercept): {error_b}')
# Out:
# Coeficiente de inclinação (slope): -0.1110640998519146
# Intercepto (intercept): 1.0167125026443835
# Erro padrão do coeficiente de inclinação: 0.025343808093261616
# R-quadrado: 0.9505061463190336
# Valor-p: 0.14282528188131452
# 0.8799999999999999
# padrão do Intercepto (intercept): 0.023774599378914973

# %%
#equação exponencial - espessura 0.2 mm:0.12653181234277716
#equação exponencial - espessura 0.8 mm:0.9437752490702533
#equação exponencial - espessura 1.4 mm:1.3242906924733824

Y4_EXP_CS002=1.0185*np.exp(-0.119*0.12653181234277716)
print(Y4_EXP_CS002)
Y4_EXP_CS008=1.0185*np.exp(-0.119*0.9437752490702533)
print(Y4_EXP_CS008)
Y4_EXP_CS014=1.0185*np.exp(-0.119*1.3242906924733824)
print(Y4_EXP_CS014)
# Out:
# 1.0032790353289613
# 0.91030251745293
# 0.8700021155066638

# %%
### '(I/I0) (CS137 EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N2 = len(x2)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals2 = y2 - (a2 * x2 + b2)


# Dados de exemplo
x2 = np.array([0.2, 0.8, 1.4])
y2 = np.array([1.0032790353289613
, 0.91030251745293,  0.8700021155066638])

#media de x
mean_x=np.mean(x2)

#media de y
mean_y=np.mean(y2)

# Variância de x
var_x = np.var(x2, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y2, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x2, y2, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a2 = cov_xy/var_x
print(a2)
b2 = mean_y - a2 * mean_x
print(b2)

# Desvio padrão de x e y
sd_x = np.std(x2, ddof=1)
print(sd_x)
sd_y = np.std(y2, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_2 = a2*sd_x/sd_y
print(f'Coeficiente de Pearson (R_2): {R_2}')
RR_2 = np.abs(R_2)
print(f'Coeficiente de Pearson (RR_2): {RR_2}')

# Resíduos
residuals2 = y2 - (a2 * x2 + b2)

# Número de observações
N2 = len(x2)

# Erro padrão residual (epsilon1)
epsilon1_2 = np.sqrt(np.sum(residuals2**2) / (N2 - 2))
print(f"epsilon1: {epsilon1_2}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a2 = epsilon1_2 / (sd_x * np.sqrt(N2))
print(f'Erro de a (error_a2): {error_a2}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_2 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_2}")
MODabs_eps2eps2_2 = np.abs(eps2eps2_2)
print(f'valor absoluto de eps2eps2: {eps2eps2_2}')
NN2=(N2 / (N2 - 2))
print(f"NN: {NN2}")
epsilon2_2 = np.sqrt(NN2 * MODabs_eps2eps2_2)
print(f"epsilon2: {epsilon2_2}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_2 = np.sqrt(NN2 * eps2eps2_2)
print(f"epsilon3: {epsilon3_2}")

# Erro padrão do coeficiente angular (error_a)
error_aa2 = epsilon2_2 / (sd_x * np.sqrt(N2))
print(f'Erro de a (error_aa2): {error_aa2}')

# Erro padrão do coeficiente angular (error_a)
error_aaa2 = epsilon3_2 / (sd_x * np.sqrt(N2))
print(f'Erro de a (error_aaa2): {error_aaa2}')

# Erro padrão do coeficiente linear (error_b)

bb2=np.mean(x2**2)
print(bb2)
error_b2 = error_a2 * np.sqrt(bb2)
print(f'Erro de b (error_b2): {error_b2}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a2}')
print(f'Coeficiente linear (b): {b2}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_2}')
print(f'Erro padrão residual (epsilon2): {epsilon2_2}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a2}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa2}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa2}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b2}')
# Out:
# 0.3599999999999999
# 0.004671915438450284
# -0.03998307594668924
# -0.1110640998519146
# 1.0167125026443835
# 0.5999999999999999
# 0.06835141138594202
# Coeficiente de Pearson (R_2): -0.9749390474891411
# Coeficiente de Pearson (RR_2): 0.9749390474891411
# epsilon1: 0.02150493427660285
# Erro de a (error_a2): 0.02069313265583645
# eps2eps2: 0.00023123109912050622
# valor absoluto de eps2eps2: 0.00023123109912050622
# NN: 3.0
# epsilon2: 0.026338057964882654
# epsilon3: 0.026338057964882654
# Erro de a (error_aa2): 0.02534380809326162
# Erro de a (error_aaa2): 0.02534380809326162
# 0.8799999999999999
# Erro de b (error_b2): 0.01941187910581043
# Coeficiente angular (a): -0.1110640998519146
# Coeficiente linear (b): 1.0167125026443835
# Erro padrão residual (epsilon1): 0.02150493427660285
# Erro padrão residual (epsilon2): 0.026338057964882654
# Erro associado ao coeficiente angular (error_a): 0.02069313265583645
# Erro associado ao coeficiente angular (error_aa): 0.02534380809326162
# ...

# %%
# (I/I0) EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [-0.00327367  0.0939783   0.13925964]


################################################################################################################################


# COEF A

a2=-0.1110640998519146

# COEF B

b2= 1.0167125026443835

# ERRO

erro_a2= 0.02069313265583645

erro_b2= 0.01941187910581043

# %%
################################################################################################################################
################################################################################################################################
################################################################################################################################
################################################################################################################################
################################################################################################################################

# %%
# LN (I/I0) EXP - VALOR 1 (CS137 - EXP) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################


# R**2 = 0.9576

YY1_EXP_CS002=-0.1188*X_002+0.0184
print(YY1_EXP_CS002)
YY1_EXP_CS008=-0.1188*X_008+0.0184
print(YY1_EXP_CS008)
YY1_EXP_CS014=-0.1188*X_014+0.0184
print(YY1_EXP_CS014)

XX1_EXP_CS002 = np.abs((np.log(PICO1_PLACS002_EXP0662)-0.0184)/(-0.1188))
print(f'equação linear - espessura 0.2 mm:{XX1_EXP_CS002}')
XX1_EXP_CS008 = np.abs((np.log(PICO1_PLACS008_EXP0662)-0.0184)/(-0.1188))
print(f'equação linear - espessura 0.8 mm:{XX1_EXP_CS008}')
XX1_EXP_CS014 = np.abs((np.log(PICO1_PLACS014_EXP0662)-0.0184)/(-0.1188))
print(f'equação linear - espessura 1.4 mm:{XX1_EXP_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################


# R**2 = 0.9989

# YY2_EXP_CS002=-0.073*np.log(X_002)-0.1129
# print(YY2_EXP_CS002)
# YY2_EXP_CS008=-0.073*np.log(X_008)-0.1129
# print(YY2_EXP_CS008)
# YY2_EXP_CS014=-0.073*np.log(X_014)-0.1129
# print(YY2_EXP_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################


# R**2 = 1

# YY3_EXP_CS002 = 0.0722*X_002**2-0.2343*X_002+0.0472
# print(YY3_EXP_CS002)
# YY3_EXP_CS008 = 0.0722*X_008**2-0.2343*X_008+0.0472
# print(YY3_EXP_CS008)
# YY3_EXP_CS014 = 0.0722*X_014**2-0.2343*X_014+0.0472
# print(YY3_EXP_CS014)

XX3_EXP_CS1 = 3.029350444502868
print(f'equação quadrática - primeira raiz:{XX3_EXP_CS1}')
XX3_EXP_CS2 = 0.21580191006776953
print(f'equação quadrática - segunda raiz:{XX3_EXP_CS2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #
# Out:
# -0.005360000000000004
# -0.07664000000000001
# -0.12415999999999999
# equação linear - espessura 0.2 mm:0.1273260015493858
# equação linear - espessura 0.8 mm:0.9459452689784233
# equação linear - espessura 1.4 mm:1.3271013107711198
# equação quadrática - primeira raiz:3.029350444502868
# equação quadrática - segunda raiz:0.21580191006776953
# 'EQUAÇÃO EXPONENCIAL'

# %%
#equação linear - espessura 0.2 mm:0.1273260015493858
#equação linear - espessura 0.8 mm:0.9459452689784233
#equação linear - espessura 1.4 mm:1.3271013107711198

YY1_EXP_CS002=-0.1188*0.1273260015493858+0.0184
print(YY1_EXP_CS002)
YY1_EXP_CS008=-0.1188*0.9459452689784233+0.0184
print(YY1_EXP_CS008)
YY1_EXP_CS014=-0.1188*1.3271013107711198+0.0184
print(YY1_EXP_CS014)
# Out:
# 0.0032736710159329656
# -0.09397829795463669
# -0.13925963571960903

# %%
### 'LN(I/I0) (CS-137 EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N3 = len(x3)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals3 = y3 - (a3 * x3 + b3)


# Dados de exemplo
x3 = np.array([0.2, 0.8, 1.4])
y3 = np.array([0.0032736710159329656, -0.09397829795463669,  -0.13925963571960903])

#media de x
mean_x=np.mean(x3)

#media de y
mean_y=np.mean(y3)

# Variância de x
var_x = np.var(x3, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y3, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x3, y3, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a3 = cov_xy/var_x
print(a3)
b3 = mean_y - a3 * mean_x
print(b3)

# Desvio padrão de x e y
sd_x = np.std(x3, ddof=1)
print(sd_x)
sd_y = np.std(y3, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_3 = a3*sd_x/sd_y
print(f'Coeficiente de Pearson (R_3): {R_3}')
RR_3 = np.abs(R_3)
print(f'Coeficiente de Pearson (RR_3): {RR_3}')

# Resíduos
residuals3 = y3 - (a3 * x3 + b3)

# Número de observações
N3 = len(x3)

# Erro padrão residual (epsilon1)
epsilon1_3 = np.sqrt(np.sum(residuals3**2) / (N3 - 2))
print(epsilon1_3)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a3 = epsilon1_3 / (sd_x * np.sqrt(N3))
print(error_a3)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_3 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_3}")
MODabs_eps2eps2_3 = np.abs(eps2eps2_3)
print(f'valor absoluto de eps2eps2: {eps2eps2_3}')
NN3=(N3 / (N3 - 2))
print(f"NN: {NN3}")
epsilon2_3 = np.sqrt(NN3 * MODabs_eps2eps2_3)
print(f"epsilon2: {epsilon2_3}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_3 = np.sqrt(NN2 * eps2eps2_3)
print(f"epsilon3: {epsilon3_3}")

# Erro padrão do coeficiente angular (error_a)
error_aa3 = epsilon2_3 / (sd_x * np.sqrt(N3))
print(f'Erro de a (error_aa3): {error_aa3}')

# Erro padrão do coeficiente angular (error_a)
error_aaa3 = epsilon3_3 / (sd_x * np.sqrt(N3))
print(f'Erro de a (error_aaa3): {error_aaa3}')

# Erro padrão do coeficiente linear (error_b)

bb3=np.mean(x3**2)
print(bb3)
error_b3 = error_a3 * np.sqrt(bb3)
print(error_b3)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a3}')
print(f'Coeficiente linear (b): {b3}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_3}')
print(f'Erro padrão residual (epsilon2): {epsilon2_3}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a3}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa3}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa3}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b3}')
# Out:
# 0.3599999999999999
# 0.005304014757901043
# -0.04275999202066259
# -0.11877775561295169
# 0.018367450270923763
# 0.5999999999999999
# 0.07282866714351598
# Coeficiente de Pearson (R_3): -0.9785522125145187
# Coeficiente de Pearson (RR_3): 0.9785522125145187
# 0.021216921344012984
# 0.02041599208223503
# eps2eps2: 0.0002250788756590176
# valor absoluto de eps2eps2: 0.0002250788756590176
# NN: 3.0
# epsilon2: 0.025985315602798684
# epsilon3: 0.025985315602798684
# Erro de a (error_aa3): 0.02500438159708868
# Erro de a (error_aaa3): 0.02500438159708868
# 0.8799999999999999
# 0.019151898202989105
# Coeficiente angular (a): -0.11877775561295169
# Coeficiente linear (b): 0.018367450270923763
# Erro padrão residual (epsilon1): 0.021216921344012984
# Erro padrão residual (epsilon2): 0.025985315602798684
# Erro associado ao coeficiente angular (error_a): 0.02041599208223503
# Erro associado ao coeficiente angular (error_aa): 0.02500438159708868
# ...

# %%
### 'LN(I/I0) (CS-137 EXP)' ###

# LN(I/I0) EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a3=-0.11877775561295169

# COEF B

b3=0.018367450270923763

# ERRO

erro_a3= 0.02041599208223503

erro_b3= 0.019151898202989105

# %%
# CONTAGEM EXP - VALOR 1 (CS137 - EXP) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################


# R**2 = 0.9505

#YYY01_EXP_CS002=-1050*X_002+9612
#print(YYY01_EXP_CS002)
#YYY01_EXP_CS008=-1050*X_008+9612
#print(YYY01_EXP_CS008)
#YYY01_EXP_CS014=-1050*X_014+9612
#print(YYY01_EXP_CS014)

XXX1_EXP_CS002=np.abs((CONTEXP002_CS137_0662-9612)/-1050)
print(f'equação linear - espessura 0.2 mm:{XXX1_EXP_CS002}')
XXX1_EXP_CS008=np.abs((CONTEXP008_CS137_0662-9612)/-1050)
print(f'equação linear - espessura 0.8 mm:{XXX1_EXP_CS008}')
XXX1_EXP_CS014=np.abs((CONTEXP014_CS137_0662-9612)/-1050)
print(f'equação linear - espessura 1.4 mm:{XXX1_EXP_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################


# R**2 = 0.9997

# YYY2_EXP_CS002=-645*np.log(X_002)+8450.4
# print(YYY2_EXP_CS002)
# YYY2_EXP_CS008=-645*np.log(X_008)+8450.4
# print(YYY2_EXP_CS008)
# YYY2_EXP_CS014=-645*np.log(X_014)+8450.4
# print(YYY2_EXP_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################


# R**2 = 1

# YYY3_EXP_CS002 = 691.67*X_002**2-2156.7*X_002+9888.7
# print(YYY3_EXP_CS002)
# YYY3_EXP_CS008 = 691.67*X_002**2-2156.7*X_008+9888.7
# print(YYY3_EXP_CS008)
# YYY3_EXP_CS014 =691.67*X_002**2-2156.7*X_014+9888.7
# print(YYY3_EXP_CS014)

xx3_EXP_CS1 = 1.5590527274567352
print(f'equação quadrática - primeira raiz:{xx3_EXP_CS1}')
xx3_EXP_CS2 = 0
print(f'equação quadrática - segunda raiz:{xx3_EXP_CS2}')

################################################################################################################################


"EQUAÇÃO EXPONENCIAL"

################################################################################################################################


#YYY4_EXP_CS002=9629*np.exp(-0.119*X_002)
#print(YYY4_EXP_CS002)
#YYY4_EXP_CS008=9629*np.exp(-0.119*X_008)
#print(YYY4_EXP_CS008)
#YYY4_EXP_CS014=9629*np.exp(-0.119*X_014)
#print(YYY4_EXP_CS014)

XXX4_EXP_CS002=np.abs(np.log(CONTEXP002_CS137_0662/9629)/-0.119)
print(f'equação exponencial - espessura 0.2 mm:{XXX4_EXP_CS002}')
XXX4_EXP_CS008=np.abs(np.log(CONTEXP008_CS137_0662/9629)/-0.119)
print(f'equação exponencial - espessura 0.8 mm:{XXX4_EXP_CS008}')
XXX4_EXP_CS014=np.abs(np.log(CONTEXP014_CS137_0662/9629)/-0.119)
print(f'equação exponencial - espessura 1.4 mm:{XXX4_EXP_CS014}')


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #
# Out:
# equação linear - espessura 0.2 mm:0.12095238095238095
# equação linear - espessura 0.8 mm:0.9580952380952381
# equação linear - espessura 1.4 mm:1.3209523809523809
# equação quadrática - primeira raiz:1.5590527274567352
# equação quadrática - segunda raiz:0
# equação exponencial - espessura 0.2 mm:0.12661995690058278
# equação exponencial - espessura 0.8 mm:0.9438633936280592
# equação exponencial - espessura 1.4 mm:1.324378837031187

# %%
#equação linear - espessura 0.2 mm:0.12095238095238095
#equação linear - espessura 0.8 mm:0.9580952380952381
#equação linear - espessura 1.4 mm:1.3209523809523809

YYY01_EXP_CS002=-1050*0.12095238095238095+9612
print(YYY01_EXP_CS002)
YYY01_EXP_CS008=-1050*0.9580952380952381+9612
print(YYY01_EXP_CS008)
YYY01_EXP_CS014=-1050*1.3209523809523809+9612
print(YYY01_EXP_CS014)
# Out:
# 9485.0
# 8606.0
# 8225.0

# %%
### 'CONTAGEM (CS-137 EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N4 = len(x4)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals4 = y4 - (a4 * x4 + b4)


# Dados de exemplo
x4 = np.array([0.2, 0.8, 1.4])
y4 = np.array([9485.0, 8606.0, 8225.0])

#media de x
mean_x=np.mean(x4)

#media de y
mean_y=np.mean(y4)

# Variância de x
var_x = np.var(x4, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y4, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x4, y4, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a4 = cov_xy/var_x
print(a4)
b4 = mean_y - a4 * mean_x
print(b4)

# Desvio padrão de x e y
sd_x = np.std(x4, ddof=1)
print(sd_x)
sd_y = np.std(y4, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_4 = a4*sd_x/sd_y
print(f'Coeficiente de Pearson (R_4): {R_4}')
RR_4 = np.abs(R_4)
print(f'Coeficiente de Pearson (RR_4): {RR_4}')

# Resíduos
residuals4 = y4 - (a4 * x4 + b4)

# Número de observações
N4 = len(x4)

# Erro padrão residual (epsilon1)
epsilon1_4 = np.sqrt(np.sum(residuals4**2) / (N4 - 2))
print(f"epsilon01: {epsilon1_4}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a4 = epsilon1_4 / (sd_x * np.sqrt(N4))
print(f'Erro de a (error_a4): {error_a4}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_4 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_4}")
MODabs_eps2eps2_4 = np.abs(eps2eps2_4)
print(f'valor absoluto de eps2eps2: {eps2eps2_4}')
NN4=(N4 / (N4 - 2))
print(f"NN: {NN4}")
epsilon2_4 = np.sqrt(NN4 * MODabs_eps2eps2_4)
print(f"epsilon2: {epsilon2_4}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_4 = np.sqrt(NN4 * eps2eps2_4)
print(f"epsilon3: {epsilon3_4}")

# Erro padrão do coeficiente angular (error_a)
error_aa4 = epsilon2_4 / (sd_x * np.sqrt(N4))
print(f'Erro de a (error_aa4): {error_aa4}')

# Erro padrão do coeficiente angular (error_a)
error_aaa4 = epsilon3_4 / (sd_x * np.sqrt(N4))
print(f'Erro de a (error_aaa4): {error_aaa4}')

# Erro padrão do coeficiente linear (error_b)

bb4=np.mean(x4**2)
print(bb4)
error_b4 = error_a4 * np.sqrt(bb4)
print(f'Erro de b (error_b4): {error_b4}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a4}')
print(f'Coeficiente linear (b): {b4}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_4}')
print(f'Erro padrão residual (epsilon2): {epsilon2_4}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a4}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa4}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa4}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b4}')
# Out:
# 0.3599999999999999
# 417567.0
# -377.99999999999994
# -1050.0000000000002
# 9612.0
# 0.5999999999999999
# 646.1942432426955
# Coeficiente de Pearson (R_4): -0.9749390474891413
# Coeficiente de Pearson (RR_4): 0.9749390474891413
# epsilon01: 203.30764865100377
# Erro de a (error_a4): 195.6328761282782
# eps2eps2: 20666.99999999994
# valor absoluto de eps2eps2: 20666.99999999994
# NN: 3.0
# epsilon2: 248.99999999999966
# epsilon3: 248.99999999999966
# Erro de a (error_aa4): 239.60036171369444
# Erro de a (error_aaa4): 239.60036171369444
# 0.8799999999999999
# Erro de b (error_b4): 183.51990506633217
# Coeficiente angular (a): -1050.0000000000002
# Coeficiente linear (b): 9612.0
# Erro padrão residual (epsilon1): 203.30764865100377
# Erro padrão residual (epsilon2): 248.99999999999966
# Erro associado ao coeficiente angular (error_a): 195.6328761282782
# Erro associado ao coeficiente angular (error_aa): 239.60036171369444
# ...

# %%
### 'CONTAGEM (CS-137 EXP)' ###

# LN(I/I0) EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a4=-1050.0000000000002

# COEF B

b4=9612.0

# ERRO

erro_a4= 195.6328761282782

erro_b4= 183.51990506633217

# %%
#equação exponencial - espessura 0.2 mm:0.12661995690058278
#equação exponencial - espessura 0.8 mm:0.9438633936280592
#equação exponencial - espessura 1.4 mm:1.324378837031187
    
YYY4_EXP_CS002=9629*np.exp(-0.119*0.12661995690058278)
print(YYY4_EXP_CS002)
YYY4_EXP_CS008=9629*np.exp(-0.119*0.9438633936280592)
print(YYY4_EXP_CS008)
YYY4_EXP_CS014=9629*np.exp(-0.119*1.324378837031187)
print(YYY4_EXP_CS014)
# Out:
# 9485.0
# 8606.0
# 8225.0

# %%
### 'CONTAGEM (CS-137 EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N5 = len(x5)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals5 = y5 - (a5 * x5 + b5)


# Dados de exemplo
x5 = np.array([0.2, 0.8, 1.4])
y5 = np.array([9485.0
, 8606.0
, 8225.0])

#media de x
mean_x=np.mean(x5)

#media de y
mean_y=np.mean(y5)

# Variância de x
var_x = np.var(x5, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y5, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x5, y5, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a5 = cov_xy/var_x
print(a5)
b5 = mean_y - a5 * mean_x
print(b5)

# Desvio padrão de x e y
sd_x = np.std(x5, ddof=1)
print(sd_x)
sd_y = np.std(y5, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_5 = a5*sd_x/sd_y
print(f'Coeficiente de Pearson (R_5): {R_5}')
RR_5 = np.abs(R_5)
print(f'Coeficiente de Pearson (RR_5): {RR_5}')

# Resíduos
residuals5 = y5 - (a5 * x5 + b5)

# Número de observações
N5 = len(x5)

# Erro padrão residual (epsilon1)
epsilon1_5 = np.sqrt(np.sum(residuals5**2) / (N5 - 2))
print(f"epsilon5: {epsilon1_5}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a5 = epsilon1_5 / (sd_x * np.sqrt(N5))
print(f'Erro de a (error_a01): {error_a5}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_5 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_5}")
MODabs_eps2eps2_5 = np.abs(eps2eps2_5)
print(f'valor absoluto de eps2eps2: {eps2eps2_5}')
NN5=(N5 / (N5 - 2))
print(f"NN: {NN5}")
epsilon2_5 = np.sqrt(NN5 * MODabs_eps2eps2_5)
print(f"epsilon2: {epsilon2_5}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_5 = np.sqrt(NN5 * eps2eps2_5)
print(f"epsilon3: {epsilon3_5}")

# Erro padrão do coeficiente angular (error_a)
error_aa5 = epsilon2_5 / (sd_x * np.sqrt(N5))
print(f'Erro de a (error_aa2): {error_aa5}')

# Erro padrão do coeficiente angular (error_a)
error_aaa5 = epsilon3_5 / (sd_x * np.sqrt(N5))
print(f'Erro de a (error_aaa2): {error_aaa5}')

# Erro padrão do coeficiente linear (error_b)

bb5=np.mean(x5**2)
print(bb5)
error_b5 = error_a5 * np.sqrt(bb5)
print(f'Erro de b (error_b4): {error_b5}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a5}')
print(f'Coeficiente linear (b): {b5}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_5}')
print(f'Erro padrão residual (epsilon2): {epsilon2_5}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a5}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa5}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa5}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b5}')
# Out:
# 0.3599999999999999
# 417567.0
# -377.99999999999994
# -1050.0000000000002
# 9612.0
# 0.5999999999999999
# 646.1942432426955
# Coeficiente de Pearson (R_5): -0.9749390474891413
# Coeficiente de Pearson (RR_5): 0.9749390474891413
# epsilon5: 203.30764865100377
# Erro de a (error_a01): 195.6328761282782
# eps2eps2: 20666.99999999994
# valor absoluto de eps2eps2: 20666.99999999994
# NN: 3.0
# epsilon2: 248.99999999999966
# epsilon3: 248.99999999999966
# Erro de a (error_aa2): 239.60036171369444
# Erro de a (error_aaa2): 239.60036171369444
# 0.8799999999999999
# Erro de b (error_b4): 183.51990506633217
# Coeficiente angular (a): -1050.0000000000002
# Coeficiente linear (b): 9612.0
# Erro padrão residual (epsilon1): 203.30764865100377
# Erro padrão residual (epsilon2): 248.99999999999966
# Erro associado ao coeficiente angular (error_a): 195.6328761282782
# Erro associado ao coeficiente angular (error_aa): 239.60036171369444
# ...

# %%
### 'CONTAGEM (CS-137 EXP)' ###

# CONTAGEM EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a5=-1050.0000000000002

# COEF B

b5=9612.0

# ERRO

erro_a5= 195.6328761282782

erro_b5= 183.51990506633217

# %%
# I/I0 EXP - VALOR 1 (AM241 - EXP) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.6498

# Y1_EXP_AM002=-0.4545*X_002+1.1291
# print(Y1_EXP_AM002)
# Y1_EXP_AM008=-0.4545*X_008+1.1291
# print(Y1_EXP_AM008)
# Y1_EXP_AM014=-0.4545*X_014+1.1291
# print(Y1_EXP_AM014)

X1_EXP_AM002=np.abs((PICO1_PLAAM002_EXP00595-1.1291)/-0.4545)
print(f'equação linear - espessura 0.2 mm: {X1_EXP_AM002}')
X1_EXP_AM008=np.abs((PICO1_PLAAM008_EXP00595-1.1291)/-0.4545)
print(f'equação linear - espessura 0.8 mm: {X1_EXP_AM008}')
X1_EXP_AM014=np.abs((PICO1_PLAAM014_EXP00595-1.1291)/-0.4545)
print(f'equação linear - espessura 1.4 mm: {X1_EXP_AM014}')


################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.412

# Y2_EXP_AM002=-0.217*np.log(X_002)+0.6573
# print(Y2_EXP_AM002)
# Y2_EXP_AM008=-0.217*np.log(X_008)+0.6573
# print(Y2_EXP_AM008)
# Y2_EXP_AM014=-0.217*np.log(X_014)+0.6573
# print(Y2_EXP_AM014)

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#Y3_EXP_AM002 = -0.9633*X_002**2+1.0868*X_002+0.7437
#print(Y3_EXP_AM002)
#Y3_EXP_AM008 = -0.9633*X_002**2+1.0868*X_008+0.7437
#print(Y3_EXP_AM008)
#Y3_EXP_AM014 = -0.9633*X_002**2+1.0868*X_014+0.7437
#print(Y3_EXP_AM014)

x3_EXP_AM1 = -0.4800455753914926
print(f'equação quadrática - primeira raiz:{x3_EXP_AM1}')
x3_EXP_AM2 = 1.6082507035966
print(f'equação quadrática - segunda raiz:{x3_EXP_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################
PICO1_PLAAM002_EXP00595

# R**2 = 0.6857

#Y4_EXP_AM002=1.2755*np.exp(-0.746*X_002)
#print(Y4_EXP_AM002)
#Y4_EXP_AM008=1.2755*np.exp(-0.746*X_008)
#print(Y4_EXP_AM008)
#Y4_EXP_AM014=1.2755*np.exp(-0.746*X_014)
#print(Y4_EXP_AM014)

X4_EXP_AM002=(np.log(PICO1_PLAAM002_EXP00595/1.2755)/(-0.746))
print(f'equação exponencial - espessura 0.2 mm:{X4_EXP_AM002}')
X4_EXP_AM008=(np.log(PICO1_PLAAM008_EXP00595/1.2755)/(-0.746))
print(f'equação exponencial - espessura 0.2 mm:{X4_EXP_AM008}')
X4_EXP_AM014=(np.log(PICO1_PLAAM014_EXP00595/1.2755)/(-0.746))
print(f'equação exponencial - espessura 0.2 mm:{X4_EXP_AM014}')
# Out:
# equação linear - espessura 0.2 mm: 0.45443581395176547
# equação linear - espessura 0.8 mm: 0.2914565530627136
# equação linear - espessura 1.4 mm: 1.6545558259529654
# equação quadrática - primeira raiz:-0.4800455753914926
# equação quadrática - segunda raiz:1.6082507035966
# equação exponencial - espessura 0.2 mm:0.43423899599779964
# equação exponencial - espessura 0.2 mm:0.3307117199441934
# equação exponencial - espessura 0.2 mm:1.633473895586239

# %%
#equação linear - espessura 0.2 mm: 0.45443581395176547
#equação linear - espessura 0.8 mm: 0.2914565530627136
#equação linear - espessura 1.4 mm: 1.6545558259529654
    
Y1_EXP_AM002=-0.4545*0.45443581395176547+1.1291
print(Y1_EXP_AM002)
Y1_EXP_AM008=-0.4545*0.2914565530627136+1.1291
print(Y1_EXP_AM008)
Y1_EXP_AM014=-0.4545*1.6545558259529654+1.1291
print(Y1_EXP_AM014)
# Out:
# 0.9225589225589226
# 0.9966329966329966
# 0.37710437710437716

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N6 = len(x6)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals6 = y6 - (a6 * x6 + b6)


# Dados de exemplo
x6 = np.array([0.2, 0.8, 1.4])
y6 = np.array([0.9225589225589226, 0.9966329966329966, 0.37710437710437716])

#media de x
mean_x=np.mean(x6)

#media de y
mean_y=np.mean(y6)

# Variância de x
var_x = np.var(x6, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y6, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x6, y6, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a6 = cov_xy/var_x
print(a6)
b6 = mean_y - a6 * mean_x
print(b6)

# Desvio padrão de x e y
sd_x = np.std(x6, ddof=1)
print(sd_x)
sd_y = np.std(y6, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_6 = a6*sd_x/sd_y
print(f'Coeficiente de Pearson (R_6): {R_6}')
RR_6 = np.abs(R_6)
print(f'Coeficiente de Pearson (RR_6): {RR_6}')

# Resíduos
residuals6 = y6 - (a6 * x6 + b6)

# Número de observações
N6 = len(x6)

# Erro padrão residual (epsilon1)
epsilon1_6 = np.sqrt(np.sum(residuals6**2) / (N6 - 2))
print(f"epsilon01: {epsilon1_6}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a6 = epsilon1_6 / (sd_x * np.sqrt(N6))
print(f'Erro de a (error_a01): {error_a6}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_6 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_6}")
MODabs_eps2eps2_6 = np.abs(eps2eps2_6)
print(f'valor absoluto de eps2eps2: {eps2eps2_6}')
NN6=(N6 / (N6 - 2))
print(f"NN: {NN6}")
epsilon2_6 = np.sqrt(NN6 * MODabs_eps2eps2_6)
print(f"epsilon2: {epsilon2_6}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_6 = np.sqrt(NN01 * eps2eps2_6)
print(f"epsilon3: {epsilon3_6}")

# Erro padrão do coeficiente angular (error_a)
error_aa6 = epsilon2_6 / (sd_x * np.sqrt(N6))
print(f'Erro de a (error_aa6): {error_aa6}')

# Erro padrão do coeficiente angular (error_a)
error_aaa6 = epsilon3_6 / (sd_x * np.sqrt(N6))
print(f'Erro de a (error_aaa2): {error_aaa6}')

# Erro padrão do coeficiente linear (error_b)

bb6=np.mean(x6**2)
print(bb6)
error_b6 = error_a6 * np.sqrt(bb6)
print(f'Erro de b (error_b01): {error_b6}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a6}')
print(f'Coeficiente linear (b): {b6}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_6}')
print(f'Erro padrão residual (epsilon2): {epsilon2_6}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a6}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa6}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa6}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b6}')
# Out:
# 0.3599999999999999
# 0.1144705566703322
# -0.1636363636363636
# -0.45454545454545464
# 1.1290684624017957
# 0.5999999999999999
# 0.33833497701291865
# Coeficiente de Pearson (R_6): -0.806086545160417
# Coeficiente de Pearson (RR_6): 0.806086545160417
# epsilon01: 0.2831621139244303
# Erro de a (error_a01): 0.2724728711642889
# eps2eps2: 0.04009039138107599
# valor absoluto de eps2eps2: 0.04009039138107599
# NN: 3.0
# epsilon2: 0.3468013468013468
# epsilon3: 0.3468013468013468
# Erro de a (error_aa6): 0.333709751551804
# Erro de a (error_aaa2): 0.333709751551804
# 0.8799999999999999
# Erro de b (error_b01): 0.2556022098066639
# Coeficiente angular (a): -0.45454545454545464
# Coeficiente linear (b): 1.1290684624017957
# Erro padrão residual (epsilon1): 0.2831621139244303
# Erro padrão residual (epsilon2): 0.3468013468013468
# Erro associado ao coeficiente angular (error_a): 0.2724728711642889
# Erro associado ao coeficiente angular (error_aa): 0.333709751551804
# ...

# %%
# (I/I0) EXP - VALOR NORMAL (AM241 - EXP) (PICO 1 - 59.5 KEV)

################################################################################################################################


# [-0.00327367  0.0939783   0.13925964]


################################################################################################################################


# COEF A

a2=-0.1110640998519146

# COEF B

b2= 1.0167125026443835

# ERRO

erro_a2= 0.02069313265583645

erro_b2= 0.01941187910581043

# %%
#equação exponencial - espessura 0.2 mm:0.43423899599779964
#equação exponencial - espessura 0.2 mm:0.3307117199441934
#equação exponencial - espessura 0.2 mm:1.633473895586239
    
Y4_EXP_AM002=1.2755*np.exp(-0.746*0.43423899599779964)
print(Y4_EXP_AM002)
Y4_EXP_AM008=1.2755*np.exp(-0.746*0.3307117199441934)
print(Y4_EXP_AM008)
Y4_EXP_AM014=1.2755*np.exp(-0.746*1.633473895586239)
print(Y4_EXP_AM014)
# Out:
# 0.9225589225589226
# 0.9966329966329966
# 0.3771043771043771

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N7 = len(x7)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals7 = y7 - (a7 * x7 + b7)


# Dados de exemplo
x7 = np.array([0.2, 0.8, 1.4])
y7 = np.array([0.9225589225589226, 0.9966329966329966, 0.3771043771043771])

#media de x
mean_x=np.mean(x7)

#media de y
mean_y=np.mean(y7)

# Variância de x
var_x = np.var(x7, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y7, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x7, y7, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a7 = cov_xy/var_x
print(a7)
b7 = mean_y - a7 * mean_x
print(b7)

# Desvio padrão de x e y
sd_x = np.std(x7, ddof=1)
print(sd_x)
sd_y = np.std(y7, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_7 = a7*sd_x/sd_y
print(f'Coeficiente de Pearson (R_7): {R_7}')
RR_7 = np.abs(R_7)
print(f'Coeficiente de Pearson (RR_7): {RR_7}')

# Resíduos
residuals7 = y7 - (a7 * x7 + b7)

# Número de observações
N7 = len(x7)

# Erro padrão residual (epsilon1)
epsilon1_7 = np.sqrt(np.sum(residuals7**2) / (N7 - 2))
print(f"epsilon01: {epsilon1_7}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a7 = epsilon1_7 / (sd_x * np.sqrt(N7))
print(f'Erro de a (error_a7): {error_a7}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_7 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_7}")
MODabs_eps2eps2_7 = np.abs(eps2eps2_7)
print(f'valor absoluto de eps2eps2: {eps2eps2_7}')
NN7=(N7 / (N7 - 2))
print(f"NN: {NN7}")
epsilon2_7 = np.sqrt(NN7 * MODabs_eps2eps2_7)
print(f"epsilon2: {epsilon2_7}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_7 = np.sqrt(NN7 * eps2eps2_7)
print(f"epsilon3: {epsilon3_7}")

# Erro padrão do coeficiente angular (error_a)
error_aa7 = epsilon2_7 / (sd_x * np.sqrt(N7))
print(f'Erro de a (error_aa7): {error_aa7}')

# Erro padrão do coeficiente angular (error_a)
error_aaa7 = epsilon3_7 / (sd_x * np.sqrt(N7))
print(f'Erro de a (error_aaa7): {error_aaa7}')

# Erro padrão do coeficiente linear (error_b)

bb7=np.mean(x7**2)
print(bb7)
error_b7 = error_a7 * np.sqrt(bb7)
print(f'Erro de b (error_b01): {error_b7}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a7}')
print(f'Coeficiente linear (b): {b7}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_7}')
print(f'Erro padrão residual (epsilon2): {epsilon2_7}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a7}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa7}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa7}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b7}')
# Out:
# 0.3599999999999999
# 0.11447055667033221
# -0.1636363636363636
# -0.45454545454545464
# 1.1290684624017957
# 0.5999999999999999
# 0.33833497701291865
# Coeficiente de Pearson (R_7): -0.806086545160417
# Coeficiente de Pearson (RR_7): 0.806086545160417
# epsilon01: 0.2831621139244303
# Erro de a (error_a7): 0.2724728711642889
# eps2eps2: 0.04009039138107601
# valor absoluto de eps2eps2: 0.04009039138107601
# NN: 3.0
# epsilon2: 0.34680134680134683
# epsilon3: 0.34680134680134683
# Erro de a (error_aa7): 0.33370975155180405
# Erro de a (error_aaa7): 0.33370975155180405
# 0.8799999999999999
# Erro de b (error_b01): 0.2556022098066639
# Coeficiente angular (a): -0.45454545454545464
# Coeficiente linear (b): 1.1290684624017957
# Erro padrão residual (epsilon1): 0.2831621139244303
# Erro padrão residual (epsilon2): 0.34680134680134683
# Erro associado ao coeficiente angular (error_a): 0.2724728711642889
# Erro associado ao coeficiente angular (error_aa): 0.33370975155180405
# ...

# %%
# (I/I0) EXP - VALOR NORMAL (AM241 - EXP) (PICO 1 - 59.5 KEV)

################################################################################################################################


# [-0.00327367  0.0939783   0.13925964]


################################################################################################################################


# COEF A

a7=-0.45454545454545464

# COEF B

b7= 1.1290684624017957

# ERRO

erro_a7= 0.2724728711642889

erro_b7= 0.01941187910581043

# %%
# ln(I/I0) EXP - VALOR 1 (AM241 - EXP) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.6857

#YY1_EXP_AM002=-0.7455*X_002+0.2433
#print(YY1_EXP_AM002)
#YY1_EXP_AM008=-0.7455*X_008+0.2433
#print(YY1_EXP_CS008)
#YY1_EXP_AM014=-0.7455*X_014+0.2433
#print(YY1_EXP_AM014)

XX1_EXP_AM002 = np.abs((np.log(PICO1_PLAAM002_EXP00595)-0.2433)/(-0.7455))
print(f'equação linear - espessura 0.2 mm:{XX1_EXP_AM002}')
XX1_EXP_AM008 = np.abs((np.log(PICO1_PLAAM008_EXP00595)-0.2433)/(-0.7455))
print(f'equação linear - espessura 0.8 mm:{XX1_EXP_AM008}')
XX1_EXP_AM014 = np.abs((np.log(PICO1_PLAAM014_EXP00595)-0.2433)/(-0.7455))
print(f'equação linear - espessura 1.4 mm:{XX1_EXP_AM014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.4498

# YY2_EXP_CS002=-0.362*np.log(X_002)-0.5334
# print(YY2_EXP_CS002)
# YY2_EXP_CS008=-0.362*np.log(X_008)-0.5334
# print(YY2_EXP_CS008)
# YY2_EXP_CS014=-0.362*np.log(X_014)-0.5334
# print(YY2_EXP_CS014)


################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#YY3_EXP_AM002 = -1.4571*X_002**2+1.5858*X_002-0.3395
#print(YY3_EXP_AM002)
#YY3_EXP_AM008 = -1.4571*X_008**2+1.5858*X_008-0.3395
#print(YY3_EXP_AM008)
#YY3_EXP_AM014 = -1.4571*X_014**2+1.5858*X_014-0.3395
#print(YY3_EXP_AM014)

xx3_EXP_AM1 = 0.29293330647485183
print(f'equação quadrática - primeira raiz:{xx3_EXP_AM1}')
xx3_EXP_AM2 = 0.7953928207641846
print(f'equação quadrática - segunda raiz:{xx3_EXP_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# equação linear - espessura 0.2 mm:0.4344789167198248
# equação linear - espessura 0.8 mm:0.33088220587342615
# equação linear - espessura 1.4 mm:1.634518132136291
# equação quadrática - primeira raiz:0.29293330647485183
# equação quadrática - segunda raiz:0.7953928207641846
# 'EQUAÇÃO EXPONENCIAL'

# %%
#equação linear - espessura 0.2 mm: 0.45443581395176547
#equação linear - espessura 0.8 mm: 0.2914565530627136
#equação linear - espessura 1.4 mm: 1.6545558259529654
    
YY1_EXP_AM002=-0.7455*0.45443581395176547+0.2433
print(YY1_EXP_AM002)
YY1_EXP_AM008=-0.7455*0.2914565530627136+0.2433
print(YY1_EXP_CS008)
YY1_EXP_AM014=-0.7455*1.6545558259529654+0.2433
print(YY1_EXP_AM014)
# Out:
# -0.0954818993010412
# -0.09397829795463669
# -0.9901713682479357

# %%
# ln(I/I0) EXP - VALOR 1 (AM241 - EXP) (PICO 1 - 59.5 KEV)

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N8 = len(x8)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals8 = y8 - (a8 * x8 + b8)


# Dados de exemplo
x8 = np.array([0.2, 0.8, 1.4])
y8 = np.array([-0.0954818993010412, -0.0939782979546366, -0.9901713682479357])

#media de x
mean_x=np.mean(x8)

#media de y
mean_y=np.mean(y8)

# Variância de x
var_x = np.var(x8, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y8, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x8, y8, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a8 = cov_xy/var_x
print(a8)
b8 = mean_y - a8 * mean_x
print(b8)

# Desvio padrão de x e y
sd_x = np.std(x8, ddof=1)
print(sd_x)
sd_y = np.std(y8, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_8 = a8*sd_x/sd_y
print(f'Coeficiente de Pearson (R_8): {R_8}')
RR_8 = np.abs(R_8)
print(f'Coeficiente de Pearson (RR_8): {RR_8}')

# Resíduos
residuals8 = y8 - (a8 * x8 + b8)

# Número de observações
N8 = len(x8)

# Erro padrão residual (epsilon1)
epsilon1_8 = np.sqrt(np.sum(residuals8**2) / (N8 - 2))
print(f"epsilon8: {epsilon1_8}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a8 = epsilon1_8 / (sd_x * np.sqrt(N8))
print(f'Erro de a (error_a8): {error_a8}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_8 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_8}")
MODabs_eps2eps2_8 = np.abs(eps2eps2_8)
print(f'valor absoluto de eps2eps2: {eps2eps2_8}')
NN8=(N8 / (N8 - 2))
print(f"NN: {NN8}")
epsilon2_8 = np.sqrt(NN8 * MODabs_eps2eps2_8)
print(f"epsilon2: {epsilon2_8}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_8 = np.sqrt(NN8 * eps2eps2_01)
print(f"epsilon3: {epsilon3_8}")

# Erro padrão do coeficiente angular (error_a)
error_aa8 = epsilon2_8/ (sd_x * np.sqrt(N8))
print(f'Erro de a (error_aa8): {error_aa8}')

# Erro padrão do coeficiente angular (error_a)
error_aaa8 = epsilon3_8 / (sd_x * np.sqrt(N8))
print(f'Erro de a (error_aaa2): {error_aaa8}')

# Erro padrão do coeficiente linear (error_b)

bb8=np.mean(x8**2)
print(bb8)
error_b8 = error_a8 * np.sqrt(bb8)
print(f'Erro de b (error_b8): {error_b8}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a8}')
print(f'Coeficiente linear (b): {b8}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_8}')
print(f'Erro padrão residual (epsilon2): {epsilon2_8}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a8}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa8}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa8}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b8}')
# Out:
# 0.3599999999999999
# 0.2672722543172026
# -0.26840684068406834
# -0.7455745574557456
# 0.20324912413005858
# 0.5999999999999999
# 0.5169838046952753
# Coeficiente de Pearson (R_8): -0.865297385354508
# Coeficiente de Pearson (RR_8): 0.865297385354508
# epsilon8: 0.36648313155200885
# Erro de a (error_a8): 0.352648557758349
# eps2eps2: 0.0671549428560835
# valor absoluto de eps2eps2: 0.0671549428560835
# NN: 3.0
# epsilon2: 0.44884833581985184
# epsilon3: 0.026338057964882654
# Erro de a (error_aa8): 0.43190451251817846
# Erro de a (error_aaa2): 0.02534380809326162
# 0.8799999999999999
# Erro de b (error_b8): 0.33081367059775263
# Coeficiente angular (a): -0.7455745574557456
# Coeficiente linear (b): 0.20324912413005858
# Erro padrão residual (epsilon1): 0.36648313155200885
# Erro padrão residual (epsilon2): 0.44884833581985184
# Erro associado ao coeficiente angular (error_a): 0.352648557758349
# Erro associado ao coeficiente angular (error_aa): 0.43190451251817846
# ...

# %%
# CONTAGEM EXP - VALOR 1 (AM241 - EXP) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.6498

#YYY1_EXP_AM002=-270*X_002+670.67
#print(YYY1_EXP_AM002)
#YYY1_EXP_AM008=-270*X_008+670.67
#print(YYY1_EXP_AM008)
#YYY1_EXP_AM014=-270*X_014+670.67
#print(YYY1_EXP_AM014)

XXX1_EXP_AM002=np.abs((CONTEXP002_AM241_00595-670.67)/-270)
print(f'equação linear - espessura 0.2 mm:{XXX1_EXP_AM002}')
XXX1_EXP_AM008=np.abs((CONTEXP008_AM241_00595-670.67)/-270)
print(f'equação linear - espessura 0.8 mm:{XXX1_EXP_AM008}')
XXX1_EXP_AM014=np.abs((CONTEXP014_AM241_00595-670.67)/-270)
print(f'equação linear - espessura 1.4 mm:{XXX1_EXP_AM014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.412

#YYY2_EXP_AM002=-128.8*np.log(X_002)+390.45
#print(YYY2_EXP_AM002)
#YYY2_EXP_AM008=-128.8*np.log(X_008)+390.45
#print(YYY2_EXP_AM008)
#YYY2_EXP_AM014=-128.8*np.log(X_014)+390.45
#print(YYY2_EXP_AM014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#YYY3_EXP_AM002 = -572.22*X_002**2+645.56*X_002+441.78
#print(YYY3_EXP_AM002)
#YYY3_EXP_AM008 = -572.22*X_002**2+645.56*X_002+441.78
#print(YYY3_EXP_AM008)
#YYY3_EXP_AM014 = -572.22*X_002**2+645.56*X_002+441.78
#print(YYY3_EXP_AM014)


xxx3_EXP_AM1 = -0.48006001378122254
print(f'equação quadrática - primeira raiz:{xxx3_EXP_AM1}')
xxx3_EXP_AM2 = 1.608227501810302
print(f'equação quadrática - segunda raiz:{xxx3_EXP_AM2}')


################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 0.6857

#YYY4_EXP_AM002=757.66*np.exp(-0.746*X_002)
#print(YYY4_EXP_AM002)
#YYY4_EXP_AM008=757.66*np.exp(-0.746*X_008)
#print(YYY4_EXP_AM008)
#YYY4_EXP_AM014=757.66*np.exp(-0.746*X_014)
#print(YYY4_EXP_AM014)

XXX4_EXP_AM002=np.abs(np.log(CONTEXP002_AM241_00595/757.66)/-0.746)
print(f'equação exponencial - espessura 0.2 mm:{XXX4_EXP_AM002}')
XXX4_EXP_AM008=np.abs(np.log(CONTEXP008_AM241_00595/757.66)/-0.746)
print(f'equação exponencial - espessura 0.8 mm:{XXX4_EXP_AM008}')
XXX4_EXP_AM014=np.abs(np.log(CONTEXP014_AM241_00595/757.66)/-0.746)
print(f'equação exponencial - espessura 1.4 mm:{XXX4_EXP_AM014}')
# Out:
# equação linear - espessura 0.2 mm:0.4543333333333332
# equação linear - espessura 0.8 mm:0.2913703703703702
# equação linear - espessura 1.4 mm:1.6543333333333332
# equação quadrática - primeira raiz:-0.48006001378122254
# equação quadrática - segunda raiz:1.608227501810302
# equação exponencial - espessura 0.2 mm:0.43426199631847223
# equação exponencial - espessura 0.8 mm:0.3307347202648661
# equação exponencial - espessura 1.4 mm:1.6334968959069114

# %%
#equação linear - espessura 0.2 mm:0.4543333333333332
#equação linear - espessura 0.8 mm:0.2913703703703702
#equação linear - espessura 1.4 mm:1.6543333333333332
    
YYY1_EXP_AM002=-270*0.4543333333333332+670.67
print(YYY1_EXP_AM002)
YYY1_EXP_AM008=-270*0.2913703703703702+670.67
print(YYY1_EXP_AM008)
YYY1_EXP_AM014=-270*1.6543333333333332+670.67
print(YYY1_EXP_AM014)
# Out:
# 548.0
# 592.0
# 224.0

# %%
### 'CONTAGEM (AM241 - EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N9 = len(x9)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals9 = y9 - (a9 * x9 + b9)


# Dados de exemplo
x9 = np.array([0.2, 0.8, 1.4])
y9 = np.array([548.0, 592.0, 224.0])

#media de x
mean_x=np.mean(x9)

#media de y
mean_y=np.mean(y9)

# Variância de x
var_x = np.var(x9, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y9, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x9, y9, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a9 = cov_xy/var_x
print(a9)
b9 = mean_y - a9 * mean_x
print(b9)

# Desvio padrão de x e y
sd_x = np.std(x9, ddof=1)
print(sd_x)
sd_y = np.std(y9, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_9 = a9*sd_x/sd_y
print(f'Coeficiente de Pearson (R_9): {R_9}')
RR_9 = np.abs(R_9)
print(f'Coeficiente de Pearson (RR_9): {RR_9}')

# Resíduos
residuals9 = y9 - (a9 * x9 + b9)

# Número de observações
N9 = len(x9)

# Erro padrão residual (epsilon1)
epsilon1_9 = np.sqrt(np.sum(residuals9**2) / (N9 - 2))
print(f"epsilon01: {epsilon1_9}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a9 = epsilon1_9 / (sd_x * np.sqrt(N9))
print(f'Erro de a (error_a9): {error_a9}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_9 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_9}")
MODabs_eps2eps2_9 = np.abs(eps2eps2_9)
print(f'valor absoluto de eps2eps2: {eps2eps2_9}')
NN9=(N9 / (N9 - 2))
print(f"NN: {NN4}")
epsilon2_9 = np.sqrt(NN9 * MODabs_eps2eps2_9)
print(f"epsilon2: {epsilon2_9}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_9 = np.sqrt(NN9 * eps2eps2_9)
print(f"epsilon3: {epsilon3_9}")

# Erro padrão do coeficiente angular (error_a)
error_aa9 = epsilon2_9 / (sd_x * np.sqrt(N9))
print(f'Erro de a (error_aa9): {error_aa9}')

# Erro padrão do coeficiente angular (error_a)
error_aaa9 = epsilon3_9 / (sd_x * np.sqrt(N9))
print(f'Erro de a (error_aaa9): {error_aaa9}')

# Erro padrão do coeficiente linear (error_b)

bb9=np.mean(x9**2)
print(bb9)
error_b9 = error_a9 * np.sqrt(bb9)
print(f'Erro de b (error_b9): {error_b9}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a9}')
print(f'Coeficiente linear (b): {b9}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_9}')
print(f'Erro padrão residual (epsilon2): {epsilon2_9}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a9}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa9}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa9}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b9}')
# Out:
# 0.3599999999999999
# 40389.33333333333
# -97.19999999999999
# -270.00000000000006
# 670.6666666666667
# 0.5999999999999999
# 200.97097634567368
# Coeficiente de Pearson (R_9): -0.8060865451604171
# Coeficiente de Pearson (RR_9): 0.8060865451604171
# epsilon01: 168.19829567111157
# Erro de a (error_a9): 161.8488854715876
# eps2eps2: 14145.333333333325
# valor absoluto de eps2eps2: 14145.333333333325
# NN: 3.0
# epsilon2: 205.99999999999994
# epsilon3: 205.99999999999994
# Erro de a (error_aa9): 198.2235924217715
# Erro de a (error_aaa9): 198.2235924217715
# 0.8799999999999999
# Erro de b (error_b9): 151.82771262515834
# Coeficiente angular (a): -270.00000000000006
# Coeficiente linear (b): 670.6666666666667
# Erro padrão residual (epsilon1): 168.19829567111157
# Erro padrão residual (epsilon2): 205.99999999999994
# Erro associado ao coeficiente angular (error_a): 161.8488854715876
# Erro associado ao coeficiente angular (error_aa): 198.2235924217715
# ...

# %%
### 'CONTAGEM (AM241 - EXP)' ###

# CONTAGEM EXP - VALOR NORMAL (AM241 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a9=-270.00000000000006

# COEF B

b9=670.6666666666667

# ERRO

erro_a9= 161.8488854715876

erro_b9= 151.82771262515834

# %%
#equação exponencial - espessura 0.2 mm:0.43426199631847223
#equação exponencial - espessura 0.8 mm:0.3307347202648661
#equação exponencial - espessura 1.4 mm:1.6334968959069114
    
YYY4_EXP_AM002=757.66*np.exp(-0.746*0.43426199631847223)
print(YYY4_EXP_AM002)
YYY4_EXP_AM008=757.66*np.exp(-0.746*0.3307347202648661)
print(YYY4_EXP_AM008)
YYY4_EXP_AM014=757.66*np.exp(-0.746*1.6334968959069114)
print(YYY4_EXP_AM014)
# Out:
# 548.0
# 592.0
# 224.00000000000003

# %%
### 'CONTAGEM (AM241 - EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N10 = len(x10)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals10 = y10 - (a10 * x10 + b10)


# Dados de exemplo
x10 = np.array([0.2, 0.8, 1.4])
y10 = np.array([548.0, 592.0, 224.0])

#media de x
mean_x=np.mean(x10)

#media de y
mean_y=np.mean(y10)

# Variância de x
var_x = np.var(x10, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y10, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x10, y10, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a10 = cov_xy/var_x
print(a10)
b10 = mean_y - a10 * mean_x
print(b10)

# Desvio padrão de x e y
sd_x = np.std(x10, ddof=1)
print(sd_x)
sd_y = np.std(y10, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_10 = a10*sd_x/sd_y
print(f'Coeficiente de Pearson (R_10): {R_10}')
RR_10 = np.abs(R_10)
print(f'Coeficiente de Pearson (RR_10): {RR_10}')

# Resíduos
residuals10 = y10 - (a10 * x10 + b10)

# Número de observações
N10 = len(x10)

# Erro padrão residual (epsilon1)
epsilon1_10 = np.sqrt(np.sum(residuals10**2) / (N10 - 2))
print(f"epsilon01: {epsilon1_10}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a10 = epsilon1_10 / (sd_x * np.sqrt(N10))
print(f'Erro de a (error_a10): {error_a10}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_10 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_10}")
MODabs_eps2eps2_10 = np.abs(eps2eps2_10)
print(f'valor absoluto de eps2eps2: {eps2eps2_10}')
NN10=(N10 / (N10 - 2))
print(f"NN: {NN10}")
epsilon2_10 = np.sqrt(NN10 * MODabs_eps2eps2_10)
print(f"epsilon2: {epsilon2_10}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_10 = np.sqrt(NN10 * eps2eps2_10)
print(f"epsilon3: {epsilon3_10}")

# Erro padrão do coeficiente angular (error_a)
error_aa10 = epsilon2_10 / (sd_x * np.sqrt(N10))
print(f'Erro de a (error_aa10): {error_aa10}')

# Erro padrão do coeficiente angular (error_a)
error_aaa10 = epsilon3_10 / (sd_x * np.sqrt(N10))
print(f'Erro de a (error_aaa10): {error_aaa10}')

# Erro padrão do coeficiente linear (error_b)

bb10=np.mean(x10**2)
print(bb10)
error_b10 = error_a10 * np.sqrt(bb10)
print(f'Erro de b (error_b4): {error_b10}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a10}')
print(f'Coeficiente linear (b): {b10}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_10}')
print(f'Erro padrão residual (epsilon2): {epsilon2_10}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a10}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa10}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa10}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b10}')
# Out:
# 0.3599999999999999
# 40389.33333333333
# -97.19999999999999
# -270.00000000000006
# 670.6666666666667
# 0.5999999999999999
# 200.97097634567368
# Coeficiente de Pearson (R_10): -0.8060865451604171
# Coeficiente de Pearson (RR_10): 0.8060865451604171
# epsilon01: 168.19829567111157
# Erro de a (error_a10): 161.8488854715876
# eps2eps2: 14145.333333333325
# valor absoluto de eps2eps2: 14145.333333333325
# NN: 3.0
# epsilon2: 205.99999999999994
# epsilon3: 205.99999999999994
# Erro de a (error_aa10): 198.2235924217715
# Erro de a (error_aaa10): 198.2235924217715
# 0.8799999999999999
# Erro de b (error_b4): 151.82771262515834
# Coeficiente angular (a): -270.00000000000006
# Coeficiente linear (b): 670.6666666666667
# Erro padrão residual (epsilon1): 168.19829567111157
# Erro padrão residual (epsilon2): 205.99999999999994
# Erro associado ao coeficiente angular (error_a): 161.8488854715876
# Erro associado ao coeficiente angular (error_aa): 198.2235924217715
# ...

# %%
# (I/I0) EXP - VALOR NORMAL (CS137 - PBEAM) (PICO 1 - 662 KEV)

################################################################################################################################


# [-0.00327367  0.0939783   0.13925964]


################################################################################################################################


# COEF A

a10=0.11877775833333334

# COEF B

b10=-0.018367450000000007

# ERRO

erro_a10= 0.020415991608631685

errob_210= 0.019151897758709787

# %%
# I/I0 PBEAM - VALOR 1 (CS137 - PBEAM) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.9994

#Y1_PBEAM_CS002=-0.1038*X_002+0.9994
#print(Y1_PBEAM_CS002)
#Y1_PBEAM_CS008=-0.1038*X_008+0.9994
#print(Y1_PBEAM_CS008)
#Y1_PBEAM_CS014=-0.1038*X_014+0.9994
#print(Y1_PBEAM_CS014)

X1_PBEAM_CS002=np.abs((PICO1_PLACS002_PBEAM0662-0.9994)/-0.1038)
print(f'equação linear - espessura 0.2 mm: {X1_PBEAM_CS002}')
X1_PBEAM_CS008=np.abs((PICO1_PLACS008_PBEAM0662-0.9994)/-0.1038)
print(f'equação linear - espessura 0.8 mm: {X1_PBEAM_CS008}')
X1_PBEAM_CS014=np.abs((PICO1_PLACS014_PBEAM0662-0.9994)/-0.1038)
print(f'equação linear - espessura 1.4 mm: {X1_PBEAM_CS014}')


################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9544

#Y2_PBEAM_CS002=-0.061*np.log(X_002)+0.886
#print(Y2_PBEAM_CS002)
#Y2_PBEAM_CS008=-0.061*np.log(X_008)+0.886
#print(Y2_PBEAM_CS008)
#Y2_PBEAM_CS014=-0.061*np.log(X_014)+0.886
#print(Y2_PBEAM_CS014)

# NÃO TEM VALORES PARA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

# Y3_PBEAM_CS002 = 0.0076*X_002**2-0.1161*X_002+1.0025
# print(Y3_PBEAM_CS002)
# Y3_PBEAM_CS008 = 0.0076*X_008**2-0.1161*X_008+1.0025
# print(Y3_PBEAM_CS008)
# Y3_PBEAM_CS014 = 0.0076*X_014**2-0.2281*X_014+1.0025
# print(Y3_PBEAM_CS014)

x3_PBEAM_AM1 = 7.638157894736842
print(f'equação quadrática - primeira raiz:{x3_PBEAM_AM1}')
x3_PBEAM_AM2 = 0
print(f'equação quadrática - segunda raiz:{x3_PBEAM_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################


# R**2 = 1


#Y4_PBEAM_CS002=1.0018*np.exp(-0.113*X_002)
#print(Y4_PBEAM_CS002)
#Y4_PBEAM_CS008=1.0018*np.exp(-0.113*X_008)
#print(Y4_PBEAM_CS008)
#Y4_PBEAM_CS014=1.0018*np.exp(-0.113*X_014)
#print(Y4_PBEAM_CS014)

X4_PBEAM_AM002=(np.log(PICO1_PLAAM002_PBEAM00595/1.2755)/(-0.746))
print(f'equação exponencial - espessura 0.2 mm:{X4_PBEAM_AM002}')
X4_PBEAM_AM008=(np.log(PICO1_PLAAM008_PBEAM00595/1.2755)/(-0.746))
print(f'equação exponencial - espessura 0.8 mm:{X4_PBEAM_AM008}')
X4_PBEAM_AM014=(np.log(PICO1_PLAAM014_PBEAM00595/1.2755)/(-0.746))
print(f'equação exponencial - espessura 1.4 mm:{X4_PBEAM_AM014}')
# Out:
# equação linear - espessura 0.2 mm: 0.19099663524487812
# equação linear - espessura 0.8 mm: 0.8177337297805353
# equação linear - espessura 1.4 mm: 1.3915462613167597
# equação quadrática - primeira raiz:7.638157894736842
# equação quadrática - segunda raiz:0
# equação exponencial - espessura 0.2 mm:0.39631342214867604
# equação exponencial - espessura 0.8 mm:0.6073067630613972
# equação exponencial - espessura 1.4 mm:0.8188224648566202

# %%
#equação linear - espessura 0.2 mm: 0.19099663524487812
#equação linear - espessura 0.8 mm: 0.8177337297805353
#equação linear - espessura 1.4 mm: 1.3915462613167597
    
Y1_PBEAM_CS002=-0.1038*0.19099663524487812+0.9994
print(Y1_PBEAM_CS002)
Y1_PBEAM_CS008=-0.1038*0.8177337297805353+0.9994
print(Y1_PBEAM_CS008)
Y1_PBEAM_CS014=-0.1038*1.3915462613167597+0.9994
print(Y1_PBEAM_CS014)
# Out:
# 0.9795745492615816
# 0.9145192388487804
# 0.8549574980753203

# %%
### '(I/I0) (CS EXP)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N11 = len(x11)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals11 = y11 - (a11 * x11 + b11)


# Dados de exemplo
x11 = np.array([0.2, 0.8, 1.4])
#y11 = np.array([0.00327367, -0.0939783,  -0.13925964])
y11 = np.array([0.9795745492615816, 0.9145192388487804,  0.8549574980753203
])


#media de x
mean_x=np.mean(x11)

#media de y
mean_y=np.mean(y11)

# Variância de x
var_x = np.var(x11, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y11, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x11, y11, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a11 = cov_xy/var_x
print(a11)
b11 = mean_y - a11 * mean_x
print(b11)

# Desvio padrão de x e y
sd_x = np.std(x11, ddof=1)
print(sd_x)
sd_y = np.std(y11, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_11 = a11*sd_x/sd_y
print(f'Coeficiente de Pearson (R_11): {R_11}')
RR_11 = np.abs(R_11)
print(f'Coeficiente de Pearson (RR_11): {RR_11}')

# Resíduos
residuals11 = y11 - (a11 * x11 + b11)

# Número de observações
N11 = len(x11)

# Erro padrão residual (epsilon1)
epsilon1_11 = np.sqrt(np.sum(residuals11**2) / (N11 - 2))
print(epsilon1_11)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a11 = epsilon1_11 / (sd_x * np.sqrt(N11))
print(error_a11)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_11 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_11}")
MODabs_eps2eps2_11 = np.abs(eps2eps2_11)
print(f'valor absoluto de eps2eps2: {eps2eps2_11}')
NN11=(N11 / (N11 - 2))
print(f"NN: {NN11}")
epsilon2_11 = np.sqrt(NN11 * MODabs_eps2eps2_11)
print(f"epsilon2: {epsilon2_11}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb11=np.mean(x11**2)
print(bb11)
error_b11 = error_a11 * np.sqrt(bb11)
print(error_b11)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a11}')
print(f'Coeficiente linear (b): {b11}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_11}')
print(f'Erro padrão residual (epsilon2): {epsilon2_11}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a11}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b11}')
# Out:
# 0.3599999999999999
# 0.0038848673038716754
# -0.03738511535587839
# -0.1038475426552178
# 0.999428462852735
# 0.5999999999999999
# 0.062328703691571154
# Coeficiente de Pearson (R_11): -0.9996762631461046
# Coeficiente de Pearson (RR_11): 0.9996762631461046
# 0.0022427404138051893
# 0.002158077969388132
# eps2eps2: 2.5149422818561765e-06
# valor absoluto de eps2eps2: 2.5149422818561765e-06
# NN: 3.0
# epsilon2: 0.0027467848196698133
# 0.8799999999999999
# 0.0020244565837091674
# Coeficiente angular (a): -0.1038475426552178
# Coeficiente linear (b): 0.999428462852735
# Erro padrão residual (epsilon1): 0.0022427404138051893
# Erro padrão residual (epsilon2): 0.0027467848196698133
# Erro associado ao coeficiente angular (error_a): 0.002158077969388132
# Erro associado ao coeficiente linear (error_b): 0.0020244565837091674

# %%
# (I/I0) EXP - VALOR NORMAL (CS137 - PBEAM) (PICO 1 - 662 KEV)

################################################################################################################################


# [-0.00327367  0.0939783   0.13925964]


################################################################################################################################


# COEF A

a11=-0.1038475426552178

# COEF B

b11=0.999428462852735

# ERRO

erro_a11= 0.002158077969388132

erro_b11= 0.0020244565837091674

# %%
#equação exponencial - espessura 0.2 mm:0.39631342214867604
#equação exponencial - espessura 0.8 mm:0.6073067630613972
#equação exponencial - espessura 1.4 mm:0.8188224648566202

Y4_PBEAM_CS002=1.0018*np.exp(-0.113*0.39631342214867604)
print(Y4_PBEAM_CS002)
Y4_PBEAM_CS008=1.0018*np.exp(-0.113*0.6073067630613972)
print(Y4_PBEAM_CS008)
Y4_PBEAM_CS014=1.0018*np.exp(-0.113*0.8188224648566202)
print(Y4_PBEAM_CS014)
# Out:
# 0.9579257255467872
# 0.9353567400653418
# 0.9132655771817724

# %%
### '(I/I0) (CS-137 PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N12 = len(x12)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals12 = y12 - (a12 * x12 + b12)


# Dados de exemplo
x12 = np.array([0.2, 0.8, 1.4])
y12 = np.array([0.9579257255467872
, 0.9353567400653418,  0.9132655771817724])

#media de x
mean_x=np.mean(x12)

#media de y
mean_y=np.mean(y12)

# Variância de x
var_x = np.var(x12, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y12, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x12, y12, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a12 = cov_xy/var_x
print(a12)
b12 = mean_y - a12 * mean_x
print(b12)

# Desvio padrão de x e y
sd_x = np.std(x12, ddof=1)
print(sd_x)
sd_y = np.std(y12, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_12 = a12*sd_x/sd_y
print(f'Coeficiente de Pearson (R_12): {R_12}')
RR_12 = np.abs(R_12)
print(f'Coeficiente de Pearson (RR_12): {RR_12}')

# Resíduos
residuals12 = y12 - (a12 * x12 + b12)

# Número de observações
N12 = len(x12)

# Erro padrão residual (epsilon1)
epsilon1_12 = np.sqrt(np.sum(residuals12**2) / (N12 - 2))
print(epsilon1_12)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a12 = epsilon1_12 / (sd_x * np.sqrt(N12))
print(error_a12)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_12 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_12}")
MODabs_eps2eps2_12 = np.abs(eps2eps2_12)
print(f'valor absoluto de eps2eps2: {eps2eps2_12}')
NN12=(N12 / (N12 - 2))
print(f"NN: {NN12}")
epsilon2_12 = np.sqrt(NN12 * MODabs_eps2eps2_12)
print(f"epsilon2: {epsilon2_12}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb12=np.mean(x12**2)
print(bb12)
error_b12 = error_a12 * np.sqrt(bb12)
print(error_b12)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a12}')
print(f'Coeficiente linear (b): {b12}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_12}')
print(f'Erro padrão residual (epsilon2): {epsilon2_12}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a12}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b12}')
# Out:
# 0.3599999999999999
# 0.0004986512391992051
# -0.013398044509504457
# -0.037216790304179063
# 0.965289446507977
# 0.5999999999999999
# 0.022330500200380757
# Coeficiente de Pearson (R_12): -0.9999809221526835
# Coeficiente de Pearson (RR_12): 0.9999809221526835
# 0.00019507025872791912
# 0.00018770644397909014
# eps2eps2: 1.9026202920015972e-08
# valor absoluto de eps2eps2: 1.9026202920015972e-08
# NN: 3.0
# epsilon2: 0.00023891129893759299
# 0.8799999999999999
# 0.0001760842526119876
# Coeficiente angular (a): -0.037216790304179063
# Coeficiente linear (b): 0.965289446507977
# Erro padrão residual (epsilon1): 0.00019507025872791912
# Erro padrão residual (epsilon2): 0.00023891129893759299
# Erro associado ao coeficiente angular (error_a): 0.00018770644397909014
# Erro associado ao coeficiente linear (error_b): 0.0001760842526119876

# %%
# (I/I0) EXP - VALOR NORMAL (CS137 - PBEAM) (PICO 1 - 662 KEV)

################################################################################################################################


# [-0.00327367  0.0939783   0.13925964]


################################################################################################################################


# COEF A

a12=-0.037216790304179063

# COEF B

b12=0.965289446507977

# ERRO

erro_a12= 0.00018770644397909014

erro_b12= 0.0001760842526119876

# %%
# LN (I/I0) PBEAM - VALOR 1 (CS137 - PBEAM) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 1

#YY1_PBEAM_CS002 = -0.1134*X_002 + 0.0018
#print(YY1_PBEAM_CS002)
#YY1_PBEAM_CS008 = -0.1134*X_008 + 0.0018
#print(YY1_PBEAM_CS008)
#YY1_PBEAM_CS014 = -0.1134*X_014 + 0.0018
#print(YY1_PBEAM_CS014) 

XX1_PBEAM_CS002 = np.abs((np.log(PICO1_PLACS002_PBEAM0662)-0.0018)/(-0.1134))
print(f'equação linear - espessura 0.2 mm:{XX1_PBEAM_CS002}')
XX1_PBEAM_CS008 = np.abs((np.log(PICO1_PLACS008_PBEAM0662)-0.0018)/(-0.1134))
print(f'equação linear - espessura 0.8 mm:{XX1_PBEAM_CS008}')
XX1_PBEAM_CS014 = np.abs((np.log(PICO1_PLACS014_PBEAM0662)-0.0184)/(-0.1134))
print(f'equação linear - espessura 1.4 mm:{XX1_PBEAM_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9459

# YY2_PBEAM_CS002=-0.066*np.log(X_002)-0.1218
# print(YY2_PBEAM_CS002)
# YY2_PBEAM_CS008=-0.066*np.log(X_008)-0.1218
# print(YY2_PBEAM_CS008)
# YY2_PBEAM_CS014=-0.066*np.log(X_014)-0.1218
# print(YY2_PBEAM_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

# YY3_PBEAM_CS002 = 0.0019*X_002**2-0.1164*X_002+0.0026
# print(YY3_PBEAM_CS002)
# YY3_PBEAM_CS008 = 0.0019*X_008**2-0.1164*X_008+0.0026
# print(YY3_PBEAM_CS008)
# YY3_PBEAM_CS014 = 0.0019*X_014**2-0.1164*X_014+0.0026
# print(YY3_PBEAM_CS014)

xx3_PBEAM_CS1 = 61.24081297496592
print(f'equação quadrática - primeira raiz:{xx3_PBEAM_CS1}')
xx3_PBEAM_CS2 = 0.022344919770921873
print(f'equação quadrática - segunda raiz:{xx3_PBEAM_CS2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #
# Out:
# equação linear - espessura 0.2 mm:0.1978565695525487
# equação linear - espessura 0.8 mm:0.8038516209199968
# equação linear - espessura 1.4 mm:1.5441227613260944
# equação quadrática - primeira raiz:61.24081297496592
# equação quadrática - segunda raiz:0.022344919770921873
# 'EQUAÇÃO EXPONENCIAL'

# %%
# equação linear - espessura 0.2 mm:0.1978565695525487
# equação linear - espessura 0.8 mm:0.8038516209199968
# equação linear - espessura 1.4 mm:1.5441227613260944

YY1_PBEAM_CS002 = -0.1134*0.1978565695525487 + 0.0018
print(YY1_PBEAM_CS002)
YY1_PBEAM_CS008 = -0.1134*0.8038516209199968 + 0.0018
print(YY1_PBEAM_CS008)
YY1_PBEAM_CS014 = -0.1134*1.5441227613260944 + 0.0018
print(YY1_PBEAM_CS014)
# Out:
# -0.020636934987259024
# -0.08935677381232765
# -0.1733035211343791

# %%
### 'LN (I/I0) (CS PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N13 = len(x13)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals13 = y13 - (a13 * x13 + b13)


# Dados de exemplo
x13 = np.array([0.2, 0.8, 1.4])
y13 = np.array([-0.020636934987259024
, -0.08935677381232765
,  -0.17330352113437910])

#media de x
mean_x=np.mean(x13)

#media de y
mean_y=np.mean(y13)

# Variância de x
var_x = np.var(x13, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y13, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x13, y13, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a13 = cov_xy/var_x
print(a13)
b13 = mean_y - a13 * mean_x
print(b13)

# Desvio padrão de x e y
sd_x = np.std(x13, ddof=1)
print(sd_x)
sd_y = np.std(y13, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_13 = a13*sd_x/sd_y
print(f'Coeficiente de Pearson (R_13): {R_13}')
RR_13 = np.abs(R_13)
print(f'Coeficiente de Pearson (RR_13): {RR_13}')

# Resíduos
residuals13 = y13 - (a13 * x13 + b13)

# Número de observações
N13 = len(x13)

# Erro padrão residual (epsilon1)
epsilon1_13 = np.sqrt(np.sum(residuals13**2) / (N13 - 2))
print(epsilon1_13)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a13 = epsilon1_13 / (sd_x * np.sqrt(N13))
print(error_a13)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_13 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_13}")
MODabs_eps2eps2_13 = np.abs(eps2eps2_13)
print(f'valor absoluto de eps2eps2: {eps2eps2_13}')
NN13=(N13 / (N13 - 2))
print(f"NN: {NN13}")
epsilon2_13 = np.sqrt(NN13 * MODabs_eps2eps2_13)
print(f"epsilon2: {epsilon2_13}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb13=np.mean(x13**2)
print(bb13)
error_b13 = error_a13 * np.sqrt(bb13)
print(error_b13)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a13}')
print(f'Coeficiente linear (b): {b13}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_13}')
print(f'Erro padrão residual (epsilon2): {epsilon2_13}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a13}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b13}')
# Out:
# 0.3599999999999999
# 0.005846093193318634
# -0.045799975844136025
# -0.1272221551226001
# 0.007345314120091484
# 0.5999999999999999
# 0.0764597488442032
# Coeficiente de Pearson (R_13): -0.9983461131830184
# Coeficiente de Pearson (RR_13): 0.9983461131830184
# 0.006216359362942919
# 0.005981694585957577
# eps2eps2: 1.932156186462263e-05
# valor absoluto de eps2eps2: 1.932156186462263e-05
# NN: 3.0
# epsilon2: 0.0076134542484911465
# 0.8799999999999999
# 0.00561132691128518
# Coeficiente angular (a): -0.1272221551226001
# Coeficiente linear (b): 0.007345314120091484
# Erro padrão residual (epsilon1): 0.006216359362942919
# Erro padrão residual (epsilon2): 0.0076134542484911465
# Erro associado ao coeficiente angular (error_a): 0.005981694585957577
# Erro associado ao coeficiente linear (error_b): 0.00561132691128518

# %%
### 'LN(I/I0) (CS-137 PBEAM)' ###

# LN(I/I0) PBEAM - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a13=0.005981694585957577

# COEF B

b13= 0.007345314120091484

# ERRO

erro_a13= 0.020415991608631685

erro_b13= 0.00561132691128518

# %%
# CONTAGEM PBEAM - VALOR 1 (CS137 - PBEAM) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.9994

#YYY1_PBEAM_CS002=-457275*X_002+4*10**6
#print(YYY1_PBEAM_CS002)
#YYY1_PBEAM_CS008=-457275*X_008+4*10**6
#print(YYY1_PBEAM_CS008)
#YYY1_PBEAM_CS014=-457275*X_014+4*10**6
#print(YYY1_PBEAM_CS014)

XXX1_PBEAM_CS002=np.abs((CONTPBEAM002_CS137_0662-4*10**6)/-457275)
print(f'equação linear - espessura 0.2 mm:{XXX1_PBEAM_CS002}')
XXX1_PBEAM_CS008=np.abs((CONTPBEAM008_CS137_0662-4*10**6)/-457275)
print(f'equação linear - espessura 0.8 mm:{XXX1_PBEAM_CS008}')
XXX1_PBEAM_CS014=np.abs((CONTPBEAM014_CS137_0662-4*10**6)/-457275)
print(f'equação linear - espessura 1.4 mm:{XXX1_PBEAM_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9544

#YYY2_PBEAM_CS002=-3*10**5*np.log(X_002)+4*10**6
#print(YYY2_PBEAM_CS002)
#YYY2_PBEAM_CS008=-3*10**5*np.log(X_008)+4*10**6
#print(YYY2_PBEAM_CS008)
#YYY2_PBEAM_CS014=-3*10**5*np.log(X_014)+4*10**6
#print(YYY2_PBEAM_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#YYY3_PBEAM_CS002 = 33597*X_002**2-511031*X_002+4*10**6
#print(YYY3_PBEAM_CS002)
#YYY3_PBEAM_CS008 = 33597*X_008**2-511031*X_002+4*10**6
#print(YYY3_PBEAM_CS008)
#YYY3_PBEAM_CS014 = 33597*X_014**2-511031*X_002+4*10**6
#print(YYY3_PBEAM_CS014)

xx3_PBEAM_CS1 = 0
print(f'equação quadrática - primeira raiz:{xx3_PBEAM_CS1}')
xx3_PBEAM_CS2 = 7.605307021460249
print(f'equação quadrática - segunda raiz:{xx3_PBEAM_CS2}')

################################################################################################################################


"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 1

#YYY4_PBEAM_CS002=4*10**6*np.exp(-0.113*X_002)
#print(YYY4_PBEAM_CS002)
#YYY4_PBEAM_CS008=4*10**6*np.exp(-0.113*X_008)
#print(YYY4_PBEAM_CS008)
#YYY4_PBEAM_CS014=4*10**6*np.exp(-0.113*X_014)
#print(YYY4_PBEAM_CS014)

XXX4_PBEAM_CS002=np.abs(np.log(CONTPBEAM002_CS137_0662/4*10**6)/-0.113)
print(f'equação exponencial - espessura 0.2 mm:{XXX4_PBEAM_CS002}')
XXX4_PBEAM_CS008=np.abs(np.log(CONTPBEAM008_CS137_0662/4*10**6)/-0.113)
print(f'equação exponencial - espessura 0.8 mm:{XXX4_PBEAM_CS008}')
XXX4_PBEAM_CS014=np.abs(np.log(CONTPBEAM014_CS137_0662/4*10**6)/-0.113)
print(f'equação exponencial - espessura 1.4 mm:{XXX4_PBEAM_CS014}')
# Out:
# equação linear - espessura 0.2 mm:0.685342518178339
# equação linear - espessura 0.8 mm:0.05889235142966486
# equação linear - espessura 1.4 mm:0.5146574818216609
# equação quadrática - primeira raiz:0
# equação quadrática - segunda raiz:7.605307021460249
# equação exponencial - espessura 0.2 mm:245.18983090871652
# equação exponencial - espessura 0.8 mm:244.581690742123
# equação exponencial - espessura 1.4 mm:243.98570182776854

# %%
# equação linear - espessura 0.2 mm:0.685342518178339
# equação linear - espessura 0.8 mm:0.05889235142966486
# equação linear - espessura 1.4 mm:0.5146574818216609

YYY1_PBEAM_CS002=-457275*0.685342518178339+4*10**6
print(YYY1_PBEAM_CS002)
YYY1_PBEAM_CS008=-457275*0.05889235142966486+4*10**6
print(YYY1_PBEAM_CS008)
YYY1_PBEAM_CS014=-457275*0.5146574818216609+4*10**6
print(YYY1_PBEAM_CS014)
# Out:
# 3686610.0
# 3973070.0
# 3764660.0

# %%
### 'CONTAGEM (CS PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N14 = len(x14)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals14 = y14 - (a14 * x14 + b14)


# Dados de exemplo
x14 = np.array([0.2, 0.8, 1.4])
y14 = np.array([3686610.0, 3973070.0,  3764660.0])

#media de x
mean_x=np.mean(x14)

#media de y
mean_y=np.mean(y14)

# Variância de x
var_x = np.var(x14, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y14, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x14, y14, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a14 = cov_xy/var_x
print(a14)
b14 = mean_y - a14 * mean_x
print(b14)

# Desvio padrão de x e y
sd_x = np.std(x14, ddof=1)
print(sd_x)
sd_y = np.std(y14, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_14 = a14*sd_x/sd_y
print(f'Coeficiente de Pearson (R_14): {R_14}')
RR_14 = np.abs(R_14)
print(f'Coeficiente de Pearson (RR_14): {RR_14}')

# Resíduos
residuals14 = y14 - (a14 * x14 + b14)

# Número de observações
N14 = len(x14)

# Erro padrão residual (epsilon1)
epsilon1_14 = np.sqrt(np.sum(residuals14**2) / (N14 - 2))
print(epsilon1_14)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a14 = epsilon1_14 / (sd_x * np.sqrt(N14))
print(error_a14)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_14 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_14}")
MODabs_eps2eps2_14 = np.abs(eps2eps2_14)
print(f'valor absoluto de eps2eps2: {eps2eps2_14}')
NN14=(N14 / (N14 - 2))
print(f"NN: {NN14}")
epsilon2_14 = np.sqrt(NN14 * MODabs_eps2eps2_14)
print(f"epsilon2: {epsilon2_14}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb14=np.mean(x14**2)
print(bb14)
error_b14 = error_a14 * np.sqrt(bb14)
print(error_b14)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a14}')
print(f'Coeficiente linear (b): {b14}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_14}')
print(f'Erro padrão residual (epsilon2): {epsilon2_14}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a14}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b14}')
# Out:
# 0.3599999999999999
# 21930977033.333332
# 23414.999999999996
# 65041.66666666668
# 3756080.0
# 0.5999999999999999
# 148091.11058174062
# Coeficiente de Pearson (R_14): 0.2635202062210189
# Coeficiente de Pearson (RR_14): 0.2635202062210189
# 202029.83150185188
# 194403.29600321493
# eps2eps2: 20408026408.333332
# valor absoluto de eps2eps2: 20408026408.333332
# NN: 3.0
# epsilon2: 247435.0
# 0.8799999999999999
# 182366.45666701967
# Coeficiente angular (a): 65041.66666666668
# Coeficiente linear (b): 3756080.0
# Erro padrão residual (epsilon1): 202029.83150185188
# Erro padrão residual (epsilon2): 247435.0
# Erro associado ao coeficiente angular (error_a): 194403.29600321493
# Erro associado ao coeficiente linear (error_b): 182366.45666701967

# %%
### 'CONTAGEM (CS-137 EXP)' ###

# CONTAGEM EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a14=65041.66666666668

# COEF B

b14=3756080.0

# ERRO

erro_a14= 194403.29600321493

erro_b14= 182366.45666701967

# %%
#equação exponencial - espessura 0.2 mm:245.18983090871652
#equação exponencial - espessura 0.8 mm:244.581690742123
#equação exponencial - espessura 1.4 mm:243.98570182776854

abcYYY4_PBEAM_CS002=4*10**6*np.exp(-0.113*X_002)
print(abcYYY4_PBEAM_CS002)
abcYYY4_PBEAM_CS008=4*10**6*np.exp(-0.113*X_008)
print(abcYYY4_PBEAM_CS008)
abcYYY4_PBEAM_CS014=4*10**6*np.exp(-0.113*X_014)
print(abcYYY4_PBEAM_CS014)


YYY4_PBEAM_CS002=4*10**6*np.exp(-0.113*245.18983090871652)
print(YYY4_PBEAM_CS002)
YYY4_PBEAM_CS008=4*10**6*np.exp(-0.113*244.581690742123)
print(YYY4_PBEAM_CS008)
YYY4_PBEAM_CS014=4*10**6*np.exp(-0.113*243.98570182776854)
print(YYY4_PBEAM_CS014)
# Out:
# 3910613.867832841
# 3654262.7436074675
# 3492767.3575137467
# 3.7093793976431497e-06
# 3.9732500937438625e-06
# 4.250051797506276e-06

# %%
### 'CONTAGEM (CS137 PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N15 = len(x15)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals15 = y15 - (a15 * x15 + b15)


# Dados de exemplo
x15 = np.array([0.2, 0.8, 1.4])
y15 = np.array([3.7093793976431497e-06, 3.9732500937438625e-06
,  4.250051797506276e-06])

#media de x
mean_x=np.mean(x15)

#media de y
mean_y=np.mean(y15)

# Variância de x
var_x = np.var(x15, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y15, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x15, y15, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a15 = cov_xy/var_x
print(a15)
b15 = mean_y - a15 * mean_x
print(b15)

# Desvio padrão de x e y
sd_x = np.std(x15, ddof=1)
print(sd_x)
sd_y = np.std(y15, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_15 = a15*sd_x/sd_y
print(f'Coeficiente de Pearson (R_15): {R_15}')
RR_15 = np.abs(R_15)
print(f'Coeficiente de Pearson (RR_15): {RR_15}')

# Resíduos
residuals15 = y15 - (a15 * x15 + b15)

# Número de observações
N15 = len(x15)

# Erro padrão residual (epsilon1)
epsilon1_15 = np.sqrt(np.sum(residuals15**2) / (N15 - 2))
print(epsilon1_15)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a15 = epsilon1_15 / (sd_x * np.sqrt(N15))
print(error_a15)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_15 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_15}")
MODabs_eps2eps2_15 = np.abs(eps2eps2_15)
print(f'valor absoluto de eps2eps2: {eps2eps2_15}')
NN15=(N15 / (N15 - 2))
print(f"NN: {NN15}")
epsilon2_15 = np.sqrt(NN15 * MODabs_eps2eps2_15)
print(f"epsilon2: {epsilon2_15}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb15=np.mean(x15**2)
print(bb15)
error_b15 = error_a15 * np.sqrt(bb15)
print(error_b15)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a15}')
print(f'Coeficiente linear (b): {b15}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_15}')
print(f'Erro padrão residual (epsilon2): {epsilon2_15}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a15}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b15}')
# Out:
# 0.3599999999999999
# 7.309559524003377e-14
# 1.62201719958938e-07
# 4.5056033321927234e-07
# 3.6171121630556787e-06
# 0.5999999999999999
# 2.7036197077258065e-07
# Coeficiente de Pearson (R_15): 0.9999046802294581
# Coeficiente de Pearson (RR_15): 0.9999046802294581
# 5.279061771864428e-09
# 5.079779558424318e-09
# eps2eps2: 1.393424659557436e-17
# valor absoluto de eps2eps2: 1.393424659557436e-17
# NN: 3.0
# epsilon2: 6.465503830848999e-09
# 0.8799999999999999
# 4.765255619452464e-09
# Coeficiente angular (a): 4.5056033321927234e-07
# Coeficiente linear (b): 3.6171121630556787e-06
# Erro padrão residual (epsilon1): 5.279061771864428e-09
# Erro padrão residual (epsilon2): 6.465503830848999e-09
# Erro associado ao coeficiente angular (error_a): 5.079779558424318e-09
# Erro associado ao coeficiente linear (error_b): 4.765255619452464e-09

# %%
### 'CONTAGEM (CS-137 EXP)' ###

# CONTAGEM EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a15=4.5056033321927234e-07

# COEF B

b15=3.6171121630556787e-06

# ERRO

erro_a15= 5.079779558424318e-09

erro_b15= 4.765255619452464e-09

# %%
# I/I0 PBEAM - VALOR 1 (AM241 - PBEAM) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.998

#YYY01_ISO_CS002=-0.2138*X_002+0.9885
#print(YYY01_ISO_CS002)
#YYY01_ISO_CS008=-0.2138*X_008+0.9885
#print(YYY01_ISO_CS008)
#YYY01_ISO_CS014=-0.2138*X_014+0.9885
#print(YYY01_ISO_CS014)

X1_PBEAM_CS002=np.abs((PICO1_PLACS002_PBEAM0662-0.9885)/(-0.2138))
print(f'equação linear - espessura 0.2 mm: {X1_PBEAM_CS002}')
X1_PBEAM_CS008=np.abs((PICO1_PLACS008_PBEAM0662-0.9885)/(-0.2138))
print(f'equação linear - espessura 0.8 mm: {X1_PBEAM_CS008}')
X1_PBEAM_CS014=np.abs((PICO1_PLACS014_PBEAM0662-0.9885)/(-0.2138))
print(f'equação linear - espessura 1.4 mm: {X1_PBEAM_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9621

# Y2_PBEAM_CS002=-0.126*np.log(X_002)+0.7547
# print(Y2_PBEAM_CS002)
# Y2_PBEAM_CS008=-0.126*np.log(X_008)+0.7547
# print(Y2_PBEAM_CS008)
# Y2_PBEAM_CS014=-0.126*np.log(X_014)+0.7547
# print(Y2_PBEAM_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#Y3_PBEAM_AM002 = 0.0276*X_002**2-0.2579*X_002+0.9995
#print(Y3_AM002)
#Y3_PBEAM_AM008 = 0.0276*X_002**2-0.2579*X_008+0.9995
#print(Y3_PBEAM_AM008)
#Y3_PBEAM_AM014 = 0.0276*X_002**2-0.2579*X_014+0.9995
#print(Y3_PBEAM_AM014)

x3_EXP_AM1 = 0
print(f'equação quadrática - primeira raiz:{x3_EXP_AM1}')
x3_EXP_AM2 = 4.672101449275362
print(f'equação quadrática - segunda raiz:{x3_EXP_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 1

#Y4_PBEAM_AM002=1.0003*np.exp(-0.263*X_002)
#print(Y4_PBEAM_AM002)
#Y4_PBEAM_AM008=1.0003*np.exp(-0.263*X_008)
#print(Y4_PBEAM_AM008)
#Y4_PBEAM_AM014=1.0003*np.exp(-0.263*X_014)
#print(Y4_PBEAM_AM014)

X4_PBEAM_AM002=np.abs(np.log(PICO1_PLAAM002_PBEAM00595/1.0003)/(-0.263))
print(f'equação exponencial - espessura 0.2 mm:{X4_PBEAM_AM002}')
X4_PBEAM_AM008=np.abs(np.log(PICO1_PLAAM008_PBEAM00595/1.0003)/(-0.263))
print(f'equação exponencial - espessura 0.8 mm:{X4_PBEAM_AM008}')
X4_PBEAM_AM014=np.abs(np.log(PICO1_PLAAM014_PBEAM00595/1.0003)/(-0.263))
print(f'equação exponencial - espessura 1.4 mm:{X4_PBEAM_AM014}')
# Out:
# equação linear - espessura 0.2 mm: 0.04174672936584864
# equação linear - espessura 0.8 mm: 0.34602788190467565
# equação linear - espessura 1.4 mm: 0.6246141343530391
# equação quadrática - primeira raiz:0
# equação quadrática - segunda raiz:4.672101449275362
# equação exponencial - espessura 0.2 mm:0.2000437617193202
# equação exponencial - espessura 0.8 mm:0.7985267743462784
# equação exponencial - espessura 1.4 mm:1.3984914646095346

# %%
#equação linear - espessura 0.2 mm: 0.18459707483937748
#equação linear - espessura 0.8 mm: 0.8310699149133361
#equação linear - espessura 1.4 mm: 1.3846536877619247

Y1_PBEAM_AM002=-0.2138*X_002+0.9885
print(Y1_PBEAM_AM002)
Y1_PBEAM_AM008=-0.2138*X_008+0.9885
print(Y1_PBEAM_AM008)
Y1_PBEAM_AM014=-0.2138*X_014+0.9885
print(Y1_PBEAM_AM014)

abcY1_PBEAM_AM002=-0.2138*0.18459707483937748+0.9885
print(abcY1_PBEAM_AM002)
abcY1_PBEAM_AM008=-0.2138*0.8310699149133361+0.9885
print(abcY1_PBEAM_AM008)
abcY1_PBEAM_AM014=-0.2138*1.3846536877619247+0.9885
print(abcY1_PBEAM_AM014)
# Out:
# 0.94574
# 0.8174600000000001
# 0.73194
# 0.9490331453993411
# 0.8108172521915288
# 0.6924610415565006

# %%
### '(I/I0) (AM-241 PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N16 = len(x16)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals16 = y16 - (a16 * x16 + b16)


# Dados de exemplo
x16 = np.array([0.2, 0.8, 1.4])
y16 = np.array([0.9490331453993411, 0.8108172521915288,  0.6924610415565006
])

#media de x
mean_x=np.mean(x16)

#media de y
mean_y=np.mean(y16)

# Variância de x
var_x = np.var(x16, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y16, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x16, y16, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a16 = cov_xy/var_x
print(a16)
b16 = mean_y - a16 * mean_x
print(b16)

# Desvio padrão de x e y
sd_x = np.std(x16, ddof=1)
print(sd_x)
sd_y = np.std(y16, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_16 = a16*sd_x/sd_y
print(f'Coeficiente de Pearson (R_16): {R_16}')
RR_16 = np.abs(R_16)
print(f'Coeficiente de Pearson (RR_16): {RR_16}')

# Resíduos
residuals16 = y16 - (a16 * x16 + b16)

# Número de observações
N16 = len(x16)

# Erro padrão residual (epsilon1)
epsilon1_16 = np.sqrt(np.sum(residuals16**2) / (N16 - 2))
print(epsilon1_16)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a16 = epsilon1_16 / (sd_x * np.sqrt(N16))
print(error_a16)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_16 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_16}")
MODabs_eps2eps2_16 = np.abs(eps2eps2_16)
print(f'valor absoluto de eps2eps2: {eps2eps2_16}')
NN16=(N16 / (N16 - 2))
print(f"NN: {NN16}")
epsilon2_16 = np.sqrt(NN16 * MODabs_eps2eps2_16)
print(f"epsilon2: {epsilon2_16}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb16=np.mean(x16**2)
print(bb16)
error_b16 = error_a16 * np.sqrt(bb16)
print(error_b16)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a16}')
print(f'Coeficiente linear (b): {b16}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_16}')
print(f'Erro padrão residual (epsilon2): {epsilon2_16}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a16}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b16}')
# Out:
# 0.3599999999999999
# 0.016490178366909653
# -0.07697163115285216
# -0.21381008653570052
# 0.9884852156110172
# 0.5999999999999999
# 0.1284140894407995
# Coeficiente de Pearson (R_16): -0.9990029324668597
# Coeficiente de Pearson (RR_16): 0.9990029324668597
# 0.0081076814594941
# 0.00780162012190443
# eps2eps2: 3.286724932431012e-05
# valor absoluto de eps2eps2: 3.286724932431012e-05
# NN: 3.0
# epsilon2: 0.00992984128639176
# 0.8799999999999999
# 0.0073185683943872235
# Coeficiente angular (a): -0.21381008653570052
# Coeficiente linear (b): 0.9884852156110172
# Erro padrão residual (epsilon1): 0.0081076814594941
# Erro padrão residual (epsilon2): 0.00992984128639176
# Erro associado ao coeficiente angular (error_a): 0.00780162012190443
# Erro associado ao coeficiente linear (error_b): 0.0073185683943872235

# %%
### '(I/I0) (AM-241 PBEAM)' ###

# (I/I0) PBEAM - VALOR NORMAL (AM-241 - PBEAM) (PICO 1 - 59.5 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1=-0.21381008653570052

# COEF B

b1=0.9884852156110172

# ERRO

erro_a1= 0.00780162012190443

erro_b1= 0.0073185683943872235

# %%
#equação exponencial - espessura 0.2 mm:0.2000437617193202
#equação exponencial - espessura 0.8 mm:0.7985267743462784
#equação exponencial - espessura 1.4 mm:1.3984914646095346

Y4_PBEAM_AM002=1.0003*np.exp(-0.263*X_002)
print(Y4_PBEAM_AM002)
Y4_PBEAM_AM008=1.0003*np.exp(-0.263*X_008)
print(Y4_PBEAM_AM008)
Y4_PBEAM_AM014=1.0003*np.exp(-0.263*X_014)
print(Y4_PBEAM_AM014)

abcY4_PBEAM_AM002=1.0003*np.exp(-0.263*0.2000437617193202)
print(abcY4_PBEAM_AM002)
abcY4_PBEAM_AM008=1.0003*np.exp(-0.263*0.7985267743462784)
print(abcY4_PBEAM_AM008)
abcY4_PBEAM_AM014=1.0003*np.exp(-0.263*1.3984914646095346)
print(Y4_PBEAM_AM014)
# Out:
# 0.9490440681999195
# 0.8105031551330263
# 0.7295699376199083
# 0.9490331453993411
# 0.8108172521915288
# 0.7295699376199083

# %%
### 'LN(I/I0) (CS ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N17 = len(x17)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals17 = y17 - (a17 * x17 + b17)


# Dados de exemplo
x17 = np.array([0.2, 0.8, 1.4])
y17 = np.array([0.9490331453993411, 0.8108172521915288
, 0.7295699376199083])

#media de x
mean_x=np.mean(x17)

#media de y
mean_y=np.mean(y17)

# Variância de x
var_x = np.var(x17, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y17, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x17, y17, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a17 = cov_xy/var_x
print(a17)
b17 = mean_y - a17 * mean_x
print(b17)

# Desvio padrão de x e y
sd_x = np.std(x17, ddof=1)
print(sd_x)
sd_y = np.std(y17, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_17 = a17*sd_x/sd_y
print(f'Coeficiente de Pearson (R_17): {R_17}')
RR_17 = np.abs(R_17)
print(f'Coeficiente de Pearson (RR_17): {RR_17}')

# Resíduos
residuals17 = y17 - (a17 * x17 + b17)

# Número de observações
N17 = len(x17)

# Erro padrão residual (epsilon1)
epsilon1_17 = np.sqrt(np.sum(residuals17**2) / (N17 - 2))
print(epsilon1_17)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a17= epsilon1_17 / (sd_x * np.sqrt(N17))
print(error_a17)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_17 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_17}")
MODabs_eps2eps2_17 = np.abs(eps2eps2_17)
print(f'valor absoluto de eps2eps2: {eps2eps2_17}')
NN17=(N17 / (N17 - 2))
print(f"NN: {NN17}")
epsilon2_17 = np.sqrt(NN17 * MODabs_eps2eps2_17)
print(f"epsilon2: {epsilon2_17}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb17=np.mean(x17**2)
print(bb17)
error_b17 = error_a17 * np.sqrt(bb17)
print(error_b17)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a17}')
print(f'Coeficiente linear (b): {b17}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_17}')
print(f'Erro padrão residual (epsilon2): {epsilon2_17}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a17}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b17}')
# Out:
# 0.3599999999999999
# 0.012311476471528627
# -0.06583896233382985
# -0.18288600648286077
# 0.9761155835898814
# 0.5999999999999999
# 0.11095709293023419
# Coeficiente de Pearson (R_17): -0.9889552888584753
# Coeficiente de Pearson (RR_17): 0.9889552888584753
# 0.023257324838381478
# 0.022379371260116868
# eps2eps2: 0.0002704515793189935
# valor absoluto de eps2eps2: 0.0002704515793189935
# NN: 3.0
# epsilon2: 0.028484289318095695
# 0.8799999999999999
# 0.020993711130678334
# Coeficiente angular (a): -0.18288600648286077
# Coeficiente linear (b): 0.9761155835898814
# Erro padrão residual (epsilon1): 0.023257324838381478
# Erro padrão residual (epsilon2): 0.028484289318095695
# Erro associado ao coeficiente angular (error_a): 0.022379371260116868
# Erro associado ao coeficiente linear (error_b): 0.020993711130678334

# %%
# ln(I/I0) PBEAM - VALOR 1 (AM241 - PBEAM) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 1

#YY1_PBEAM_AM002=-0.2627*X_002+0.0003
#print(YY1_PBEAM_AM002)
#YY1_PBEAM_AM008=-0.2627*X_008+0.0003
#print(YY1_PBEAM_AM008)
#YY1_PBEAM_AM014=-0.2627*X_014+0.0003
#print(YY1_PBEAM_AM014)

XX1_PBEAM_AM002 = np.abs((np.log(PICO1_PLAAM002_PBEAM00595)-0.003)/(-0.2627))
print(f'equação linear - espessura 0.2 mm:{XX1_PBEAM_AM002}')
XX1_PBEAM_AM008 = np.abs((np.log(PICO1_PLAAM008_PBEAM00595)-0.003)/(-0.2627))
print(f'equação linear - espessura 0.8 mm:{XX1_PBEAM_AM008}')
XX1_PBEAM_AM014 = np.abs((np.log(PICO1_PLAAM014_PBEAM00595)-0.003)/(-0.2627))
print(f'equação linear - espessura 1.4 mm:{XX1_PBEAM_AM014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9429

# YY2_PBEAM_AM002=-0.153*np.log(X_002)-0.286
# print(YY2_PBEAM_AM002)
# YY2_PBEAM_AM008=-0.153*np.log(X_008)-0.286
# print(YY2_PBEAM_CS008)
# YY2_PBEAM_AM014=-0.153*np.log(X_014)-0.286
# print(YY2_PBEAM_AM014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#YY3_PBEAM_AM002 = -0.0005*X_002**2-0.2618*X_002+7*10**-5
#print(YY3_PBEAM_AM002)
#YY3_PBEAM_AM008 = -0.0005*X_008**2-0.2618*X_008-7*10**-5
#print(YY3_PBEAM_AM008)
#YY3_PBEAM_AM014 = -0.0005*X_014**2-0.2618*X_014+7*10**-5
#print(YY3_PBEAM_AM014)

xx3_EXP_AM1 = -523.6002673795425
print(f'equação quadrática - primeira raiz:{xx3_EXP_AM1}')
xx3_EXP_AM2 = 0.00026737954261779606
print(f'equação quadrática - segunda raiz:{xx3_EXP_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #
# Out:
# equação linear - espessura 0.2 mm:0.21055026388726034
# equação linear - espessura 0.8 mm:0.8097167363687601
# equação linear - espessura 1.4 mm:1.4103665785432422
# equação quadrática - primeira raiz:-523.6002673795425
# equação quadrática - segunda raiz:0.00026737954261779606
# 'EQUAÇÃO EXPONENCIAL'

# %%
#equação linear - espessura 0.2 mm:0.21055026388726034
#equação linear - espessura 0.8 mm:0.8097167363687601
#equação linear - espessura 1.4 mm:1.4103665785432422

YY1_PBEAM_AM002=-0.2627*X_002+0.0003
print(YY1_PBEAM_AM002)
YY1_PBEAM_AM008=-0.2627*X_008+0.0003
print(YY1_PBEAM_AM008)
YY1_PBEAM_AM014=-0.2627*X_014+0.0003
print(YY1_PBEAM_AM014)

ABCYY1_PBEAM_AM002=-0.2627*0.21055026388726034+0.0003
print(ABCYY1_PBEAM_AM002)
ABCYY1_PBEAM_AM008=-0.2627*0.8097167363687601+0.0003
print(ABCYY1_PBEAM_AM008)
ABCYY1_PBEAM_AM014=-0.2627*1.4103665785432422+0.0003
print(ABCYY1_PBEAM_AM014)
# Out:
# -0.05224
# -0.20986000000000002
# -0.31493999999999994
# -0.05501155432318328
# -0.21241258664407325
# -0.3702033001833097

# %%
### LN(I/I0) (AM241 PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N18 = len(x18)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals18 = y18 - (a18 * x18 + b18)


# Dados de exemplo
x18 = np.array([0.2, 0.8, 1.4])
y18 = np.array([-0.05501155432318328, -0.21241258664407325,  -0.3702033001833097])

#media de x
mean_x=np.mean(x18)

#media de y
mean_y=np.mean(y18)

# Variância de x
var_x = np.var(x18, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y18, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x18, y18, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a18 = cov_xy/var_x
print(a18)
b18 = mean_y - a18 * mean_x
print(b18)

# Desvio padrão de x e y
sd_x = np.std(x18, ddof=1)
print(sd_x)
sd_y = np.std(y18, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_18 = a18*sd_x/sd_y
print(f'Coeficiente de Pearson (R_18): {R_18}')
RR_18 = np.abs(R_18)
print(f'Coeficiente de Pearson (RR_18): {RR_18}')

# Resíduos
residuals18 = y18 - (a18 * x18 + b18)

# Número de observações
N18 = len(x18)

# Erro padrão residual (epsilon1)
epsilon1_18 = np.sqrt(np.sum(residuals18**2) / (N18 - 2))
print(epsilon1_18)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a18 = epsilon1_18 / (sd_x * np.sqrt(N18))
print(error_a18)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_18 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_18}")
MODabs_eps2eps2_18 = np.abs(eps2eps2_18)
print(f'valor absoluto de eps2eps2: {eps2eps2_18}')
NN18=(N18 / (N18 - 2))
print(f"NN: {NN18}")
epsilon2_18 = np.sqrt(NN18 * MODabs_eps2eps2_18)
print(f"epsilon2: {epsilon2_18}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb18=np.mean(x18**2)
print(bb18)
error_b18 = error_a18 * np.sqrt(bb18)
print(error_b18)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a18}')
print(f'Coeficiente linear (b): {b18}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_18}')
print(f'Erro padrão residual (epsilon2): {epsilon2_18}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a18}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b18}')
# Out:
# 0.3599999999999999
# 0.024836471818876292
# -0.09455752375803791
# -0.26265978821677205
# -0.0024146498101044467
# 0.5999999999999999
# 0.15759591307796117
# Coeficiente de Pearson (R_18): -0.9999997452478482
# Coeficiente de Pearson (RR_18): 0.9999997452478482
# 0.00015908669121587503
# 0.00015308123999662057
# eps2eps2: 1.2654287662866581e-08
# valor absoluto de eps2eps2: 1.2654287662866581e-08
# NN: 3.0
# epsilon2: 0.00019484060918761197
# 0.8799999999999999
# 0.00014360293212269234
# Coeficiente angular (a): -0.26265978821677205
# Coeficiente linear (b): -0.0024146498101044467
# Erro padrão residual (epsilon1): 0.00015908669121587503
# Erro padrão residual (epsilon2): 0.00019484060918761197
# Erro associado ao coeficiente angular (error_a): 0.00015308123999662057
# Erro associado ao coeficiente linear (error_b): 0.00014360293212269234

# %%
### 'LN(I/I0) (AM-241)' ###

# LN(I/I0) PBEAM - VALOR NORMAL (AM241 - PBEAM) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1=-0.26265978821677205

# COEF B

b1=-0.0024146498101044467

# ERRO

erro_a1= 0.00015308123999662057


erro_b1= 0.00014360293212269234

# %%
# CONTAGEM PBEAM - VALOR 1 (AM241 - PBEAM) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.998

#YYY1_PBEAM_AM002=-2*10**6*X_002+8*10**6
#print(YYY1_PBEAM_AM002)
#YYY1_PBEAM_AM008=-2*10**6*X_008+8*10**6
#print(YYY1_PBEAM_AM008)
#YYY1_PBEAM_AM014=-2*10**6*X_014+8*10**6
#print(YYY1_PBEAM_AM014)

XXX1_PBEAM_AM002=np.abs((CONTPBEAM002_AM241_00595-8*10**6)/(-2*10**6))
print(f'equação linear - espessura 0.2 mm:{XXX1_PBEAM_AM002}')
XXX1_PBEAM_AM008=np.abs((CONTPBEAM008_AM241_00595-8*10**6)/(-2*10**6))
print(f'equação linear - espessura 0.8 mm:{XXX1_PBEAM_AM008}')
XXX1_PBEAM_AM014=np.abs((CONTPBEAM014_AM241_00595-8*10**6)/(-2*10**6))
print(f'equação linear - espessura 1.4 mm:{XXX1_PBEAM_AM014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9621

# YYY2_PBEAM_AM002=-1*10**6*np.log(X_002)+6*10**6
# print(YYY2_PBEAM_AM002)
# YY2Y_PBEAM_AM008=-1*10**6*np.log(X_008)+6*10**6
# print(YYY2_PBEAM_S008)
# YYY2_PBEAM_AM014=-1*10**6*np.log(X_014)+6*10**6
# print(YYY2_PBEAM_AM014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

# YY3_PBEAM_AM002 = 2222208*X_002**2-2*10**6*X_002+8*10**6
# print(YY3_PBEAM_CS002)
# YY3_PBEAM_AM008 = 2222208*X_002**2-2*10**6*X_008+8*10**6
# print(YY3_PBEAM_CS008)
# YY3_PBEAM_AM014 = 2222208*X_002**2-2*10**6*X_014+8*10**6
# print(YY3_PBEAM_CS014)

xxx3_EXP_AM1 = 0.45000288001843214
print(f'equação quadrática - primeira raiz:{xxx3_EXP_AM1}')
xxx3_EXP_AM2 = 0
print(f'equação quadrática - segunda raiz:{xxx3_EXP_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 1

#YYY4_AM002=8*10**6*np.exp(-0.263*X_002)
#print(YYY4_AM002)
#YYY4_AM008=8*10**6*np.exp(-0.263*X_008)
#print(YYY4_AM008)
#YYY4_AM014=8*10**6*np.exp(-0.263*X_014)
#print(YYY4_AM014)

XXX4_PBEAM_AM002 = np.abs((np.log(CONTPBEAM002_AM241_00595/8*10**6)/(-0.263)))
print(f'equação exponencial - espessura 0.2 mm:{XXX4_PBEAM_AM002}')
XXX4_PBEAM_AM008 = np.abs((np.log(CONTPBEAM008_AM241_00595/8*10**6)/(-0.263)))
print(f'equação exponencial - espessura 0.8 mm:{XXX4_PBEAM_AM008}')
XXX4_PBEAM_AM014 = np.abs((np.log(CONTPBEAM014_AM241_00595/8*10**6)/(-0.263)))
print(f'equação exponencial - espessura 1.4 mm:{XXX4_PBEAM_AM014}')
# Out:
# equação linear - espessura 0.2 mm:0.177285
# equação linear - espessura 0.8 mm:0.73402
# equação linear - espessura 1.4 mm:1.21076
# equação quadrática - primeira raiz:0.45000288001843214
# equação quadrática - segunda raiz:0
# equação exponencial - espessura 0.2 mm:104.88854622798614
# equação exponencial - espessura 0.8 mm:104.29006321535918
# equação exponencial - espessura 1.4 mm:103.69009852509593

# %%
#equação linear - espessura 0.2 mm:0.177285
#equação linear - espessura 0.8 mm:0.73402
#equação linear - espessura 1.4 mm:1.21076


YYY1_PBEAM_AM002=-2*10**6*X_002+8*10**6
print(YYY1_PBEAM_AM002)
YYY1_PBEAM_AM008=-2*10**6*X_008+8*10**6
print(YYY1_PBEAM_AM008)
YYY1_PBEAM_AM014=-2*10**6*X_014+8*10**6
print(YYY1_PBEAM_AM014)

ABCYYY1_PBEAM_AM002=-2*10**6*0.177285+8*10**6
print(ABCYYY1_PBEAM_AM002)
ABCYYY1_PBEAM_AM008=-2*10**6*0.73402+8*10**6
print(ABCYYY1_PBEAM_AM008)
ABCYYY1_PBEAM_AM014=-2*10**6*1.21076+8*10**6
print(ABCYYY1_PBEAM_AM014)
# Out:
# 7600000.0
# 6400000.0
# 5600000.0
# 7645430.0
# 6531960.0
# 5578480.0

# %%
### 'CONTAGEM - NORMAL (AM241 PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N19 = len(x19)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals19 = y19 - (a19 * x19 + b19)


# Dados de exemplo
x19 = np.array([0.2, 0.8, 1.4])
y19 = np.array([7645430.0, 6531960.0, 5578480.0])

#media de x
mean_x=np.mean(x19)

#media de y
mean_y=np.mean(y19)

# Variância de x
var_x = np.var(x19, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y19, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x19, y19, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a19 = cov_xy/var_x
print(a19)
b19 = mean_y - a19 * mean_x
print(b19)

# Desvio padrão de x e y
sd_x = np.std(x19, ddof=1)
print(sd_x)
sd_y = np.std(y19, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_19 = a19*sd_x/sd_y
print(f'Coeficiente de Pearson (R_19): {R_19}')
RR_19 = np.abs(R_19)
print(f'Coeficiente de Pearson (RR_19): {RR_19}')

# Resíduos
residuals19 = y19 - (a19 * x19 + b19)

# Número de observações
N19 = len(x19)

# Erro padrão residual (epsilon1)
epsilon1_19 = np.sqrt(np.sum(residuals19**2) / (N19 - 2))
print(epsilon1_19)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a19 = epsilon1_19 / (sd_x * np.sqrt(N19))
print(error_a19)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_19 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_19}")
MODabs_eps2eps2_19 = np.abs(eps2eps2_19)
print(f'valor absoluto de eps2eps2: {eps2eps2_19}')
NN19=(N19 / (N19 - 2))
print(f"NN: {NN19}")
epsilon2_19 = np.sqrt(NN19 * MODabs_eps2eps2_19)
print(f"epsilon2: {epsilon2_19}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb19=np.mean(x19**2)
print(bb19)
error_b19 = error_a19 * np.sqrt(bb19)
print(error_b19)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a19}')
print(f'Coeficiente linear (b): {b19}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_19}')
print(f'Erro padrão residual (epsilon2): {epsilon2_19}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a19}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b19}')

# %%
### 'CONTAGEM (CS-137 EXP)' ###

# CONTAGEM PBEAM - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a19=-1722458.3333333335

# COEF B

b19=7963256.666666667

# ERRO

erro_a19= 62850.00773446432

erro_b19= 58958.533356551176

# %%
#equação exponencial - espessura 0.2 mm:104.88854622798614

#equação exponencial - espessura 0.8 mm:104.29006321535918

#equação exponencial - espessura 1.4 mm:103.69009852509593

YYY4_AM002=8*10**6*np.exp(-0.263*X_002)
print(YYY4_AM002)
YYY4_AM008=8*10**6*np.exp(-0.263*X_008)
print(YYY4_AM008)
YYY4_AM014=8*10**6*np.exp(-0.263*X_014)
print(YYY4_AM014)


ABCYYY4_AM002=8*10**6*np.exp(-0.263*104.88854622798614)
print(ABCYYY4_AM002)
ABCYYY4_AM008=8*10**6*np.exp(-0.263*104.29006321535918)
print(ABCYYY4_AM008)
ABCYYY4_AM014=8*10**6*np.exp(-0.263*103.69009852509593)
print(ABCYYY4_AM014)

# %%
### 'CONTAGEM - NORMAL (AM241 PBEAM)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N30 = len(x30)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals30 = y30 - (a30 * x30 + b30)


# Dados de exemplo
x30 = np.array([0.2, 0.8, 1.4])
y30 = np.array([8.371013795169144e-06, 9.797977942302172e-06
,  1.1472659218998726e-05])

#media de x
mean_x=np.mean(x30)

#media de y
mean_y=np.mean(y30)

# Variância de x
var_x = np.var(x30, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y30, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x30, y30, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a30 = cov_xy/var_x
print(a30)
b30 = mean_y - a30 * mean_x
print(b30)

# Desvio padrão de x e y
sd_x = np.std(x30, ddof=1)
print(sd_x)
sd_y = np.std(y30, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_30 = a2*sd_x/sd_y
print(f'Coeficiente de Pearson (R_30): {R_30}')
RR_30 = np.abs(R_30)
print(f'Coeficiente de Pearson (RR_30): {RR_30}')

# Resíduos
residuals30 = y30 - (a30 * x30 + b30)

# Número de observações
N30 = len(x30)

# Erro padrão residual (epsilon1)
epsilon1_30 = np.sqrt(np.sum(residuals2**2) / (N30 - 2))
print(f"epsilon1: {epsilon1_30}")

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a30 = epsilon1_30 / (sd_x * np.sqrt(N30))
print(f'Erro de a (error_a2): {error_a30}')

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_30 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_30}")
MODabs_eps2eps2_30 = np.abs(eps2eps2_30)
print(f'valor absoluto de eps2eps2: {eps2eps2_30}')
NN30=(N30 / (N30 - 2))
print(f"NN: {NN30}")
epsilon2_30 = np.sqrt(NN30 * MODabs_eps2eps2_30)
print(f"epsilon2: {epsilon2_2}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)
epsilon3_30 = np.sqrt(NN2 * eps2eps2_30)
print(f"epsilon3: {epsilon3_30}")

# Erro padrão do coeficiente angular (error_a)
error_aa30 = epsilon2_30 / (sd_x * np.sqrt(N30))
print(f'Erro de a (error_aa2): {error_aa30}')

# Erro padrão do coeficiente angular (error_a)
error_aaa30 = epsilon3_30 / (sd_x * np.sqrt(N30))
print(f'Erro de a (error_aaa2): {error_aaa30}')

# Erro padrão do coeficiente linear (error_b)

bb30=np.mean(x30**2)
print(bb30)
error_b30 = error_a30 * np.sqrt(bb30)
print(f'Erro de b (error_b2): {error_b30}')

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a30}')
print(f'Coeficiente linear (b): {b30}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_30}')
print(f'Erro padrão residual (epsilon2): {epsilon2_30}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a30}')
print(f'Erro associado ao coeficiente angular (error_aa): {error_aa30}')
print(f'Erro associado ao coeficiente angular (error_aaa): {error_aaa30}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b30}')

# %%
### 'CONTAGEM (AM-241 PBEAM)' ###

# CONTAGEM PBEAM - VALOR NORMAL (AM-241 - PBEAM) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a30=0.7249947870773908

# COEF B

b30=0.01344183832921697

# ERRO

erro_a30= 0.02069313265583645

erro_b30= 0.01941187910581043

# %%
# I/I0 ISO - VALOR 1 (CS137 - ISO) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.8983

#Y1_ISO_CS002=-0.0974*X_002+0.9829
#print(Y1_ISO_CS002)
#Y1_ISO_CS008=-0.0974*X_008+0.9829
#print(Y1_ISO_CS008)
#Y1_ISO_CS014=-0.0974*X_014+0.9829
#print(Y1_ISO_CS014)

X1_ISO_CS002=np.abs((PICO1_PLACS002_ISO0662-0.9829)/(-0.0974))
print(f'equação linear - espessura 0.2 mm:{X1_ISO_CS002}')
X1_ISO_CS008=np.abs((PICO1_PLACS008_ISO0662-0.9829)/(-0.0974))
print(f'equação linear - espessura 0.8 mm:{X1_ISO_CS008}')
X1_ISO_CS014=np.abs((PICO1_PLACS014_ISO0662-0.9829)/(-0.0974))
print(f'equação linear - espessura 1.4 mm:{X1_ISO_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################


# R**2 = 0.7133

#Y2_ISO_CS002=-0.052*np.log(X_002)+0.8791
#print(Y2_ISO_CS002)
#Y2_ISO_CS008=-0.052*np.log(X_008)+0.8791
#print(Y2_ISO_CS008)
#Y2_ISO_CS014=-0.052*np.log(X_014)+0.8791
#print(Y2_ISO_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

# Y3_ISO_CS002 = -0.0946*X_002**2+0.054*X_002+0.9451
# print(Y3_ISO_CS002)
# Y3_ISO_CS008 = -0.0946*X_008**2+0.054*X_008+0.9451
# print(Y3_ISO_CS008)
# Y3_ISO_CS014 = -0.0946*X_014**2+0.054*X_014+0.9451
# print(Y3_ISO_CS014)

x3_EXP_CS1 = -2.888220737627455
print(f'equação quadrática - primeira raiz:{x3_EXP_CS1}')
x3_EXP_CS2 = 3.459045261940352
print(f'equação quadrática - segunda raiz:{x3_EXP_CS2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 0.8916

#Y4_ISO_CS002=0.986*np.exp(-0.109*X_002)
#print(Y4_ISO_CS002)
#Y4_ISO_CS008=0.986*np.exp(-0.109*X_008)
#print(Y4_ISO_CS008)
#Y4_ISO_CS014=0.986*np.exp(-0.109*X_014)
#print(Y4_ISO_CS014)

X4_ISO_CS002=np.abs(np.log(PICO1_PLACS002_ISO0662/0.986)/(-0.109))
print(f'equação exponencial - espessura 0.2 mm:{X4_ISO_CS002}')
X4_ISO_CS008=np.abs(np.log(PICO1_PLACS008_ISO0662/0.986)/(-0.109))
print(f'equação exponencial - espessura 0.8 mm:{X4_ISO_CS008}')
X4_ISO_CS014=np.abs(np.log(PICO1_PLACS014_ISO0662/0.986)/(-0.109))
print(f'equação exponencial - espessura 1.4 mm:{X4_ISO_CS014}')

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #
# Out:
# equação linear - espessura 0.2 mm:0.31624650920969877
# equação linear - espessura 0.8 mm:0.566734196517977
# equação linear - espessura 1.4 mm:1.51675457155303
# equação quadrática - primeira raiz:-2.888220737627455
# equação quadrática - segunda raiz:3.459045261940352
# equação exponencial - espessura 0.2 mm:0.3209982986952845
# equação exponencial - espessura 0.8 mm:0.5591546213567172
# equação exponencial - espessura 1.4 mm:1.5231497888414824

# %%
#equação linear - espessura 0.2 mm:0.31624650920969877
#equação linear - espessura 0.8 mm:0.566734196517977
#equação linear - espessura 1.4 mm:1.51675457155303


Y1_ISO_CS002=-0.0974*X_002+0.9829
print(Y1_ISO_CS002)
Y1_ISO_CS008=-0.0974*X_008+0.9829
print(Y1_ISO_CS008)
Y1_ISO_CS014=-0.0974*X_014+0.9829
print(Y1_ISO_CS014)

ABCY1_ISO_CS002=-0.0974*0.31624650920969877+0.9829
print(ABCY1_ISO_CS002)
ABCY1_ISO_CS008=-0.0974*0.566734196517977+0.9829
print(ABCY1_ISO_CS008)
ABCY1_ISO_CS014=-0.0974*1.51675457155303+0.9829
print(ABCY1_ISO_CS014)
# Out:
# 0.9634199999999999
# 0.90498
# 0.86602
# 0.9520975900029753
# 0.927700089259149
# 0.8351681047307349

# %%
### 'LN(I/I0) - INVERSO (CS ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N20 = len(x20)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals20 = y20 - (a20 * x20 + b20)


# Dados de exemplo
x20 = np.array([0.2, 0.8, 1.4])
y20 = np.array([0.9520975900029753, 0.927700089259149
,  0.8351681047307349])

#media de x
mean_x=np.mean(x20)

#media de y
mean_y=np.mean(y20)

# Variância de x
var_x = np.var(x20, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y20, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x20, y20, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a20 = cov_xy/var_x
print(a20)
b20 = mean_y - a20 * mean_x
print(b20)

# Desvio padrão de x e y
sd_x = np.std(x20, ddof=1)
print(sd_x)
sd_y = np.std(y20, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_20 = a20*sd_x/sd_y
print(f'Coeficiente de Pearson (R_10): {R_20}')
RR_20 = np.abs(R_20)
print(f'Coeficiente de Pearson (RR_10): {RR_20}')

# Resíduos
residuals20 = y20 - (a20 * x20 + b20)

# Número de observações
N20 = len(x20)

# Erro padrão residual (epsilon1)
epsilon1_20 = np.sqrt(np.sum(residuals20**2) / (N20 - 2))
print(epsilon1_20)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a20 = epsilon1_20 / (sd_x * np.sqrt(N20))
print(error_a20)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_20 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_20}")
MODabs_eps2eps2_20 = np.abs(eps2eps2_20)
print(f'valor absoluto de eps2eps2: {eps2eps2_20}')
NN20=(N20 / (N20 - 2))
print(f"NN: {NN20}")
epsilon2_20 = np.sqrt(NN20 * MODabs_eps2eps2_20)
print(f"epsilon2: {epsilon2_20}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb20=np.mean(x20**2)
print(bb20)
error_b20 = error_a20 * np.sqrt(bb20)
print(error_b20)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a20}')
print(f'Coeficiente linear (b): {b20}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_20}')
print(f'Erro padrão residual (epsilon2): {epsilon2_20}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a20}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b20}')

# %%
### 'I/I0 (CS-137 ISO)' ###

# (I/I0) ISO - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1= -0.09744123772686707

# COEF B

b1=0.9829415848457801

# ERRO

erro_a1= 0.026765753064848352

erro_b1= 0.02510850199978139

# %%
#equação exponencial - espessura 0.2 mm:0.3209982986952845
#equação exponencial - espessura 0.8 mm:0.5591546213567172
#equação exponencial - espessura 1.4 mm:1.5231497888414824

Y4_ISO_CS002=0.986*np.exp(-0.109*X_002)
print(Y4_ISO_CS002)
Y4_ISO_CS008=0.986*np.exp(-0.109*X_008)
print(Y4_ISO_CS008)
Y4_ISO_CS014=0.986*np.exp(-0.109*X_014)
print(Y4_ISO_CS014)

ABCY4_ISO_CS002=0.986*np.exp(-0.109*0.3209982986952845)
print(ABCY4_ISO_CS002)
ABCY4_ISO_CS008=0.986*np.exp(-0.109*0.5591546213567172)
print(ABCY4_ISO_CS008)
ABCY4_ISO_CS014=0.986*np.exp(-0.109*1.5231497888414824)
print(ABCY4_ISO_CS014)
# Out:
# 0.9647378000270287
# 0.9036628656466965
# 0.8651097301945667
# 0.9520975900029753
# 0.927700089259149
# 0.8351681047307349

# %%
### '(I/I0) (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N21 = len(x21)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals21 = y21 - (a21 * x21 + b21)


# Dados de exemplo
x21 = np.array([0.2, 0.8, 1.4])
y21 = np.array([0.9520975900029753, 0.927700089259149
,  0.8351681047307349])

#media de x
mean_x=np.mean(x21)

#media de y
mean_y=np.mean(y21)

# Variância de x
var_x = np.var(x21, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y21, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x21, y21, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a21 = cov_xy/var_x
print(a21)
b21 = mean_y - a21 * mean_x
print(b21)

# Desvio padrão de x e y
sd_x = np.std(x21, ddof=1)
print(sd_x)
sd_y = np.std(y21, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_21 = a21*sd_x/sd_y
print(f'Coeficiente de Pearson (R_21): {R_21}')
RR_21 = np.abs(R_21)
print(f'Coeficiente de Pearson (RR_21): {RR_21}')

# Resíduos
residuals21 = y21 - (a21 * x21 + b21)

# Número de observações
N21 = len(x21)

# Erro padrão residual (epsilon1)
epsilon1_21 = np.sqrt(np.sum(residuals21**2) / (N21 - 2))
print(epsilon1_21)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a21 = epsilon1_21/ (sd_x * np.sqrt(N21))
print(error_a21)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_21 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_21}")
MODabs_eps2eps2_21 = np.abs(eps2eps2_21)
print(f'valor absoluto de eps2eps2: {eps2eps2_21}')
NN21=(N21 / (N21 - 2))
print(f"NN: {NN21}")
epsilon2_21 = np.sqrt(NN21 * MODabs_eps2eps2_21)
print(f"epsilon2: {epsilon2_21}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb21=np.mean(x21**2)
print(bb21)
error_b21 = error_a21 * np.sqrt(bb21)
print(error_b21)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a21}')
print(f'Coeficiente linear (b): {b21}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_21}')
print(f'Erro padrão residual (epsilon2): {epsilon2_21}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a21}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b21}')

# %%
### '(I/I0) (CS-137 ISO)' ###

# (I/I0) ISO - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1=-0.09744123772686707

# COEF B

b1=0.9829415848457801

# ERRO

erro_a1= 0.026765753064848352

erro_b1= 0.02510850199978139

# %%
# LN (I/I0) ISO - VALOR 1 (CS137 - ISO) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################


# R**2 = 0.8916

#YY1_ISO_CS002 = -0.1092*X_002 - 0.0141
#print(YY1_ISO_CS002)
#YY1_ISO_CS008 = -0.1092*X_008 - 0.0141
#print(YY1_ISO_CS008)
#YY1_ISO_CS014 = -0.1092*X_014 - 0.0141
#print(YY1_ISO_CS014) 

XX1_ISO_CS002 = np.abs((np.log(PICO1_PLACS002_ISO0662)+0.0141)/(-0.1092))
print(f'equação linear - espessura 0.2 mm:{XX1_ISO_CS002}')
XX1_ISO_CS008 = np.abs((np.log(PICO1_PLACS008_ISO0662)+0.0141)/(-0.1092))
print(f'equação linear - espessura 0.8 mm:{XX1_ISO_CS008}')
XX1_ISO_CS014 = np.abs((np.log(PICO1_PLACS014_ISO0662)+0.0141)/(-0.1092))
print(f'equação linear - espessura 1.4 mm:{XX1_ISO_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################


# R**2 = 0.7034

# YY2_ISO_CS002=-0.058*np.log(X_002)-0.1304
# print(YY2_ISO_CS002)
# YY2_ISO_CS008=-0.058*np.log(X_008)-0.1304
# print(YY2_ISO_CS008)
# YY2_ISO_CS014=-0.058*np.log(X_014)-0.1304
# print(YY2_ISO_CS014)


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################


# R**2 = 1

# YY3_ISO_CS002 = -0.1099*X_002**2+0.0666*X_002-0.058
# print(YY3_ISO_CS002)
# YY3_ISO_CS008 = -0.1099*X_008**2+0.0666*X_008-0.058
# print(YY3_ISO_CS008)
# YY3_ISO_CS014 = -0.1099*X_014**2+0.0666*X_014-0.058
# print(YY3_ISO_CS014)

xx3_EXP_CS1 = 0.30300272975432213
print(f'equação quadrática - primeira raiz:{xx3_EXP_CS1}')
xx3_EXP_CS2 = 0
print(f'equação quadrática - segunda raiz:{xx3_EXP_CS2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #
# Out:
# equação linear - espessura 0.2 mm:0.32040053971875193
# equação linear - espessura 0.8 mm:0.5581206786390464
# equação linear - espessura 1.4 mm:1.5203502872090033
# equação quadrática - primeira raiz:0.30300272975432213
# equação quadrática - segunda raiz:0
# 'EQUAÇÃO EXPONENCIAL'

# %%
#equação linear - espessura 0.2 mm:0.32040053971875193
#equação linear - espessura 0.8 mm:0.5581206786390464

#equação linear - espessura 1.4 mm:1.5203502872090033


YY1_ISO_CS002 = -0.1092*X_002 - 0.0141
print(YY1_ISO_CS002)
YY1_ISO_CS008 = -0.1092*X_008 - 0.0141
print(YY1_ISO_CS008)
YY1_ISO_CS014 = -0.1092*X_014 - 0.0141
print(YY1_ISO_CS014) 

ABCYY1_ISO_CS002 = -0.1092*X_002 - 0.0141
print(YY1_ISO_CS002)
ABCYY1_ISO_CS008 = -0.1092*X_008 - 0.0141
print(ABCYY1_ISO_CS008)
ABCYY1_ISO_CS014 = -0.1092*X_014 - 0.0141
print(ABCYY1_ISO_CS014)
# Out:
# -0.03594
# -0.10146000000000001
# -0.14514
# -0.03594
# -0.10146000000000001
# -0.14514

# %%
### 'LN(I/I0) (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N22 = len(x22)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals22 = y22 - (a22 * x22 + b22)


# Dados de exemplo
x22 = np.array([0.2, 0.8, 1.4])
y22 = np.array([-0.03594, -0.10146000000000001,  -0.145146051])

#media de x
mean_x=np.mean(x22)

#media de y
mean_y=np.mean(y22)

# Variância de x
var_x = np.var(x22, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y22, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x22, y22, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a22 = cov_xy/var_x
print(a22)
b22 = mean_y - a22 * mean_x
print(b22)

# Desvio padrão de x e y
sd_x = np.std(x22, ddof=1)
print(sd_x)
sd_y = np.std(y22, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_22 = a22*sd_x/sd_y
print(f'Coeficiente de Pearson (R_22): {R_22}')
RR_22 = np.abs(R_22)
print(f'Coeficiente de Pearson (RR_22): {RR_22}')

# Resíduos
residuals22 = y22 - (a22 * x22 + b22)

# Número de observações
N22 = len(x22)

# Erro padrão residual (epsilon1)
epsilon1_22 = np.sqrt(np.sum(residuals22**2) / (N22 - 2))
print(epsilon1_22)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a22 = epsilon1_22 / (sd_x * np.sqrt(N22))
print(error_a22)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_22 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_22}")
MODabs_eps2eps2_22 = np.abs(eps2eps2_22)
print(f'valor absoluto de eps2eps2: {eps2eps2_22}')
NN22=(N22 / (N22 - 2))
print(f"NN: {NN22}")
epsilon2_22 = np.sqrt(NN22 * MODabs_eps2eps2_22)
print(f"epsilon2: {epsilon2_22}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb22=np.mean(x22**2)
print(bb22)
error_b22 = error_a22 * np.sqrt(bb22)
print(error_b22)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a22}')
print(f'Coeficiente linear (b): {b22}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_22}')
print(f'Erro padrão residual (epsilon2): {epsilon2_22}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a22}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b22}')
# Out:
# 0.3599999999999999
# 0.003021217171164867
# -0.0327618153
# -0.09100504250000002
# -0.02137798299999999
# 0.5999999999999999
# 0.05496559988906577
# Coeficiente de Pearson (R_22): -0.9934036126268514
# Coeficiente de Pearson (RR_22): 0.9934036126268514
# 0.008913672353325179
# 0.008577185221100698
# eps2eps2: 3.972677741121691e-05
# valor absoluto de eps2eps2: 3.972677741121691e-05
# NN: 3.0
# epsilon2: 0.010916974500000022
# 0.8799999999999999
# 0.008046112947195063
# Coeficiente angular (a): -0.09100504250000002
# Coeficiente linear (b): -0.02137798299999999
# Erro padrão residual (epsilon1): 0.008913672353325179
# Erro padrão residual (epsilon2): 0.010916974500000022
# Erro associado ao coeficiente angular (error_a): 0.008577185221100698
# Erro associado ao coeficiente linear (error_b): 0.008046112947195063

# %%
### '(I/I0) (CS-137 ISO)' ###

# (I/I0) ISO - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1=-0.09100504250000002

# COEF B

b1=-0.02137798299999999

# ERRO

erro_a1= 0.008577185221100698

erro_b1= 0.008046112947195063

# %%
# CONTAGEM ISO - VALOR 1 (CS137 - ISO) (PICO 1 - 662 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################


# R**2 = 0.8983

#YYY01_ISO_CS002=-327.5*X_002+3303.7
#print(YYY01_ISO_CS002)
#YYY01_ISO_CS008=-327.5*X_008+3303.7
#print(YYY01_ISO_CS008)
#YYY01_ISO_CS014=-327.5*X_014+3303.7
#print(YYY01_ISO_CS014)

XXX1_ISO_CS002=np.abs((CONTISO002_CS137_0662-3303.7)/(-327.5))
print(f'equação linear - espessura 0.2 mm:{XXX1_ISO_CS002}')
XXX1_ISO_CS008=np.abs((CONTISO008_CS137_0662-3303.7)/(-327.5))
print(f'equação linear - espessura 0.8 mm:{XXX1_ISO_CS008}')
XXX1_ISO_CS014=np.abs((CONTISO014_CS137_0662-3303.7)/(-327.5))
print(f'equação linear - espessura 1.4 mm:{XXX1_ISO_CS014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################


# R**2 = 0.7133

#YYY2_ISO_CS002=-174.8*np.log(X_002)+2954.5
#print(YYY2_ISO_CS002)
#YYY2_ISO_CS008=-174.8*np.log(X_008)+2954.5
#print(YYY2_ISO_CS008)
#YYY2_ISO_CS014=-174.8*np.log(X_014)+2954.5
#print(YYY2_ISO_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################


# R**2 = 1

#YYY3_ISO_CS002 = -318.06*X_002**2+181.39*X_002+3176.4
#print(YYY3_ISO_CS002)
#YYY3_ISO_CS008 = -318.06*X_008**2+181.39*X_008+3176.4
#print(YYY3_ISO_CS008)
#YYY3_ISO_CS014 = -318.06*X_014**2+181.39*X_014+3176.4
#print(YYY3_ISO_CS014)

xx3_EXP_CS1 = -2.887877260900744
print(f'equação quadrática - primeira raiz:{xx3_EXP_CS1}')
xx3_EXP_CS2 = 3.4581784619319964
print(f'equação quadrática - segunda raiz:{xx3_EXP_CS2}')

################################################################################################################################


"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 0.8916

#YYY4_ISO_CS002=3314.1*np.exp(-0.109*X_002)
#print(YYY4_ISO_CS002)
#YYY4_ISO_CS008=3314.1*np.exp(-0.109*X_008)
#print(YYY4_ISO_CS008)
#YYY4_ISO_CS014=3314.1*np.exp(-0.109*X_014)
#print(YYY4_ISO_CS014)

XXX4_ISO_CS002=np.abs(np.log(CONTISO002_CS137_0662/3314)/-0.109)
print(f'equação exponencial - espessura 0.2 mm:{XXX4_ISO_CS002}')
XXX4_ISO_CS008=np.abs(np.log(CONTISO008_CS137_0662/3314)/-0.109)
print(f'equação exponencial - espessura 0.8 mm:{XXX4_ISO_CS008}')
XXX4_ISO_CS014=np.abs(np.log(CONTISO014_CS137_0662/3314)/-0.109)
print(f'equação exponencial - espessura 1.4 mm:{XXX4_ISO_CS014}')
# Out:
# equação linear - espessura 0.2 mm:0.31664122137404527
# equação linear - espessura 0.8 mm:0.5670229007633583
# equação linear - espessura 1.4 mm:1.5166412213740452
# equação quadrática - primeira raiz:-2.887877260900744
# equação quadrática - segunda raiz:3.4581784619319964
# equação exponencial - espessura 0.2 mm:0.321147790813673
# equação exponencial - espessura 0.8 mm:0.5593041134751041
# equação exponencial - espessura 1.4 mm:1.5232992809598687

# %%
#equação linear - espessura 0.2 mm:0.31664122137404527
#equação linear - espessura 0.8 mm:0.5670229007633583
#equação linear - espessura 1.4 mm:1.5166412213740452

YYY01_ISO_CS002=-327.5*X_002+3303.7
print(YYY01_ISO_CS002)
YYY01_ISO_CS008=-327.5*X_008+3303.7
print(YYY01_ISO_CS008)
YYY01_ISO_CS014=-327.5*X_014+3303.7
print(YYY01_ISO_CS014)

ABCYYY01_ISO_CS002=-327.5*0.31664122137404527+3303.7
print(ABCYYY01_ISO_CS002)
ABCYYY01_ISO_CS008=-327.5*0.5670229007633583+3303.7
print(ABCYYY01_ISO_CS008)
ABCYYY01_ISO_CS014=-327.5*1.5166412213740452+3303.7
print(ABCYYY01_ISO_CS014)

# %%
### 'CONTAGEM (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N23 = len(x23)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals23 = y23 - (a23 * x23 + b23)


# Dados de exemplo
x23 = np.array([0.2, 0.8, 1.4])
y23 = np.array([3200.0, 3118.0,  2807.0])

#media de x
mean_x=np.mean(x23)

#media de y
mean_y=np.mean(y23)

# Variância de x
var_x = np.var(x23, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y23, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x23, y23, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a23 = cov_xy/var_x
print(a23)
b23 = mean_y - a23 * mean_x
print(b23)

# Desvio padrão de x e y
sd_x = np.std(x23, ddof=1)
print(sd_x)
sd_y = np.std(y23, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_23 = a23*sd_x/sd_y
print(f'Coeficiente de Pearson (R_23): {R_23}')
RR_23 = np.abs(R_23)
print(f'Coeficiente de Pearson (RR_23): {RR_23}')

# Resíduos
residuals23 = y23 - (a23 * x23 + b23)

# Número de observações
N23 = len(x23)

# Erro padrão residual (epsilon1)
epsilon1_23 = np.sqrt(np.sum(residuals23**2) / (N23 - 2))
print(epsilon1_23)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a23 = epsilon1_23 / (sd_x * np.sqrt(N23))
print(error_a23)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_23 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_23}")
MODabs_eps2eps2_23 = np.abs(eps2eps2_23)
print(f'valor absoluto de eps2eps2: {eps2eps2_23}')
NN23=(N23 / (N23 - 2))
print(f"NN: {NN23}")
epsilon2_23 = np.sqrt(NN23 * MODabs_eps2eps2_23)
print(f"epsilon2: {epsilon2_23}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb23=np.mean(x23**2)
print(bb23)
error_b23 = error_a23 * np.sqrt(bb23)
print(error_b23)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a23}')
print(f'Coeficiente linear (b): {b23}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_23}')
print(f'Erro padrão residual (epsilon2): {epsilon2_23}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a23}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b23}')

# %%
### 'CONTAGEM (CS-137 EXP)' ###

# LN(I/I0) EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1=-327.50000000000006

# COEF B

b1=3303.6666666666665

# ERRO

erro_a1= 89.95969605095523

erro_b1= 84.38967522126518

# %%
#equação exponencial - espessura 0.2 mm:0.321147790813673
#equação exponencial - espessura 0.8 mm:0.5593041134751041

#equação exponencial - espessura 1.4 mm:1.5232992809598687


YYY4_ISO_CS002=3314.1*np.exp(-0.109*0.321147790813673)
print(YYY4_ISO_CS002)
YYY4_ISO_CS008=3314.1*np.exp(-0.109*0.5593041134751041)
print(YYY4_ISO_CS008)
YYY4_ISO_CS014=3314.1*np.exp(-0.109*1.5232992809598687)
print(YYY4_ISO_CS014)

# %%
### 'LN(I/I0) (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N22 = len(x22)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals22 = y22 - (a22 * x22 + b22)


# Dados de exemplo
x22 = np.array([0.2, 0.8, 1.4])
y22 = np.array([3200.0965600482796, 3118.094085697043
,  2807.0847012673507])

#media de x
mean_x=np.mean(x22)

#media de y
mean_y=np.mean(y22)

# Variância de x
var_x = np.var(x22, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y22, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x22, y22, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a22 = cov_xy/var_x
print(a22)
b22 = mean_y - a22 * mean_x
print(b22)

# Desvio padrão de x e y
sd_x = np.std(x22, ddof=1)
print(sd_x)
sd_y = np.std(y22, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_22 = a22*sd_x/sd_y
print(f'Coeficiente de Pearson (R_22): {R_22}')
RR_22 = np.abs(R_22)
print(f'Coeficiente de Pearson (RR_22): {RR_22}')

# Resíduos
residuals22 = y22 - (a22 * x22 + b22)

# Número de observações
N22 = len(x22)

# Erro padrão residual (epsilon1)
epsilon1_22 = np.sqrt(np.sum(residuals22**2) / (N22 - 2))
print(epsilon1_22)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a22 = epsilon1_22 / (sd_x * np.sqrt(N22))
print(error_a22)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_22 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_22}")
MODabs_eps2eps2_22 = np.abs(eps2eps2_22)
print(f'valor absoluto de eps2eps2: {eps2eps2_22}')
NN22=(N22 / (N22 - 2))
print(f"NN: {NN22}")
epsilon2_22 = np.sqrt(NN22 * MODabs_eps2eps2_22)
print(f"epsilon2: {epsilon2_22}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb22=np.mean(x22**2)
print(bb22)
error_b22 = error_a22 * np.sqrt(bb22)
print(error_b22)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a22}')
print(f'Coeficiente linear (b): {b22}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_22}')
print(f'Erro padrão residual (epsilon2): {epsilon2_22}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a22}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b22}')

# %%
### 'CONTAGEM (CS-137 EXP)' ###

# LN(I/I0) EXP - VALOR NORMAL (CS137 - EXP) (PICO 1 - 662 KEV)

################################################################################################################################


# [0.9225589225589226, 0.9966329966329966, 0.3771043771043771]


################################################################################################################################


# COEF A

a1=-1050.0000000000002

# COEF B

b1=9612.0

# ERRO

erro_a1= 195.6328761282782

erro_b1= 183.51990506633217

# %%
# I/I0  ISO - VALOR 1 (AM241 -  ISO) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.9971

# Y1_ISO_AM002=-0.1663*X_002+0.9733
# print(Y1_ISO_AM002)
# Y1_ISO_AM008=-0.1663*X_008+0.9733
# print(Y1_ISO_AM008)
# Y1_ISO_AM014=-0.1663*X_014+0.9733
# print(Y1_ISO_AM014)

X1_ISO_AM002=np.abs((PICO1_PLAAM002_ISO00595-0.9733)/-0.1663)
print(f'equação linear - espessura 0.2 mm: {X1_ISO_AM002}')
X1_ISO_AM008=np.abs((PICO1_PLAAM008_ISO00595-0.9733)/-0.1663)
print(f'equação linear - espessura 0.8 mm: {X1_ISO_AM008}')
X1_ISO_AM014=np.abs((PICO1_PLAAM014_ISO00595-0.9733)/-0.1663)
print(f'equação linear - espessura 1.4 mm: {X1_ISO_AM014}')


################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9654

# Y2_ISO_CS002=-0.098*np.log(X_002)+0.7914
# print(Y2_ISO_CS002)
# Y2_ISO_CS008=-0.098*np.log(X_008)+0.7914
# print(Y2_ISO_CS008)
# Y2_ISO_CS014=-0.098*np.log(X_014)+0.7914
# print(Y2_ISO_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#Y3_ISO_AM002 = 0.0257*X_002**2-0.2073*X_002+0.9836
#print(Y3_ISO_AM002)
#Y3_ISO_AM008 = 0.0257*X_002**2-0.2073*X_008+0.9836
#print(Y3_ISO_AM008)
#Y3_ISO_AM014 = 0.0257*X_002**2-0.2073*X_014+0.9836
#print(Y3_ISO_AM014)

x3_ISO_AM1 = -0.4800455753914926
print(f'equação quadrática - primeira raiz:{x3_ISO_AM1}')
x3_ISO_AM2 = 1.6082507035966
print(f'equação quadrática - segunda raiz:{x3_ISO_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################


# R**2 = 0.9996

#Y4_ISO_AM002=0.9799*np.exp(-0.198*X_002)
#print(Y4_ISO_AM002)
#Y4_ISO_AM008=0.9799*np.exp(-0.198*X_008)
#print(Y4_ISO_AM008)
#Y4_ISO_AM014=0.9799*np.exp(-0.198*X_014)
#print(Y4_ISO_AM014)

X4_ISO_AM002=np.abs(np.log(PICO1_PLAAM002_ISO00595/0.9799)/(-0.198))
print(f'equação exponencial - espessura 0.2 mm:{X4_ISO_AM002}')
X4_ISO_AM008=np.abs(np.log(PICO1_PLAAM008_ISO00595/0.9799)/(-0.198))
print(f'equação exponencial - espessura 0.2 mm:{X4_ISO_AM008}')
X4_ISO_AM014=np.abs(np.log(PICO1_PLAAM014_ISO00595/0.9799)/(-0.198))
print(f'equação exponencial - espessura 0.2 mm:{X4_ISO_AM014}')

# %%
#equação linear - espessura 0.2 mm: 0.18152124381004509

#equação linear - espessura 0.8 mm: 0.8201613681279445

#equação linear - espessura 1.4 mm: 1.3768856570226446


Y1_ISO_AM002=-0.1663*X_002+0.9733
print(Y1_ISO_AM002)
Y1_ISO_AM008=-0.1663*X_008+0.9733
print(Y1_ISO_AM008)
Y1_ISO_AM014=-0.1663*X_014+0.9733
print(Y1_ISO_AM014)

ABCY1_ISO_AM002=-0.1663*0.18152124381004509+0.9733
print(ABCY1_ISO_AM002)
ABCY1_ISO_AM008=-0.1663*0.8201613681279445+0.9733
print(ABCY1_ISO_AM008)
ABCY1_ISO_AM014=-0.1663*1.3768856570226446+0.9733
print(ABCY1_ISO_AM014)

# %%
### '(I/I0) - INVERSO (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N24 = len(x24)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals24 = y24  - (a24  * x24  + b24)


# Dados de exemplo
x24 = np.array([0.2, 0.8, 1.4])
y24  = np.array([0.9431130171543896
, 0.8369071644803229,  0.7443239152371343])

#media de x
mean_x=np.mean(x24)

#media de y
mean_y=np.mean(y24)

# Variância de x
var_x = np.var(x24, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y24, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x24, y24, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a24 = cov_xy/var_x
print(a24)
b24 = mean_y - a24 * mean_x
print(b24)

# Desvio padrão de x e y
sd_x = np.std(x24, ddof=1)
print(sd_x)
sd_y = np.std(y24, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_24 = a24*sd_x/sd_y
print(f'Coeficiente de Pearson (R_24): {R_24}')
RR_24 = np.abs(R_24)
print(f'Coeficiente de Pearson (RR_24): {RR_24}')

# Resíduos
residuals24 = y24 - (a24 * x24 + b24)

# Número de observações
N24 = len(x24)

# Erro padrão residual (epsilon1)
epsilon1_24 = np.sqrt(np.sum(residuals24**2) / (N24 - 2))
print(epsilon1_24)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a24 = epsilon1_24 / (sd_x * np.sqrt(N24))
print(error_a24)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_24 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_24}")
MODabs_eps2eps2_24 = np.abs(eps2eps2_24)
print(f'valor absoluto de eps2eps2: {eps2eps2_24}')
NN24=(N24 / (N24 - 2))
print(f"NN: {NN24}")
epsilon2_24 = np.sqrt(NN24 * MODabs_eps2eps2_24)
print(f"epsilon2: {epsilon2_24}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb24=np.mean(x24**2)
print(bb24)
error_b24 = error_a24 * np.sqrt(bb24)
print(error_b24)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a24}')
print(f'Coeficiente linear (b): {b24}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_24}')
print(f'Erro padrão residual (epsilon2): {epsilon2_24}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a24}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b24}')

# %%
#equação exponencial - espessura 0.2 mm:0.1932545538865863
#equação exponencial - espessura 0.2 mm:0.796653413652282
#equação exponencial - espessura 0.2 mm:1.3887586647085393

Y4_ISO_AM002=0.9799*np.exp(-0.198*X_002)
print(Y4_ISO_AM002)
Y4_ISO_AM008=0.9799*np.exp(-0.198*X_008)
print(Y4_ISO_AM008)
Y4_ISO_AM014=0.9799*np.exp(-0.198*X_014)
print(Y4_ISO_AM014)

ABCY4_ISO_AM002=0.9799*np.exp(-0.198*0.1932545538865863)
print(ABCY4_ISO_AM002)
ABCY4_ISO_AM008=0.9799*np.exp(-0.198*0.796653413652282)
print(ABCY4_ISO_AM008)
ABCY4_ISO_AM014=0.9799*np.exp(-0.198*1.3887586647085393)
print(ABCY4_ISO_AM014)

# %%
### '(I/I0) - INVERSO (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N24 = len(x24)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals24 = y24  - (a24  * x24  + b24)


# Dados de exemplo
x24 = np.array([0.2, 0.8, 1.4])
y24  = np.array([0.9431130171543896
, 0.8369071644803229,  0.7443239152371343])

#media de x
mean_x=np.mean(x24)

#media de y
mean_y=np.mean(y24)

# Variância de x
var_x = np.var(x24, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y24, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x24, y24, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a24 = cov_xy/var_x
print(a24)
b24 = mean_y - a24 * mean_x
print(b24)

# Desvio padrão de x e y
sd_x = np.std(x24, ddof=1)
print(sd_x)
sd_y = np.std(y24, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_24 = a24*sd_x/sd_y
print(f'Coeficiente de Pearson (R_24): {R_24}')
RR_24 = np.abs(R_24)
print(f'Coeficiente de Pearson (RR_24): {RR_24}')

# Resíduos
residuals24 = y24 - (a24 * x24 + b24)

# Número de observações
N24 = len(x24)

# Erro padrão residual (epsilon1)
epsilon1_24 = np.sqrt(np.sum(residuals24**2) / (N24 - 2))
print(epsilon1_24)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a24 = epsilon1_24 / (sd_x * np.sqrt(N24))
print(error_a24)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_24 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_24}")
MODabs_eps2eps2_24 = np.abs(eps2eps2_24)
print(f'valor absoluto de eps2eps2: {eps2eps2_24}')
NN24=(N24 / (N24 - 2))
print(f"NN: {NN24}")
epsilon2_24 = np.sqrt(NN24 * MODabs_eps2eps2_24)
print(f"epsilon2: {epsilon2_24}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb24=np.mean(x24**2)
print(bb24)
error_b24 = error_a24 * np.sqrt(bb24)
print(error_b24)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a24}')
print(f'Coeficiente linear (b): {b24}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_24}')
print(f'Erro padrão residual (epsilon2): {epsilon2_24}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a24}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b24}')
# Out:
# 0.3599999999999999
# 0.009894741370620144
# -0.05963673057517658
# -0.1656575849310461
# 0.9739741002354525
# 0.5999999999999999
# 0.0994723145936604
# Coeficiente de Pearson (R_24): -0.9992182384078381
# Coeficiente de Pearson (RR_24): 0.9992182384078381
# 0.00556140456232308
# 0.005351464035216074
# eps2eps2: 1.5464610352915534e-05
# valor absoluto de eps2eps2: 1.5464610352915534e-05
# NN: 3.0
# epsilon2: 0.0068113017154393185
# 0.8799999999999999
# 0.005020118249781151
# Coeficiente angular (a): -0.1656575849310461
# Coeficiente linear (b): 0.9739741002354525
# Erro padrão residual (epsilon1): 0.00556140456232308
# Erro padrão residual (epsilon2): 0.0068113017154393185
# Erro associado ao coeficiente angular (error_a): 0.005351464035216074
# Erro associado ao coeficiente linear (error_b): 0.005020118249781151

# %%
# ln(I/I0) ISO - VALOR 1 (AM241 - ISO) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.9996

#YY1_ISO_AM002=-0.1981*X_002-0.0203
#print(YY1_ISO_AM002)
#YY1_ISO_AM008=-0.1981*X_008-0.0203
#print(YY1_ISO_CS008)
#YY1_ISO_AM014=-0.1981*X_014-0.0203
#print(YY1_ISO_AM014)

XX1_ISO_AM002 = np.abs((np.log(PICO1_PLAAM002_ISO00595)+0.0203)/(-0.1981))
print(f'equação linear - espessura 0.2 mm:{XX1_ISO_AM002}')
XX1_ISO_AM008 = np.abs((np.log(PICO1_PLAAM008_ISO00595)+0.0203)/(-0.1981))
print(f'equação linear - espessura 0.8 mm:{XX1_ISO_AM008}')
XX1_ISO_AM014 = np.abs((np.log(PICO1_PLAAM014_ISO00595)+0.0203)/(-0.1981))
print(f'equação linear - espessura 1.4 mm:{XX1_ISO_AM014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9519

# YY2_ISO_CS002=-0.116*np.log(X_002)-0.2364
# print(YY2_ISO_CS002)
# YY2_ISO_CS008=-0.116*np.log(X_008)-0.2364
# print(YY2_ISO_CS008)
# YY2_ISO_CS014=-0.116*np.log(X_014)-0.2364
# print(YY2_ISO_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

#YY3_ISO_AM002 = 0.011*X_002**2-0.2157*X_002-0.0158
#print(YY3_ISO_AM002)
#YY3_ISO_AM008 = 0.011*X_008**2-0.2157*X_008-0.0158
#print(YY3_ISO_AM008)
#YY3_ISO_AM014 = 0.011*X_014**2-0.2157*X_014-0.0158
#print(YY3_ISO_AM014)

xx3_EXP_AM1 = 19.68206919314571
print(f'equação quadrática - primeira raiz:{xx3_EXP_AM1}')
xx3_EXP_AM2 = -0.07297828405480121
print(f'equação quadrática - segunda raiz:{xx3_EXP_AM2}')

################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# equação linear - espessura 0.2 mm:0.19318099449726564
# equação linear - espessura 0.8 mm:0.7962752611989705
# equação linear - espessura 1.4 mm:1.3880816201547457
# equação quadrática - primeira raiz:19.68206919314571
# equação quadrática - segunda raiz:-0.07297828405480121
# 'EQUAÇÃO EXPONENCIAL'

# %%
#equação linear - espessura 0.2 mm:0.19318099449726564

#equação linear - espessura 0.8 mm:0.7962752611989705

#equação linear - espessura 1.4 mm:1.3880816201547457


YY1_ISO_AM002=-0.1981*X_002-0.0203
print(YY1_ISO_AM002)
YY1_ISO_AM008=-0.1981*X_008-0.0203
print(YY1_ISO_AM008)
YY1_ISO_AM014=-0.1981*X_014-0.0203
print(YY1_ISO_AM014)

ABCYY1_ISO_AM002=-0.1981*0.19318099449726564-0.0203
print(ABCYY1_ISO_AM002)
ABCYY1_ISO_AM008=-0.1981*0.7962752611989705-0.0203
print(ABCYY1_ISO_AM008)
ABCYY1_ISO_AM014=-0.1981*1.3880816201547457-0.0203
print(ABCYY1_ISO_AM014)
# Out:
# -0.05992
# -0.17878
# -0.25801999999999997
# -0.05856915500990832
# -0.17804212924351603
# -0.2952789689526551

# %%
### 'LN(I/I0) - INVERSO (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N25 = len(x25)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals25 = y25 - (a25 * x25 + b25)


# Dados de exemplo
x25 = np.array([0.2, 0.8, 1.4])
y25 = np.array([-0.05856915500990832, -0.10146000000000001,  -0.2952789689526551])

#media de x
mean_x=np.mean(x25)

#media de y
mean_y=np.mean(y25)

# Variância de x
var_x = np.var(x25, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y25, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x25, y25, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a25 = cov_xy/var_x
print(a25)
b25 = mean_y - a25 * mean_x
print(b25)

# Desvio padrão de x e y
sd_x = np.std(x25, ddof=1)
print(sd_x)
sd_y = np.std(y25, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_25 = a25*sd_x/sd_y
print(f'Coeficiente de Pearson (R_25): {R_25}')
RR_25 = np.abs(R_25)
print(f'Coeficiente de Pearson (RR_25): {RR_25}')

# Resíduos
residuals25 = y25 - (a25 * x25 + b25)

# Número de observações
N25 = len(x25)

# Erro padrão residual (epsilon1)
epsilon1_25 = np.sqrt(np.sum(residuals25**2) / (N25 - 2))
print(epsilon1_25)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a25 = epsilon1_25 / (sd_x * np.sqrt(N25))
print(error_a25)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_25 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_25}")
MODabs_eps2eps2_25 = np.abs(eps2eps2_25)
print(f'valor absoluto de eps2eps2: {eps2eps2_25}')
NN25=(N25 / (N25 - 2))
print(f"NN: {NN25}")
epsilon2_25 = np.sqrt(NN25 * MODabs_eps2eps2_25)
print(f"epsilon2: {epsilon2_25}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb25=np.mean(x25**2)
print(bb25)
error_b25 = error_a25 * np.sqrt(bb25)
print(error_b25)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a25}')
print(f'Coeficiente linear (b): {b25}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_25}')
print(f'Erro padrão residual (epsilon2): {epsilon2_25}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a25}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b25}')

# %%
# CONTAGEM ISO - VALOR 1 (AM241 - ISO) (PICO 1 - 59.5 KEV)

# EQUAÇÃO E COEF PEARSON - CALCULO ESPESSURA #

################################################################################################################################

"EQUAÇÃO LINEAR"

################################################################################################################################

# R**2 = 0.9971

#YYY1_ISO_AM002=-1403.3*X_002+8215.7
#print(YYY1_ISO_AM002)
#YYY1_ISO_AM008=-1403.3*X_008+8215.7
#print(YYY1_ISO_AM008)
#YYY1_ISO_AM014=-1403.3*X_014+8215.7
#print(YYY1_ISO_AM014)


XXX1_ISO_AM002=np.abs((CONTISO002_AM241_00595-8215.7)/(-1403.3))
print(f'equação linear - espessura 0.2 mm:{XXX1_ISO_AM002}')
XXX1_ISO_AM008=np.abs((CONTISO008_AM241_00595-8215.7)/(-1403.3))
print(f'equação linear - espessura 0.8 mm:{XXX1_ISO_AM008}')
XXX1_ISO_AM014=np.abs((CONTISO014_AM241_00595-8215.7)/(-1403.3))
print(f'equação linear - espessura 1.4 mm:{XXX1_ISO_AM014}')

################################################################################################################################

"EQUAÇÃO LOGARITMICA"

################################################################################################################################

# R**2 = 0.9654

# YYY2_ISO_CS002=-827*np.log(X_002)+6680.6
# print(YYY2_ISO_CS002)
# YYY2_ISO_CS008=-827*np.log(X_008)+6680.6
# print(YYY2_ISO_S008)
# YYY2_ISO_CS014=-827*np.log(X_014)+6680.6
# print(YYY2_ISO_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #

################################################################################################################################

"EQUAÇÃO QUADRÁTICA"

################################################################################################################################

# R**2 = 1

# YYY3_ISO_CS002 = 216.67*X_002**2-1750*X_002+8302.3
# print(YYY3_ISO_CS002)
# YYY3_ISO_CS008 = 216.67*X_008**2-1750*X_008+8302.3
# print(YYY3_ISO_CS008)
# YYY3_ISO_CS014 = 216.67*X_014**2-1750*X_014+8302.3
# print(YYY3_ISO_CS014)


xxx3_ISO_AM1 = 4.038399409239858
print(f'equação quadrática - primeira raiz:{xxx3_EXP_AM1}')
xxx3_ISO_AM2 = 0
print(f'equação quadrática - segunda raiz:{xxx3_EXP_AM2}')


################################################################################################################################

"EQUAÇÃO EXPONENCIAL"

################################################################################################################################

# R**2 = 0.9996

#YYY4_ISO_CS002=8271.7*np.exp(-0.198*X_002)
#print(YYY4_ISO_CS002)
#YYY4_ISO_CS008=8271.7*np.exp(-0.198*X_008)
#print(YYY4_ISO_CS008)
#YYY4_ISO_CS014=8271.7*np.exp(-0.198*X_014)
#print(YYY4_ISO_CS014)

XXX4_ISO_AM002 = np.abs((np.log(CONTISO002_AM241_00595/8271.7)/(-0.198)))
print(f'equação exponencial - espessura 0.2 mm:{XXX4_ISO_AM002}')
XXX4_ISO_AM008 = np.abs((np.log(CONTISO008_AM241_00595/8271.7)/(-0.198)))
print(f'equação exponencial - espessura 0.8 mm:{XXX4_ISO_AM008}')
XXX4_ISO_AM014 = np.abs((np.log(CONTISO014_AM241_00595/8271.7)/(-0.198)))
print(f'equação exponencial - espessura 1.4 mm:{XXX4_ISO_AM014}')
# Out:
# equação linear - espessura 0.2 mm:0.5264020523052809
# equação linear - espessura 0.8 mm:1.1264163044252837
# equação linear - espessura 1.4 mm:1.6494691085298945
# equação quadrática - primeira raiz:0.45000288001843214
# equação quadrática - segunda raiz:0
# equação exponencial - espessura 0.2 mm:0.5101434755862084
# equação exponencial - espessura 0.8 mm:1.1135423353519036
# equação exponencial - espessura 1.4 mm:1.7056475864081622

# %%
#equação linear - espessura 0.2 mm:0.5264020523052809
#equação linear - espessura 0.8 mm:1.1264163044252837

#equação linear - espessura 1.4 mm:1.6494691085298945

YYY1_ISO_AM002=-1403.3*0.5264020523052809+8215.7
print(YYY1_ISO_AM002)
YYY1_ISO_AM008=-1403.3*1.1264163044252837+8215.7
print(YYY1_ISO_AM008)
YYY1_ISO_AM014=-1403.3*1.6494691085298945+8215.7
print(YYY1_ISO_AM014)
# Out:
# 7477.0
# 6635.0
# 5901.0

# %%
### '(I/I0) - INVERSO (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N26 = len(x26)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals26 = y26  - (a26  * x26  + b26)


# Dados de exemplo
x26 = np.array([0.2, 0.8, 1.4])
y26  = np.array([7477.0, 6635.0,  5901.0])

#media de x
mean_x=np.mean(x26)

#media de y
mean_y=np.mean(y26)

# Variância de x
var_x = np.var(x26, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y26, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x26, y26, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a26 = cov_xy/var_x
print(a26)
b26 = mean_y - a26 * mean_x
print(b26)

# Desvio padrão de x e y
sd_x = np.std(x26, ddof=1)
print(sd_x)
sd_y = np.std(y26, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_26 = a26*sd_x/sd_y
print(f'Coeficiente de Pearson (R_26): {R_26}')
RR_26 = np.abs(R_26)
print(f'Coeficiente de Pearson (RR_26): {RR_26}')

# Resíduos
residuals26 = y26 - (a26 * x26 + b26)

# Número de observações
N26 = len(x26)

# Erro padrão residual (epsilon1)
epsilon1_26 = np.sqrt(np.sum(residuals26**2) / (N26 - 2))
print(epsilon1_26)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a26 = epsilon1_26 / (sd_x * np.sqrt(N26))
print(error_a26)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_26 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_26}")
MODabs_eps2eps2_26 = np.abs(eps2eps2_26)
print(f'valor absoluto de eps2eps2: {eps2eps2_26}')
NN26=(N26 / (N26 - 2))
print(f"NN: {NN26}")
epsilon2_26 = np.sqrt(NN26 * MODabs_eps2eps2_26)
print(f"epsilon2: {epsilon2_26}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb26=np.mean(x26**2)
print(bb26)
error_b26 = error_a26 * np.sqrt(bb26)
print(error_b26)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a26}')
print(f'Coeficiente linear (b): {b26}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_26}')
print(f'Erro padrão residual (epsilon2): {epsilon2_26}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a26}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b26}')
# Out:
# 0.3599999999999999
# 621916.0
# -472.79999999999995
# -1313.3333333333337
# 7721.666666666667
# 0.5999999999999999
# 788.6165100985396
# Coeficiente de Pearson (R_26): -0.9992182384078383
# Coeficiente de Pearson (RR_26): 0.9992182384078383
# 44.090815370097204
# 42.42640687119286
# eps2eps2: 971.9999999998836
# valor absoluto de eps2eps2: 971.9999999998836
# NN: 3.0
# epsilon2: 53.99999999999677
# 0.8799999999999999
# 39.799497484264805
# Coeficiente angular (a): -1313.3333333333337
# Coeficiente linear (b): 7721.666666666667
# Erro padrão residual (epsilon1): 44.090815370097204
# Erro padrão residual (epsilon2): 53.99999999999677
# Erro associado ao coeficiente angular (error_a): 42.42640687119286
# Erro associado ao coeficiente linear (error_b): 39.799497484264805

# %%
#equação exponencial - espessura 0.2 mm:0.5101434755862084
#equação exponencial - espessura 0.8 mm:1.1135423353519036

#equação exponencial - espessura 1.4 mm:1.7056475864081622


YYY4_ISO_CS002=8271.7*np.exp(-0.198*0.5101434755862084)
print(YYY4_ISO_CS002)
YYY4_ISO_CS008=8271.7*np.exp(-0.198*1.1135423353519036)
print(YYY4_ISO_CS008)
YYY4_ISO_CS014=8271.7*np.exp(-0.198*1.7056475864081622)
print(YYY4_ISO_CS014)
# Out:
# 7477.0
# 6635.0
# 5901.0

# %%
### '(I/I0) - INVERSO (AM ISO)' ###

import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N27 = len(x27)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals27 = y27  - (a27  * x27  + b27)


# Dados de exemplo
x27 = np.array([0.2, 0.8, 1.4])
y27  = np.array([7477.0, 6635.0,  5901.0])

#media de x
mean_x=np.mean(x27)

#media de y
mean_y=np.mean(y27)

# Variância de x
var_x = np.var(x27, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y27, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x27, y27, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a27 = cov_xy/var_x
print(a27)
b27 = mean_y - a27 * mean_x
print(b27)

# Desvio padrão de x e y
sd_x = np.std(x27, ddof=1)
print(sd_x)
sd_y = np.std(y27, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_27 = a27*sd_x/sd_y
print(f'Coeficiente de Pearson (R_27): {R_27}')
RR_27 = np.abs(R_27)
print(f'Coeficiente de Pearson (RR_27): {RR_27}')

# Resíduos
residuals27 = y27 - (a27 * x27 + b27)

# Número de observações
N27 = len(x27)

# Erro padrão residual (epsilon1)
epsilon1_27 = np.sqrt(np.sum(residuals27**2) / (N27 - 2))
print(epsilon1_27)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a27 = epsilon1_27 / (sd_x * np.sqrt(N27))
print(error_a27)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_27 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_27}")
MODabs_eps2eps2_27 = np.abs(eps2eps2_27)
print(f'valor absoluto de eps2eps2: {eps2eps2_27}')
NN27=(N27 / (N27 - 2))
print(f"NN: {NN27}")
epsilon2_27 = np.sqrt(NN27 * MODabs_eps2eps2_27)
print(f"epsilon2: {epsilon2_27}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb27=np.mean(x27**2)
print(bb27)
error_b27 = error_a27 * np.sqrt(bb27)
print(error_b27)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a27}')
print(f'Coeficiente linear (b): {b27}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_27}')
print(f'Erro padrão residual (epsilon2): {epsilon2_27}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a27}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b27}')
# Out:
# 0.3599999999999999
# 621916.0
# -472.79999999999995
# -1313.3333333333337
# 7721.666666666667
# 0.5999999999999999
# 788.6165100985396
# Coeficiente de Pearson (R_27): -0.9992182384078383
# Coeficiente de Pearson (RR_27): 0.9992182384078383
# 44.090815370097204
# 42.42640687119286
# eps2eps2: 971.9999999998836
# valor absoluto de eps2eps2: 971.9999999998836
# NN: 3.0
# epsilon2: 53.99999999999677
# 0.8799999999999999
# 39.799497484264805
# Coeficiente angular (a): -1313.3333333333337
# Coeficiente linear (b): 7721.666666666667
# Erro padrão residual (epsilon1): 44.090815370097204
# Erro padrão residual (epsilon2): 53.99999999999677
# Erro associado ao coeficiente angular (error_a): 42.42640687119286
# Erro associado ao coeficiente linear (error_b): 39.799497484264805
