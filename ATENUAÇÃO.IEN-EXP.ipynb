# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import math
import random # necessário para utilizar o módulo random
# Out:
# C:\Users\T-Gamer\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Dados para Determinação do Coeficiente Linear de Atenuação

# Intensidade DO CS137 (Intensidade sem amostra - 0mm)

# Césio 137
I0_CS000_0662 = 9454
print(I0_CS000_0662)

# Amerício 241
I0_AM000_00595 = 594 
print(I0_AM000_00595)

# Intensidade após a Atenuação (número de contagens por segundo)

# I_CS137_PLA000

I_PLACS002_0662 = 9485
print(I_PLACS002_0662)

I_PLACS008_0662 = 8606
print(I_PLACS008_0662)

I_PLACS014_0662 = 8225
print(I_PLACS014_0662)

#I0_PLAAM000_00595

I_PLAAM002_00595 = 548
print(I_PLAAM002_00595)

I_PLAAM008_00595 = 592
print(I_PLAAM008_00595)

I_PLAAM014_00595 = 224
print(I_PLAAM014_00595)
# Out:
# 9454
# 594
# 9485
# 8606
# 8225
# 548
# 592
# 224

# %%
# CALCULO DA ESPESSURA

# Calculo do Coeficiente Linear de Atenuação

# I_CS137_PLA002

PICO1_PLACS002_EXP0662 = I_PLACS002_0662/I0_CS000_0662
print(PICO1_PLACS002_EXP0662)

# I_CS137_PLA008

PICO1_PLACS008_EXP0662 = I_PLACS008_0662/I0_CS000_0662
print(PICO1_PLACS008_EXP0662)

# I_CS137_PLA014

PICO1_PLACS014_EXP0662 = I_PLACS014_0662/I0_CS000_0662
print(PICO1_PLACS014_EXP0662)

# I_AM241_PLA002

PICO1_PLAAM002_EXP00595 = I_PLAAM002_00595/I0_AM000_00595
print(PICO1_PLAAM002_EXP00595)

# I_AM241_PLA008

PICO1_PLAAM008_EXP00595 = I_PLAAM008_00595/I0_AM000_00595
print(PICO1_PLAAM008_EXP00595)

# I_AM241_PLA014

PICO1_PLAAM014_EXP00595 = I_PLAAM014_00595/I0_AM000_00595
print(PICO1_PLAAM014_EXP00595)
# Out:
# 1.0032790353289613
# 0.91030251745293
# 0.8700021155066638
# 0.9225589225589226
# 0.9966329966329966
# 0.3771043771043771

# %%
INVPICO1_PLACS002_EXP0662 = I0_CS000_0662/I_PLACS002_0662
print(INVPICO1_PLACS002_EXP0662)
INVPICO1_PLACS008_EXP0662 = I0_CS000_0662/I_PLACS008_0662
print(INVPICO1_PLACS008_EXP0662)  
INVPICO1_PLACS014_EXP0662 = I0_CS000_0662/I_PLACS014_0662
print(INVPICO1_PLACS014_EXP0662)   
INVPICO1_PLAAM002_EXP00595 = I0_AM000_00595/I_PLAAM002_00595
print(INVPICO1_PLAAM002_EXP00595)    
INVPICO1_PLAAM008_EXP00595 = I0_AM000_00595/I_PLAAM008_00595
print(INVPICO1_PLAAM008_EXP00595)  
INVPICO1_PLAAM014_EXP00595 = I0_AM000_00595/I_PLAAM014_00595
print(INVPICO1_PLAAM014_EXP00595)
# Out:
# 0.9967316816025303
# 1.0985359051824308
# 1.1494224924012157
# 1.083941605839416
# 1.0033783783783783
# 2.6517857142857144

# %%
# lN (I/I0): CS-137 (EXPERIMENTAL)

LN_PICO1_PLACS002_EXP0662 = np.log(PICO1_PLACS002_EXP0662)
print(LN_PICO1_PLACS002_EXP0662)

LN_INVPICO1_PLACS002_EXP0662 = np.log(INVPICO1_PLACS002_EXP0662)
print(LN_INVPICO1_PLACS002_EXP0662)

LN_PICO1_PLACS008_EXP0662 = np.log(PICO1_PLACS008_EXP0662)
print(LN_PICO1_PLACS008_EXP0662)

LN_INVPICO1_PLACS008_EXP0662 = np.log(INVPICO1_PLACS008_EXP0662)
print(LN_INVPICO1_PLACS008_EXP0662)

LN_PICO1_PLACS014_EXP0662 = np.log(PICO1_PLACS014_EXP0662)
print(LN_PICO1_PLACS014_EXP0662)

LN_INVPICO1_PLACS014_EXP0662 = np.log(INVPICO1_PLACS014_EXP0662)
print(LN_INVPICO1_PLACS014_EXP0662)
# Out:
# 0.0032736710159329665
# -0.0032736710159328806
# -0.09397829795463669
# 0.09397829795463669
# -0.13925963571960903
# 0.13925963571960898

# %%
# lN (I/I0): AM-241 (EXPERIMENTAL)

LN_PICO1_PLAAM002_EXP00595 = np.log(PICO1_PLAAM002_EXP00595)
print(PICO1_PLAAM002_EXP00595)

LN_INVPICO1_PLAAM002_EXP00595 = np.log(INVPICO1_PLAAM002_EXP00595)
print(LN_INVPICO1_PLAAM002_EXP00595)

LN_PICO1_PLAAM008_EXP00595 = np.log(PICO1_PLAAM008_EXP00595)
print(LN_PICO1_PLAAM008_EXP00595)

LN_INVPICO1_PLAAM008_EXP00595 = np.log(INVPICO1_PLAAM008_EXP00595)
print(LN_INVPICO1_PLAAM008_EXP00595)

LN_PICO1_PLAAM014_EXP00595 = np.log(PICO1_PLAAM014_EXP00595)
print(LN_PICO1_PLAAM014_EXP00595)

LN_INVPICO1_PLAAM014_EXP00595 = np.log(INVPICO1_PLAAM014_EXP00595)
print(LN_INVPICO1_PLAAM014_EXP00595)
# Out:
# 0.9225589225589226
# 0.08060403241462935
# -0.00337268447863923
# 0.003372684478639156
# -0.9752332675076051
# 0.9752332675076051

# %%
print(PICO1_PLACS002_EXP0662)
print(PICO1_PLACS008_EXP0662)
print(PICO1_PLACS014_EXP0662)
print(PICO1_PLAAM002_EXP00595)
print(PICO1_PLAAM008_EXP00595)
print(PICO1_PLAAM014_EXP00595)
# Out:
# 1.0032790353289613
# 0.91030251745293
# 0.8700021155066638
# 0.9225589225589226
# 0.9966329966329966
# 0.3771043771043771

# %%
print(INVPICO1_PLACS002_EXP0662)
print(INVPICO1_PLACS008_EXP0662)
print(INVPICO1_PLACS014_EXP0662)
print(INVPICO1_PLAAM002_EXP00595)
print(INVPICO1_PLAAM008_EXP00595)
print(INVPICO1_PLAAM014_EXP00595)
# Out:
# 0.9967316816025303
# 1.0985359051824308
# 1.1494224924012157
# 1.083941605839416
# 1.0033783783783783
# 2.6517857142857144

# %%
#  DADOS - EXPERIMENTAL

CONTEXP000_CS137_0662 = 9454
CONTEXP002_CS137_0662 = 9485
CONTEXP008_CS137_0662 = 8606
CONTEXP014_CS137_0662 = 8225
CONTEXP000_AM241_00595 = 594
CONTEXP002_AM241_00595 = 548
CONTEXP008_AM241_00595 = 592
CONTEXP014_AM241_00595 = 224

# TEORIA

# DADOS - TEORIA (PENCIL-BEAM)

CONTPBEAM000_CS137_0662 = 4403330
CONTPBEAM002_CS137_0662 = 4313390
CONTPBEAM008_CS137_0662 = 4026930
CONTPBEAM014_CS137_0662 = 3764660
CONTPBEAM000_AM241_00595 = 8056020
CONTPBEAM002_AM241_00595 = 7645430
CONTPBEAM008_AM241_00595 = 6531960
CONTPBEAM014_AM241_00595 = 5578480

# DADOS - TEORIA (ISOTRÓPICO)

CONTISO000_CS137_0662 = 3361
CONTISO002_CS137_0662 = 3200
CONTISO008_CS137_0662 = 3118
CONTISO014_CS137_0662 = 2807
CONTISO000_AM241_00595 = 7928
CONTISO002_AM241_00595 = 7477
CONTISO008_AM241_00595 = 6635
CONTISO014_AM241_00595 = 5901

# %%
PICO1_PLACS002_PBEAM0662=CONTPBEAM002_CS137_0662/CONTPBEAM000_CS137_0662
print(PICO1_PLACS002_PBEAM0662)
PICO1_PLACS008_PBEAM0662=CONTPBEAM008_CS137_0662/CONTPBEAM000_CS137_0662
print(PICO1_PLACS008_PBEAM0662)
PICO1_PLACS014_PBEAM0662=CONTPBEAM014_CS137_0662/CONTPBEAM000_CS137_0662
print(PICO1_PLACS014_PBEAM0662)

INVPICO1_PLACS002_PBEAM0662=CONTISO000_CS137_0662/CONTISO002_CS137_0662
print(INVPICO1_PLACS002_PBEAM0662)
INVPICO1_PLACS008_PBEAM0662=CONTISO000_CS137_0662/CONTISO008_CS137_0662
print(INVPICO1_PLACS008_PBEAM0662)
INVPICO1_PLACS014_PBEAM0662=CONTISO000_CS137_0662/CONTISO014_CS137_0662
print(INVPICO1_PLACS014_PBEAM0662)
# Out:
# 0.9795745492615816
# 0.9145192388487804
# 0.8549574980753203
# 1.0503125
# 1.0779345734445158
# 1.1973637335233345

# %%
PICO1_PLAAM002_PBEAM00595=CONTPBEAM002_AM241_00595/CONTPBEAM000_AM241_00595
print(PICO1_PLAAM002_PBEAM00595)
PICO1_PLAAM008_PBEAM00595=CONTPBEAM008_AM241_00595/CONTPBEAM000_AM241_00595
print(PICO1_PLAAM008_PBEAM00595)
PICO1_PLAAM014_PBEAM00595=CONTPBEAM014_AM241_00595/CONTPBEAM000_AM241_00595
print(PICO1_PLAAM014_PBEAM00595)

INVPICO1_PLAAM002_PBEAM00595=CONTPBEAM000_AM241_00595/CONTPBEAM002_AM241_00595
print(INVPICO1_PLAAM002_PBEAM00595)
INVPICO1_PLAAM008_PBEAM00595=CONTPBEAM000_AM241_00595/CONTPBEAM008_AM241_00595
print(INVPICO1_PLAAM008_PBEAM00595)
INVPICO1_PLAAM014_PBEAM00595=CONTPBEAM000_AM241_00595/CONTPBEAM014_AM241_00595
print(INVPICO1_PLAAM014_PBEAM00595)
# Out:
# 0.9490331453993411
# 0.8108172521915288
# 0.6924610415565006
# 1.0537039774087265
# 1.233323535355391
# 1.4441245643974703

# %%
## lN (I/I0): CS-137 (PENCIL BEAM)

LN_PICO1_PLACS002_PBEAM0662 = np.log(PICO1_PLACS002_PBEAM0662)
print(LN_PICO1_PLACS002_PBEAM0662)

LN_INVPICO1_PLACS002_PBEAM0662 = np.log(INVPICO1_PLACS002_PBEAM0662)
print(LN_INVPICO1_PLACS002_PBEAM0662)

LN_PICO1_PLACS008_PBEAM0662 = np.log(PICO1_PLACS008_PBEAM0662)
print(LN_PICO1_PLACS008_PBEAM0662)

LN_INVPICO1_PLACS008_PBEAM0662 = np.log(INVPICO1_PLACS008_PBEAM0662)
print(LN_INVPICO1_PLACS008_PBEAM0662)

LN_PICO1_PLACS014_PBEAM0662 = np.log(PICO1_PLACS014_PBEAM0662)
print(LN_PICO1_PLACS014_PBEAM0662)

LN_INVPICO1_PLACS014_PBEAM0662 = np.log(INVPICO1_PLACS014_PBEAM0662)
print(LN_INVPICO1_PLACS014_PBEAM0662)
# Out:
# -0.020636934987259024
# 0.04908773893728773
# -0.08935677381232765
# 0.07504677810738393
# -0.1567035211343791
# 0.18012225136322313

# %%
# lN (I/I0): AM-241 (PENCIL BEAM)

LN_PICO1_PLAAM002_PBEAM00595 = np.log(PICO1_PLAAM002_PBEAM00595)
print(PICO1_PLAAM002_PBEAM00595)

LN_INVPICO1_PLAAM002_PBEAM00595 = np.log(INVPICO1_PLAAM002_PBEAM00595)
print(LN_INVPICO1_PLAAM002_PBEAM00595)

LN_PICO1_PLAAM008_PBEAM00595 = np.log(PICO1_PLAAM008_PBEAM00595)
print(LN_PICO1_PLAAM008_PBEAM00595)

LN_INVPICO1_PLAAM008_PBEAM00595 = np.log(INVPICO1_PLAAM008_PBEAM00595)
print(LN_INVPICO1_PLAAM008_PBEAM00595)

LN_PICO1_PLAAM014_PBEAM00595 = np.log(PICO1_PLAAM014_PBEAM00595)
print(LN_PICO1_PLAAM014_PBEAM00595)

LN_INVPICO1_PLAAM014_PBEAM00595 = np.log(INVPICO1_PLAAM014_PBEAM00595)
print(LN_INVPICO1_PLAAM014_PBEAM00595)
# Out:
# 0.9490331453993411
# 0.05231155432318324
# -0.20971258664407325
# 0.20971258664407322
# -0.36750330018330973
# 0.3675033001833097

# %%
PICO1_PLACS002_ISO0662=CONTISO002_CS137_0662/CONTISO000_CS137_0662
print(PICO1_PLACS002_ISO0662)
PICO1_PLACS008_ISO0662=CONTISO008_CS137_0662/CONTISO000_CS137_0662
print(PICO1_PLACS008_ISO0662)
PICO1_PLACS014_ISO0662=CONTISO014_CS137_0662/CONTISO000_CS137_0662
print(PICO1_PLACS014_ISO0662)

INVPICO1_PLACS002_ISO0662=CONTISO000_CS137_0662/CONTISO002_CS137_0662
print(INVPICO1_PLACS002_ISO0662)
INVPICO1_PLACS008_ISO0662=CONTISO000_CS137_0662/CONTISO008_CS137_0662
print(INVPICO1_PLACS008_ISO0662)
INVPICO1_PLACS014_ISO0662=CONTISO000_CS137_0662/CONTISO014_CS137_0662
print(INVPICO1_PLACS014_ISO0662)
# Out:
# 0.9520975900029753
# 0.927700089259149
# 0.8351681047307349
# 1.0503125
# 1.0779345734445158
# 1.1973637335233345

# %%
## lN (I/I0): CS-137 (ISOTRÓPICO)

LN_PICO1_PLACS002_ISO0662 = np.log(PICO1_PLACS002_ISO0662)
print(LN_PICO1_PLACS002_ISO0662)

LN_INVPICO1_PLACS002_ISO0662 = np.log(INVPICO1_PLACS002_ISO0662)
print(LN_INVPICO1_PLACS002_ISO0662)

LN_PICO1_PLACS008_ISO0662 = np.log(PICO1_PLACS008_ISO0662)
print(LN_PICO1_PLACS008_ISO0662)

LN_INVPICO1_PLACS008_ISO0662 = np.log(INVPICO1_PLACS008_ISO0662)
print(LN_INVPICO1_PLACS008_ISO0662)

LN_PICO1_PLACS014_ISO0662 = np.log(PICO1_PLACS014_ISO0662)
print(LN_PICO1_PLACS014_ISO0662)

LN_INVPICO1_PLACS014_ISO0662 = np.log(INVPICO1_PLACS014_ISO0662)
print(LN_INVPICO1_PLACS014_ISO0662)
# Out:
# -0.04908773893728771
# 0.04908773893728773
# -0.07504677810738386
# 0.07504677810738393
# -0.18012225136322318
# 0.18012225136322313

# %%
PICO1_PLAAM002_ISO00595=CONTISO002_AM241_00595/CONTISO000_AM241_00595
print(PICO1_PLAAM002_ISO00595)
PICO1_PLAAM008_ISO00595=CONTISO008_AM241_00595/CONTISO000_AM241_00595
print(PICO1_PLAAM008_ISO00595)
PICO1_PLAAM014_ISO00595=CONTISO014_AM241_00595/CONTISO000_AM241_00595
print(PICO1_PLAAM014_ISO00595)

INVPICO1_PLAAM002_ISO00595=CONTISO000_AM241_00595/CONTISO002_AM241_00595
print(INVPICO1_PLAAM002_ISO00595)
INVPICO1_PLAAM008_ISO00595=CONTISO000_AM241_00595/CONTISO008_AM241_00595
print(INVPICO1_PLAAM008_ISO00595)
INVPICO1_PLAAM014_ISO00595=CONTISO000_AM241_00595/CONTISO014_AM241_00595
print(INVPICO1_PLAAM014_ISO00595)
# Out:
# 0.9431130171543896
# 0.8369071644803229
# 0.7443239152371343
# 1.0603183094824127
# 1.1948756593820649
# 1.343501101508219

# %%
# lN (I/I0): AM-241 (ISOTRÓPICO)

LN_PICO1_PLAAM002_ISO00595 = np.log(PICO1_PLAAM002_ISO00595)
print(PICO1_PLAAM002_ISO00595)

LN_INVPICO1_PLAAM002_ISO00595 = np.log(INVPICO1_PLAAM002_ISO00595)
print(LN_INVPICO1_PLAAM002_ISO00595)

LN_PICO1_PLAAM008_ISO00595 = np.log(PICO1_PLAAM008_ISO00595)
print(LN_PICO1_PLAAM008_ISO00595)

LN_INVPICO1_PLAAM008_ISO00595 = np.log(INVPICO1_PLAAM008_ISO00595)
print(LN_INVPICO1_PLAAM008_ISO00595)

LN_PICO1_PLAAM014_ISO00595 = np.log(PICO1_PLAAM014_ISO00595)
print(LN_PICO1_PLAAM014_ISO00595)

LN_INVPICO1_PLAAM014_ISO00595 = np.log(INVPICO1_PLAAM014_ISO00595)
print(LN_INVPICO1_PLAAM014_ISO00595)
# Out:
# 0.9431130171543896
# 0.05856915500990833
# -0.17804212924351606
# 0.1780421292435161
# -0.2952789689526551
# 0.2952789689526552

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
#  X ESPESSURA
###################################################################################

"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"

###################################################################################
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
#  X ESPESSURA
###################################################################################

"RESOLUÇÃO"



###################################################################################
# Out:
# 'RESOLUÇÃO'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################

"RESOLUÇÃO - (I/I0)"

###################################################################################

# (I/I0) = y # ESPESSURA = x # COEFICIENTE DE  ATENUAÇÃO = a
# Out:
# 'RESOLUÇÃO - (I/I0)'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################

"EQUAÇÃO LINEAR"
###################################################################################
# CERTO

# R**2 = 0.9505

#Y1_EXP_CS002=-0.1111*PICO1_PLACS002_0662+1.0167
#print(Y1_EXP_CS002)
#Y1_EXP_CS008=-0.1111*PICO1_PLACS008_0662+1.0167
#print(Y1_EXP_CS008)
#Y1_EXP_CS014=-0.1111*PICO1_PLACS014_0662+1.0167
#print(Y1_EXP_CS014)

X1_EXP_CS002=np.abs((PICO1_PLACS002_EXP0662-1.0167)/-0.1111)
print(X1_EXP_CS002)
X1_EXP_CS008=np.abs((PICO1_PLACS008_EXP0662-1.0167)/-0.1111)
print(X1_EXP_CS008)
X1_EXP_CS014=np.abs((PICO1_PLACS014_EXP0662-1.0167)/-0.1111)
print(X1_EXP_CS014)


# CERTO #
# Out:
# 0.12080076211555889
# 0.9576731102346528
# 1.320413001740199

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################
###################################################################################
"EQUAÇÃO LOGARITMICA"
###################################################################################
# CERTO

# R**2 = 0.9997

#Y2_EXP_CS002=-0.068*np.log(X_002)+0.8938
#print(Y2_CS002)
#Y2_EXP_CS008=-0.068*np.log(X_008)+0.8938
#print(Y2_EXP_CS008)
#Y2_EXP_CS014=-0.068*np.log(X_014)+0.8938
#print(Y2_EXP_CS014)


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
#####################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
#####################################################################################
# I/I0 X ESPESSURA
#####################################################################################
###################################################################################
"EQUAÇÃO QUADRÁTICA"
###################################################################################
# CERTO

# R**2 = 1

# Y3_EXP_CS002 = 0.0732*X_002**2-0.2281*X_002+1.046
# print(Y3_EXP_CS002)
# Y3_EXP_CS008 = 0.0732*X_008**2-0.2281*X_008+1.046
# print(Y3_EXP_CS008)
# Y3_EXP_CS014 = 0.0732*X_014**2-0.2281*X_014+1.046
# print(Y3_EXP_CS014)



# EQUAÇÃO - Y3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ay3_EXP_CS = 0.0732
by3_EXP_CS = -0.2281
cy3_EXP_CS = 1.046
print(cy3_EXP_CS)

# Calcular o discriminante
deltay3_EXP_CS = by3_EXP_CS**2 - 4*ay3_EXP_CS*cy3_EXP_CS

# Verificar a natureza das raízes
if deltay3_EXP_CS > 0:
    x1y3_EXP_CS = (-by3_CS + math.sqrt(deltay3_EXP_CS)) / (2*ay3_EXP_CS)
    x2y3_EXP_CS = (-by3_CS - math.sqrt(deltay3_EXP_CS)) / (2*ay3_EXP_CS)
    print(f"Raízes reais: x1 = {x1y3_EXP_CS}, x2 = {x2y3_EXP_CS}")
elif deltay3_EXP_CS == 0:
    x = -by3_EXP_CS / (2*ay3_EXP_CS)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realY3_EXP_CS = -by3_EXP_CS / (2*ay3_EXP_CS)
    print(parte_realY3_EXP_CS)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas cconjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
    


    # CERTO #
# Out:
# 1.046
# 1.5580601092896174

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################
###################################################################################
"EQUAÇÃO EXPONENCIAL"
###################################################################################
# CERTO

# R**2 = 0.9576

#Y4_EXP_CS002=1.0185*np.exp(-0.119*X_002)
#print(Y4_EXP_CS002)
#Y4_EXP_CS008=1.0185*np.exp(-0.119*X_008)
#print(Y4_EXP_CS008)
#Y4_EXP_CS014=1.0185*np.exp(-0.119*X_014)
#print(Y4_EXP_CS014)

X4_EXP_CS002=np.log(PICO1_PLACS002_EXP0662/1.0185)/(-0.119)
print(X4_EXP_CS002)
X4_EXP_CS008=np.log(PICO1_PLACS008_EXP0662/1.0185)/(-0.119)
print(X4_EXP_CS008)
X4_EXP_CS014=np.log(PICO1_PLACS014_EXP0662/1.0185)/(-0.119)
print(X4_EXP_CS014)



# CERTO #
# Out:
# 0.12653181234277716
# 0.9437752490702533
# 1.3242906924733824

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# LN(I/I0) X ESPESSURA
###################################################################################

"RESOLUÇÃO - LN(I/I0)"

###################################################################################

# LN(I/I0) = y # ESPESSURA = x # COEFICIENTE DE  ATENUAÇÃO = a
# Out:
# 'RESOLUÇÃO - LN(I/I0)'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################

# # LN(I/I0) X ESPESSURA: x=PICO1_PLACS - X=np.log(PICO1_PLACS)

###################################################################################
###################################################################################
"EQUAÇÃO LINEAR"
###################################################################################
# CERTO

# R**2 = 0.9576

#YY1_EXP_CS002=-0.1188*X_002+0.0184
#print(YY1_EXP_CS002)
#YY1_EXP_CS008=-0.1188*X_008+0.0184
#print(YYY1_EXP_CS008)
#YY1_EXP_CS014=-0.1188*X_014+0.0184
#print(YY1_EXP_CS014)

# SIM #
XX1_EXP_CS002 = np.abs((np.log(PICO1_PLACS002_EXP0662)-0.0184)/(-0.1188))
print(XX1_EXP_CS002)
XX1_EXP_CS008 = np.abs((np.log(PICO1_PLACS008_EXP0662)-0.0184)/(-0.1188))
print(XX1_EXP_CS008)
XX1_EXP_CS014 = np.abs((np.log(PICO1_PLACS014_EXP0662)-0.0184)/(-0.1188))
print(XX1_EXP_CS014)
# SIM #

#XX01_EXP_CS002 = ((np.log(PICO1_PLACS002_0662)-0.0184)/(-0.1188))
#print(XX01_EXP_CS002)
#XX01_EXP_CS008 = ((np.log(PICO1_PLACS008_0662)-0.0184)/(-0.1188))
#print(XX01_EXP_CS008)
#XX01_EXP_CS014 = ((np.log(PICO1_PLACS014_0662)-0.0184)/(0.1188))
#print(XX01_EXP_CS014)



# CERTO #
# Out:
# 0.1273260015493858
# 0.9459452689784233
# 1.3271013107711198

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################

# # LN(I/I0) X ESPESSURA: x=PICO1_PLACS - X=np.log(PICO1_PLACS)

###################################################################
###################################################################################
"EQUAÇÃO LOGARITMICA"
###################################################################################
# CERTO #

# R**2 = 0.9989

# YY2_EXP_CS002=-0.073*np.log(X_002)-0.1129
# print(YY2_EXP_CS002)
# YY2_EXP_CS008=-0.073*np.log(X_008)-0.1129
# print(YY2_EXP_CS008)
# YY2_EXP_CS014=-0.073*np.log(X_014)-0.1129
# print(YY2_EXP_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################

# LN(I/I0) X ESPESSURA: x=PICO1_PLACS - X=np.log(PICO1_PLACS)

###################################################################
###################################################################################
"EQUAÇÃO QUADRÁTICA"
###################################################################################

# CERTO #

# R**2 = 1


# YY3_EXP_CS002 = 0.0722*X_002**2-0.2343*X_002+0.0472
# print(YY3_EXP_CS002)
# YY3_EXP_CS008 = 0.0722*X_008**2-0.2343*X_008+0.0472
# print(YY3_EXP_CS008)
# YY3_EXP_CS014 = 0.0722*X_014**2-0.2343*X_014+0.0472
# print(YY3_EXP_CS014)

# EQUAÇÃO - YY3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayy3_EXP_CS = 0.0722
byy3_EXP_CS = -0.2343
cyy3_EXP_CS = 0.0472
print(cyy3_EXP_CS)

# Calcular o discriminante
deltayy3_EXP_CS = byy3_EXP_CS**2 - 4*ayy3_EXP_CS*cyy3_EXP_CS

# Verificar a natureza das raízes
if deltayy3_EXP_CS > 0:
    x1yy3_EXP_CS = (-byy3_EXP_CS + math.sqrt(deltayy3_EXP_CS)) / (2*ayy3_EXP_CS)
    x2yy3_EXP_CS = (-byy3_EXP_CS - math.sqrt(deltayy3_EXP_CS)) / (2*ayy3_EXP_CS)
    print(f"Raízes reais: x1 = {x1yy3_EXP_CS}, x2 = {x2yy3_EXP_CS}")
elif deltayy3_EXP_CS == 0:
    x = -byy3_EXP_CS / (2*ayy3_EXP_CS)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYY3_EXP_CS = -byy3_CS / (2*ayy3_EXP_CS)
    print(parte_realYY3_EXP_CS)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")

    # CERTO #
# Out:
# 0.0472
# Raízes reais: x1 = 3.029350444502868, x2 = 0.21580191006776953

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################

# # LN(I/I0) X ESPESSURA: x=PICO1_PLACS - X=np.log(PICO1_PLACS)

###################################################################
###################################################################################
"EQUAÇÃO EXPONENCIAL"
###################################################################################


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# CONTAGEM X ESPESSURA
###################################################################################

"RESOLUÇÃO - CONTAGEM"

###################################################################################

# CONTAGEM = y # ESPESSURA = x # COEFICIENTE DE  ATENUAÇÃO = a
# Out:
# 'RESOLUÇÃO - CONTAGEM'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# CONTAGEM X ESPESSURA

###################################################################
###################################################################################
"EQUAÇÃO LINEAR"
###################################################################################
# CERTO

# R**2 = 0.9505

#YYY01_EXP_CS002-1050*X_002+9612
#print(YYY01_EXP_CS002)
#YYY01_EXP_CS008=-1050*X_008+9612
#print(YYY01_EXP_CS008)
#YYY01_EXP_CS014=-1050*X_014+9612
#print(YYY01_EXP_CS014)

XXX1_EXP_CS002=np.abs((CONTEXP002_CS137_0662-9612)/-1050)
print(XXX1_EXP_CS002)
XXX1_EXP_CS008=np.abs((CONTEXP008_CS137_0662-9612)/-1050)
print(XXX1_EXP_CS008)
XXX1_EXP_CS014=np.abs((CONTEXP014_CS137_0662-9612)/-1050)
print(XXX1_EXP_CS014)
# Out:
# 0.12095238095238095
# 0.9580952380952381
# 1.3209523809523809

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# CONTAGEM X ESPESSURA

###################################################################################
###################################################################################
"EQUAÇÃO LOGARITMICA"
###################################################################################

# CERTO

# R**2 = 0.9997

# YYY2_EXP_CS002=-645*np.log(X_002)+8450.4
# print(YYY2_EXP_CS002)
# YYY2_EXP_CS008=-645*np.log(X_008)+8450.4
# print(YYY2_EXP_CS008)
# YYY2_EXP_CS014=-645*np.log(X_014)+8450.4
# print(YYY2_EXP_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# CONTAGEM X ESPESSURA

###################################################################################
###################################################################################
"EQUAÇÃO QUADRÁTICA"
###################################################################################

# CERTO

# R**2 = 1

# YYY3_EXP_CS002 = 691.67*X_002**2-2156.7*X_002+9888.7
# print(YYY3_EXP_CS002)
# YYY3_EXP_CS008 = 691.67*X_002**2-2156.7*X_008+9888.7
# print(YYY3_EXP_CS008)
# YYY3_EXP_CS014 =691.67*X_002**2-2156.7*X_014+9888.7
# print(YYY3_EXP_CS014)

# EQUAÇÃO - YYY3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayyy3_EXP_CS = 691.67
byyy3_EXP_CS = -2156.7
cyyy3_EXP_CS = 9888.7
print(cyyy3_EXP_CS)

# Calcular o discriminante
deltayyy3_EXP_CS = byyy3_EXP_CS**2 - 4*ayyy3_EXP_CS*cyyy3_EXP_CS

# Verificar a natureza das raízes
if deltayyy3_EXP_CS > 0:
    x1yyy3_EXP_CS = (-byyy3_EXP_CS + math.sqrt(deltayyy3_EXP_CS)) / (2*ayyy3_EXP_CS)
    x2yyy3_EXP_CS = (-byyy3_EXP_CS - math.sqrt(deltayyy3_EXP_CS)) / (2*ayyy3_EXP_CS)
    print(f"Raízes reais: x1 = {x1yyy3_EXP_CS}, x2 = {x2yyy3_EXP_CS}")
elif deltayyy3_EXP_CS == 0:
    x = -byyy3_EXP_CS / (2*ayyy3_EXP_CS)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYYY3_EXP_CS = -byyy3_EXP_CS / (2*ayyy3_EXP_CS)
    print(parte_realYYY3_EXP_CS)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
    


# CERTO #
# Out:
# 9888.7
# 1.5590527274567352

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMETAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# CONTAGEM X ESPESSURA

###################################################################################
###################################################################################
"EQUAÇÃO EXPONENCIAL"
###################################################################################

# CERTO

# R**2 = 0.9576

#YYY4_EXP_CS002=9629*np.exp(-0.119*X_002)
#print(YYY4_EXP_CS002)
#YYY4_EXP_CS008=9629*np.exp(-0.119*X_008)
#print(YYY4_EXP_CS008)
#YYY4_EXP_CS014=9629*np.exp(-0.119*X_014)
#print(YYY4_EXP_CS014)

#XXX04_EXP_CS002=np.log(CONTEXP002_CS137_0662/9629)/-0.119
#print(XXX04_EXP_CS002)
#XXX04_EXP_CS008=np.log(CONTEXP008_CS137_0662/9629)/-0.119
#print(XXX04_EXP_CS008)
#XXX04_EXP_CS014=np.log(CONTEXP014_CS137_0662/9629)/-0.119
#print(XXX04_EXP_CS014)

#XXX004_EXP_CS002=np.abs(XXX04CS002)
#print(XXX004_EXP_CS002)
#XXX004_EXP_CS008=np.abs(XXX04CS008)
#print(XXX004_EXP_CS008)
#XXX004_EXP_CS014=np.abs(XXX04CS014)
#print(XXX004_EXP_CS014)

XXX4_EXP_CS002=np.abs(np.log(CONTEXP002_CS137_0662/9629)/-0.119)
print(XXX4_EXP_CS002)
XXX4_EXP_CS008=np.abs(np.log(CONTEXP008_CS137_0662/9629)/-0.119)
print(XXX4_EXP_CS008)
XXX4_EXP_CS014=np.abs(np.log(CONTEXP014_CS137_0662/9629)/-0.119)
print(XXX4_EXP_CS014)



# CERTO #
# Out:
# 0.12661995690058278
# 0.9438633936280592
# 1.324378837031187

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# (I/I0) - (inverso) X ESPESSURA
###################################################################################

"RESOLUÇÃO - [(I/I0) - (inverso)]"

###################################################################################

# [(I/I0)-(inverso)] = y # ESPESSURA = x # COEFICIENTE DE  ATENUAÇÃO = a
# Out:
# 'RESOLUÇÃO - [(I/I0) - (inverso)]'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO LINEAR"
###################################################################################
# CERTO

# R**2 = 0.9643


#YINV01_EXP_CS002=0.1272*X_002+0.9798
#print(YINV01_EXP_CS002)
#YINV01_EXP_CS008=0.1272*X_008+0.9798
#print(YINV01_EXP_CS008)
#YINV01_EXP_CS014=0.1272*X_014+0.9798
#print(YINV01_EXP_CS014)


XINV1_EXP_CS002=np.abs((PICO1_PLACS002_EXP0662-0.9798)/0.1272)
print(XINV1_EXP_CS002)
XINV1_EXP_CS008=np.abs((PICO1_PLACS008_EXP0662-0.9798)/0.1272)
print(XINV1_EXP_CS008)
XINV1_EXP_CS014=np.abs((PICO1_PLACS014_EXP0662-0.9798)/0.1272)
print(XINV1_EXP_CS014)



# CERTO #
# Out:
# 0.18458361107674007
# 0.5463638565021226
# 0.8631909158281145

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO LOGARITMICA"
###########################################################
# CERTO

# R**2 = 0.9975


# YYINV2_EXP_CS002=0.0775*np.log(X_002)+1.1202
# print(YYINV2_EXP_CS002)
# YYINV2_EXP_CS008=0.0775*np.log(X_008)+1.1202
# print(YYINV2_EXP_CS008)
# YYINV2_EXP_CS014=0.0775*np.log(X_014)+1.1202
# print(YYINV2_EXP_CS014)


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO QUADRÁTICA"
###################################################################################
# CERTO

# R**2 = 1

# YINV3_EXP_CS002 = -0.0707*X_002**2+0.2404*X_002+0.9515
# print(YINV3_EXP_CS002)
# YINV3_EXP_CS008 = -0.0707*X_008**2+0.2404*X_008+0.9515
# print(YINV3_EXP_CS008)
# YINV3_EXP_CS014 = -0.0707*X_014**2+0.2404*X_002+0.9515
# print(YINV3_EXP_CS014)

# EQUAÇÃO - Y3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
aINVy3_EXP_CS = -0.0707
bINVy3_EXP_CS = 0.2404
cINVy3_EXP_CS = 0.9515
print(cINVy3_EXP_CS)

# Calcular o discriminante
deltaINVy3_EXP_CS = bINVy3_EXP_CS**2 - 4*aINVy3_EXP_CS*cINVy3_EXP_CS

# Verificar a natureza das raízes
if deltaINVy3_EXP_CS > 0:
    x1INVy3_EXP_CS = (-bINVy3_EXP_CS + math.sqrt(deltaINVy3_EXP_CS)) / (2*aINVy3_EXP_CS)
    x2INVy3_EXP_CS = (-bINVy3_EXP_CS - math.sqrt(deltaINVy3_EXP_CS)) / (2*aINVy3_EXP_CS)
    print(f"Raízes reais: x1 = {x1INVy3_EXP_CS}, x2 = {x2INVy3_EXP_CS}")
elif deltaINVy3_EXP_CS == 0:
    x = -bINVy3_EXP_CS / (2*aINVy3_EXP_CS)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realINVY3_EXP_CS = -bINVy3_EXP_CS / (2*aINVy3_EXP_CS)
    print(parte_realINVY3_EXP_CS)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
    


# CERTO #
# Out:
# 0.9515
# Raízes reais: x1 = -2.3432179679857383, x2 = 5.743500853417138

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO EXPONENCIAL"
###################################################################################
# CERTO

# R**2 = 0.9576


# YYINV2_EXP_CS002=0.9818*np.exp(0.1188*X_002)
# print(YYINV2_EXP_CS002)
# YYINV2_EXP_CS008=0.9818*np.exp(0.1188*X_008)
# print(YYINV2_EXP_CS008)
# YYINV2_EXP_CS014=0.9818*np.exp(0.1188*X_014)
# print(YYINV2_EXP_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# lN(I/I0) - INVERSO X ESPESSURA 

###################################################################################
###################################################################################
"RESOLUÇÃO - lN(I/I0) - INVERSO"
###########################################################
# lN(I/I0) = y # ESPESSURA = x # COEFICIENTE DE  ATENUAÇÃO = a
# Out:
# 'RESOLUÇÃO - lN(I/I0) - INVERSO'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO LINEAR"
####################################################################################
# CERTO

# R**2 = 0.9576 

#YYINV1_EXP_CS002=0.1188*X_002-0.0184
#print(YYINV1_EXP_CS002)
#YYINV1_EXP_CS008=0.1188*X_008-0.0184
#print(YYINV1_EXP_CS008)
#YYYINV1_EXP_CS014=0.1188*X_014-0.0184
#print(YYINV1_EXP_CS014)

XXINV1_EXP_CS002 = np.abs((np.log(PICO1_PLACS002_EXP0662)+0.0184)/(0.1188))
print(XXINV1_EXP_CS002)
XXINV1_EXP_CS008 = np.abs((np.log(PICO1_PLACS008_EXP0662)+0.0184)/(0.1188))
print(XXINV1_EXP_CS008)
XXINV1_EXP_CS014 = np.abs((np.log(PICO1_PLACS014_EXP0662)+0.0184)/(0.1188))
print(XXINV1_EXP_CS014)


#XXINV01_EXP_CS002=(np.log(PICO1_PLACS002_0662)+0.0184)/(0.1188)
#print(XXINV01_EXP_CS002)
#XXINV01_EXP_CS008=(np.log(PICO1_PLACS008_0662)+0.0184)/(0.1188)
#print(XXINV01_EXP_CS008)
#XXINV01_EXP_CS014=(np.log(PICO1_PLACS014_0662)+0.0184)/(0.1188)
#print(XXINV01_EXP_CS014)

# CERTO #
# Out:
# 0.18243830821492393
# 0.6361809592141136
# 1.01733700100681

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO LOGARITMICA"
###########################################################


# R**2= 0.9989

#YYINV2_EXP_CS002=0.0727*np.log(X_002)+0.1129
# print(YYINV2_EXP_CS002)
#YYINV2_EXP_CS008=0.0727*np.log(X_008)+0.1129
# print(YYINV2_EXP_CS008)
#YYINV2_EXP_CS014=0.0727*np.log(X_014)+0.1129
# print(YYINV2_EXP_CS014)


# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO QUADRÁTICA"
###################################################################################
# CERTO

# R**2 = 1

# YYINV3_EXP_CS002 = -0.0722*X_002**2+0.2343*X_002-0.0472
# print(YYINV3_EXP_CS002)
# YYINV3_EXP_CS008 = -0.0722*X_008**2+0.2343*X_008-0.0472
# print(YYINV3_EXP_CS008)
# YYINV3_EXP_CS014 = -0.0722*X_014**2+0.2343*X_014-0.0472
# print(YYINV3_EXP_CS014)

# EQUAÇÃO - YYY3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
aINVyy3_EXP_CS = -0.0722
bINVyy3_EXP_CS = 0.2343
cINVyy3_EXP_CS = -0.0472
print(cINVyy3_EXP_CS)

# Calcular o discriminante
deltaINVyy3_EXP_CS = bINVyy3_EXP_CS**2 - 4*aINVyy3_EXP_CS*cINVyy3_EXP_CS

# Verificar a natureza das raízes
if deltaINVyy3_EXP_CS > 0:
    x1INVyy3_EXP_CS = (-bINVyy3_EXP_CS + math.sqrt(deltaINVyy3_EXP_CS)) / (2*aINVyy3_EXP_CS)
    x2INVyy3_EXP_CS = (-bINVyy3_EXP_CS - math.sqrt(deltaINVyy3_EXP_CS)) / (2*aINVyy3_EXP_CS)
    print(f"Raízes reais: x1 = {x1INVyy3_EXP_CS}, x2 = {x2INVyy3_EXP_CS}")
elif deltaINVyy3_EXP_CS == 0:
    x = -bINVyy3_EXP_CS / (2*aINVyy3_EXP_CS)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realINVYY3_EXP_CS = -bINVyy3_EXP_CS / (2*aINVyy3_EXP_CS)
    print(parte_realINVYY3_EXP_CS)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
    


# CERTO #
# Out:
# -0.0472
# Raízes reais: x1 = 0.21580191006776953, x2 = 3.029350444502868

# %%
# CALCULO ESPESSURA - CESIO 137 - 662 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - CS-137(662 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO

###################################################################################
###################################################################################
"EQUAÇÃO EXPONECIAL"
###########################################################
# CERTO



# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO EXPONECIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################

"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
###################################################################################
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################

"EQUAÇÃO LINEAR"
###################################################################################
# CERTO

# R**2 = 0.6498

# Y1_EXP_AM002=-0.4545*X_002+1.1291
# print(Y1_EXP_AM002)
# Y1_EXP_AM008=-0.4545*X_008+1.1291
# print(Y1_EXP_AM008)
# Y1_EXP_AM014=-0.4545*X_014+1.1291
# print(Y1_EXP_AM014)

#X01_EXP_AM002=np.abs(PICO1_PLAAM002_00595-1.1291)/-0.4545
#print(X01_EXP_AM002)
#X01_EXP_AM008=np.abs(PICO1_PLAAM008_00595-1.1291)/-0.4545
#print(X01_EXP_AM008)
#X01_EXP_AM014=np.abs(PICO1_PLAAM014_00595-1.1291)/-0.4545
#print(X01_EXP_AM014)

#X001_EXP_AM002=(X01_PBEAM_AM002)
#print(X001_EXP_AM002)
#X001_PBEAM_AM008=(X01_PBEAM_AM008)
#print(X001_AM008)
#X001_AM014=(X01_PBEAM_AM014)
#print(X001_PBEAM_AM014)

X1_EXP_AM002=np.abs((PICO1_PLAAM002_EXP00595-1.1291)/-0.4545)
print(X1_EXP_AM002)
X1_EXP_AM008=np.abs((PICO1_PLAAM008_EXP00595-1.1291)/-0.4545)
print(X1_EXP_AM008)
X1_EXP_AM014=np.abs((PICO1_PLAAM014_EXP00595-1.1291)/-0.4545)
print(X1_EXP_AM014)



# CERTO #
# Out:
# 0.45443581395176547
# 0.2914565530627136
# 1.6545558259529654

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################


"EQUAÇÃO LOGARITMICA"
###################################################################################
# CERTO

# R**2 = 0.412

# Y2_EXP_AM002=-0.217*np.log(X_002)+0.6573
# print(Y2_EXP_AM002)
# Y2_EXP_AM008=-0.217*np.log(X_008)+0.6573
# print(Y2_EXP_AM008)
# Y2_EXP_AM014=-0.217*np.log(X_014)+0.6573
# print(Y2_EXP_AM014)

# NÃO
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################

"EQUAÇÃO QUADRÁTICA"

#############################################################
# CERTO

# R**2 = 1

#Y3_EXP_AM002 = -0.9633*X_002**2+1.0868*X_002+0.7437
#print(Y3_EXP_AM002)
#Y3_EXP_AM008 = -0.9633*X_002**2+1.0868*X_008+0.7437
#print(Y3_EXP_AM008)
#Y3_EXP_AM014 = -0.9633*X_002**2+1.0868*X_014+0.7437
#print(Y3_EXP_AM014)

# EQUAÇÃO - Y3_AM

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ay3_EXP_AM = -0.9633
by3_EXP_AM = 1.0868
cy3_EXP_AM = 0.7437
print(cy3_EXP_AM)

# Calcular o discriminante
deltay3_EXP_AM = by3_EXP_AM**2 - 4*ay3_EXP_AM*cy3_EXP_AM

# Verificar a natureza das raízes
if deltay3_EXP_AM > 0:
    x1y3_EXP_AM = (-by3_EXP_AM + math.sqrt(deltay3_EXP_AM)) / (2*ay3_EXP_AM)
    x2y3_EXP_AM = (-by3_EXP_AM - math.sqrt(deltay3_EXP_AM)) / (2*ay3_EXP_AM)
    print(f"Raízes reais: x1 = {x1y3_EXP_AM}, x2 = {x2y3_EXP_AM}")
elif deltay3_EXP_AM == 0:
    x = -by3_EXP_AM / (2*ay3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realY3_EXP_AM = -by3_EXP_AM / (2*ay3_EXP_AM)
    print(parte_realY3_EXP_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")

    # CERTO #
# Out:
# 0.7437
# Raízes reais: x1 = -0.4800455753914926, x2 = 1.608250703596621

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA
###################################################################################


"EQUAÇÃO EXPONENCIAL"
#############################################################
# CERTO

# R**2 = 0.6857

#Y4_EXP_AM002=1.2755*np.exp(-0.746*X_002)
#print(Y4_EXP_AM002)
#Y4_EXP_AM008=1.2755*np.exp(-0.746*X_008)
#print(Y4_EXP_AM008)
#Y4_EXP_AM014=1.2755*np.exp(-0.746*X_014)
#print(Y4_EXP_AM014)

X4_EXP_AM002=(np.log(PICO1_PLAAM002_EXP00595/1.2755)/(-0.746))
print(X4_EXP_AM002)
X4_EXP_AM008=(np.log(PICO1_PLAAM008_EXP00595/1.2755)/(-0.746))
print(X4_EXP_AM008)
X4_EXP_AM014=(np.log(PICO1_PLAAM014_EXP00595/1.2755)/(-0.746))
print(X4_EXP_AM014)

# CERTO #
# Out:
# 0.43423899599779964
# 0.3307117199441934
# 1.633473895586239

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# LN(I/I0) X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################


"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
#############################################################

# LN(I/I0) X ESPESSURA: x=PICO1_PLACS - X=np.log(PICO1_PLACS)
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# ln(I/I0) X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PL
###################################################################################


"EQUAÇÃO LINEAR"
#############################################################
# CERTO

# R**2 = 0.6857

#YY1_EXP_AM002=-0.7455*X_002+0.2433
#print(YY1_EXP_AM002)
#YY1_EXP_AM008=-0.7455*X_008+0.2433
#print(YYY1_EXP_CS008)
#YY1_EXP_AM014=-0.7455*X_014+0.2433
#print(YY1_EXP_AM014)

XX1_EXP_AM002 = np.abs((np.log(PICO1_PLAAM002_EXP00595)-0.2433)/(-0.7455))
print(XX1_EXP_AM002)
XX1_EXP_AM008 = np.abs((np.log(PICO1_PLAAM008_EXP00595)-0.2433)/(-0.7455))
print(XX1_EXP_AM008)
XX1_EXP_AM014 = np.abs((np.log(PICO1_PLAAM014_EXP00595)-0.2433)/(-0.7455))
print(XX1_EXP_AM014)


# CERTO #
# Out:
# 0.4344789167198248
# 0.33088220587342615
# 1.634518132136291

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# ln(I/I0) X ESPESSURA : x=PICO1_PLAAM - X=np.log(PICO1_PL
###################################################################################


"EQUAÇÃO LOGARITMICA"
#############################################################
# CERTO

# R**2 = 0.4498

# YY2_EXP_CS002=-0.362*np.log(X_002)-0.5334
# print(YY2_EXP_CS002)
# YY2_EXP_CS008=-0.362*np.log(X_008)-0.5334
# print(YY2_EXP_CS008)
# YY2_EXP_CS014=-0.362*np.log(X_014)-0.5334
# print(YY2_EXP_CS014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# ln(I/I0) X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PL
###################################################################################


"EQUAÇÃO QUADRÁTICA"
#############################################################
# CERTO

# R**2 = 1

#YY3_EXP_AM002 = -1.4571*X_002**2+1.5858*X_002-0.3395
#print(YY3_EXP_AM002)
#YY3_EXP_AM008 = -1.4571*X_008**2+1.5858*X_008-0.3395
#print(YY3_EXP_AM008)
#YY3_EXP_AM014 = -1.4571*X_014**2+1.5858*X_014-0.3395
#print(YY3_EXP_AM014)

# EQUAÇÃO - YY3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayy3_EXP_AM = -1.4571
byy3_EXP_AM = 1.5858
cyy3_EXP_AM = -0.3395
print(cyy3_EXP_AM)

# Calcular o discriminante
deltayy3_EXP_AM = byy3_EXP_AM**2 - 4*ayy3_EXP_AM*cyy3_EXP_AM

# Verificar a natureza das raízes
if deltayy3_EXP_AM > 0:
    x1yy3_EXP_AM = (-byy3_EXP_AM + math.sqrt(deltayy3_EXP_AM)) / (2*ayy3_EXP_AM)
    x2yy3_EXP_AM = (-byy3_EXP_AM - math.sqrt(deltayy3_EXP_AM)) / (2*ayy3_EXP_AM)
    print(f"Raízes reais: x1 = {x1yy3_EXP_AM}, x2 = {x2yy3_EXP_AM}")
elif deltayy3_EXP_AM == 0:
    x = -byy3_EXP_AM / (2*ayy3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYY3_EXP_AM = -byy3_EXP_AM / (2*ayy3_EXP_AM)
    print(parte_realYY3_EXP_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")    
    
    


# CERTO #
# Out:
# -0.3395
# Raízes reais: x1 = 0.29293330647485183, x2 = 0.7953928207641846

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# ln(I/I0) X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################


"EQUAÇÃO EXPONENCIAL"
#############################################################
# CERTO

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# CONTAGEM X ESPESSURA: x=PICO1_PLAAM
###################################################################################


"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
#############################################################
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# CONTAGEM X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################

"EQUAÇÃO LINEAR"
#############################################################

# R**2 = 0.6498

#YYY1_EXP_AM002=-270*X_002+670.67
#print(YY1_EXP_AM002)
#YYY1_EXP_AM008=-270*X_008+670.67
#print(YY1_EXP_AM008)
#YYY1_EXP_AM014=-270*X_014+670.67
#print(YY1_EXP_AM014)

XXX1_EXP_AM002=np.abs((CONTEXP002_AM241_00595-670.67)/-270)
print(XXX1_EXP_AM002)
XXX1_EXP_AM008=np.abs((CONTEXP008_AM241_00595-670.67)/-270)
print(XXX1_EXP_AM008)
XXX1_EXP_AM014=np.abs((CONTEXP014_AM241_00595-670.67)/-270)
print(XXX1_EXP_AM014)

# CERTO #
# Out:
# 0.4543333333333332
# 0.2913703703703702
# 1.6543333333333332

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# CONTAGEM X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################


"EQUAÇÃO LOGARITMICA"
#############################################################
# CERTO

# R**2 = 0.412

#YYY2_EXP_AM002=-128.8*np.log(X_002)+390.45
#print(YYY2_EXP_AM002)
#YYY2_EXP_AM008=-128.8*np.log(X_008)+390.45
#print(YYY2_EXP_AM008)
#YYY2_EXP_AM014=-128.8*np.log(X_014)+390.45
#print(YYY2_EXP_AM014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# CONTAGEM X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################


"EQUAÇÃO QUADRÁTICA"
#############################################################

# R**2 = 1

#YYY3_EXP_AM002 = -572.22*X_002**2+645.56*X_002+441.78
#print(YYY3_EXP_AM002)
#YYY3_EXP_AM008 = -572.22*X_002**2+645.56*X_002+441.78
#print(YYY3_EXP_AM008)
#YYY3_EXP_AM014 = -572.22*X_002**2+645.56*X_002+441.78
#print(YYY3_EXP_AM014)

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayyy3_EXP_AM = -572.22
byyy3_EXP_AM = 645.56
cyyy3_EXP_AM = 441.78
print(cyyy3_EXP_AM)

# Calcular o discriminante
deltayyy3_EXP_AM = byyy3_EXP_AM**2 - 4*ayyy3_EXP_AM*cyyy3_EXP_AM

# Verificar a natureza das raízes
if deltayyy3_EXP_AM > 0:
    x1yyy3_EXP_AM = (-byyy3_EXP_AM + math.sqrt(deltayyy3_EXP_AM)) / (2*ayyy3_EXP_AM)
    x2yyy3_EXP_AM = (-byyy3_EXP_AM - math.sqrt(deltayyy3_EXP_AM)) / (2*ayyy3_EXP_AM)
    print(f"Raízes reais: x1 = {x1yyy3_EXP_AM}, x2 = {x2yyy3_EXP_AM}")
elif deltayyy3_EXP_AM == 0:
    x = -byyy3_EXP_AM / (2*ayyy3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYYY3_EXP_AM = -byyy3_EXP_AM / (2*ayyy3_EXP_AM)
    print(parte_realYYY3_EXP_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
    
     # CERTO #
# Out:
# 441.78
# Raízes reais: x1 = -0.48006001378122254, x2 = 1.608227501810302

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# CONTAGEM X ESPESSURA: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################


"EQUAÇÃO EXPONENCIAL"
#############################################################

# CERTO

# R**2 = 0.6857

#YYY4_EXP_AM002=757.66*np.exp(-0.746*X_002)
#print(YYY4_EXP_AM002)
#YYY4_EXP_AM008=757.66*np.exp(-0.746*X_008)
#print(YYY4_EXP_AM008)
#YYY4_EXP_AM014=757.66*np.exp(-0.746*X_014)
#print(YYY4_EXP_AM014)

XXX4_EXP_AM002=np.abs(np.log(CONTEXP002_AM241_00595/757.66)/-0.746)
print(f'equação exponencial - espessura 0.2 mm:{XXX4_EXP_AM002}')
XXX4_EXP_AM008=np.abs(np.log(CONTEXP008_AM241_00595/757.66)/-0.746)
print(f'equação exponencial - espessura 0.8 mm:{XXX4_EXP_AM008}')
XXX4_EXP_AM014=np.abs(np.log(CONTEXP014_AM241_00595/757.66)/-0.746)
print(f'equação exponencial - espessura 1.4 mm:{XXX4_EXP_AM014}')

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# equação exponencial - espessura 0.2 mm:0.43426199631847223
# equação exponencial - espessura 0.8 mm:0.3307347202648661
# equação exponencial - espessura 1.4 mm:1.6334968959069114

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# (I/I0) X ESPESSURA  - INVERSO: x=PICO1_PLAAM
###################################################################################


"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
#############################################################
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# (I/I0) X ESPESSURA - INVERSO: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)
###################################################################################


"EQUAÇÃO LINEAR"
#############################################################
# CERTO

# R**2 = 0.7116

#YINV01_EXP_AM002=1.3065*X_002+0.5345
#print(YINV01_EXP_AM002)
#YINV01_EXP_AM008=1.3065*X_008+0.5345
#print(YINV01_EXP_CS008)
#YINV01_EXP_AM014=1.3065*X_014+0.5345
#print(YINV01_EXP_AM014)

XINV1_EXP_AM002 = np.abs((np.log(PICO1_PLAAM002_EXP00595)-0.5345)/(1.3065))
print(XINV1_EXP_AM002)
XINV1_EXP_AM008 = np.abs((np.log(PICO1_PLAAM008_EXP00595)-0.5345)/(1.3065))
print(XINV1_EXP_AM008)
XINV1_EXP_AM014 = np.abs((np.log(PICO1_PLAAM014_EXP00595)-0.5345)/(1.3065))
print(XINV1_EXP_AM014)

#XINV001_EXP_AM002 = (np.log(PICO1_PLAAM002_00595)-0.5345)/(1.3065)
#print(XINV001_EXP_AM002)
#XINV001_EXP_AM008 = (np.log(PICO1_PLAAM008_00595)-0.5345)/(1.3065)
#print(XINV001_EXP_AM008)
#XINV001_EXP_AM014 = (np.log(PICO1_PLAAM014_00595)-0.5345)/(1.3065)
#print(XINV001_EXP_AM014)

# CERTO #
# Out:
# 0.47080293334453066
# 0.4116897699798234
# 1.1555555051722963

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# (I/I0) X ESPESSURA - INVERSO: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################


"EQUAÇÃO LOGARITMICA"
#############################################################

# CERTO

# R**2 = 0.4479

#YINV2_EXP_AM002=0.6413*np.log(X_002)+1.8995
#print(YINV2_EXP_AM002)
#YINV2_EXP_AM008=0.6413*np.log(X_008)+1.8995
#print(YINV2_EXP_AM008)
#YINV2_EXP_AM014=0.6413*np.log(X_014)+1.8995
#print(YINV2_EXP_AM014)



# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# (I/I0) X ESPESSURA - INVERSO: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)
###################################################################################


"EQUAÇÃO QUADRÁTICA"
#############################################################
# CERTO

# R**2 = 1

#YINV3_EXP_AM002 = 2.4013*X_002**2-2.5356*X_002+1.495
#print(YINV3_EXP_AM002)
#YINV3_EXP_AM008 = 2.4013*X_008**2-2.5356*X_008+1.495
#print(YINV3_EXP_AM008)
#YINV3_EXP_AM014 = 2.4013*X_014**2-2.5356*X_014+1.495
#print(YINV3_EXP_AM014)

# EQUAÇÃO - YY3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayINV3_EXP_AM = 2.4013
byINV3_EXP_AM = -2.5356
cyINV3_EXP_AM = 1.495
print(cyINV3_EXP_AM)

# Calcular o discriminante
deltayINV3_EXP_AM = byINV3_EXP_AM**2 - 4*ayINV3_EXP_AM*cyINV3_EXP_AM

# Verificar a natureza das raízes
if deltayINV3_EXP_AM > 0:
    x1yINV3_EXP_AM = (-byINV3_AM + math.sqrt(deltayINV3_AM)) / (2*ayINV3_EXP_AM)
    x2yINV3_EXP_AM = (-byINV3_AM - math.sqrt(deltayINV3_AM)) / (2*ayINV3_EXP_AM)
    print(f"Raízes reais: x1 = {x1yINV3_EXP_AM}, x2 = {x2yINV3_EXP_AM}")
elif deltayINV3_EXP_AM == 0:
    x = -byINV3_EXP_AM / (2*ayINV3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYINV3_EXP_AM = -byINV3_EXP_AM / (2*ayINV3_EXP_AM)
    print(parte_realYINV3_EXP_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")



    # CERTO #
# Out:
# 1.495
# 0.5279640194894433

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################

# (I/I0) X ESPESSURA - INVERSO: x=PICO1_PLAAM - X=np.log(PICO1_PLAAM)

###################################################################################


"EQUAÇÃO EXPONENCIAL"
#############################################################
# CERTO

# R**2 = 0.6857

#YINV4_EXP_AM002=0.784*np.exp(0.7455*X_002)
#print(YINV4_EXP_AM002)
#YINV4_EXP_AM008=0.784*np.exp(0.7455*X_008)
#print(YINV4_EXP_AM008)
#YINV4_EXP_AM014=0.784*np.exp(0.7455*X_014)
#print(YINV4_EXP_AM014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
###################################################
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO LINEAR"
#############################################################


# R**2 = 0.6857

#YYINV1_EXP_AM002=0.7455*X_002-0.2433
#print(YYINV1_AM002)
#YYINV1_EXP_AM008=0.7455*X_008-0.2433
#print(YYINV1_EXP_AM008)
#YYINV1_EXP_AM014=0.7455*X_014-0.2433
#print(YYINV1_EXP_AM014)




XXINV1_EXP_AM002 = np.abs((np.log(PICO1_PLAAM002_EXP00595)+0.2433)/(0.7455))
print(XXINV1_EXP_AM002)
XXINV1_EXP_AM008 = np.abs((np.log(PICO1_PLAAM008_EXP00595)+0.2433)/(0.7455))
print(XXINV1_EXP_AM008)
XXINV1_EXP_AM014 = np.abs((np.log(PICO1_PLAAM014_EXP00595)+0.2433)/(0.7455))
print(XXINV1_EXP_AM014)




# CERTO #
# Out:
# 0.2182373810668955
# 0.3218340919132941
# 0.9818018343495708

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO LOGARITMICA"
#############################################################
# CERTO

# R**2 = 0.4498

#YYINV2_EXP_AM002=0.3616*np.log(X_002)+0.5334
#print(YYINV2_EXP_AM002)
#YYINV2_EXP_AM008=0.3616*np.log(X_008)+0.5334
#print(YYINV2_EXP_AM008)
#YYINV2_EXP_AM014=0.3616*np.log(X_014)+0.5334
#print(YYINV2_EXP_AM014)

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
#############################################################
"EQUAÇÃO QUADRÁTICA"
#############################################################
# CERTO

# R**2 = 1

#YYINV3_EXP_AM002 = 1.4571*X_002**2-1.5858*X_002+0.3395
#print(YYINV3_EXP_AM002)
#YYINV3_EXP_AM008 = 1.4571*X_008**2-1.5858*X_008+0.3395
#print(YYINV3_EXP_AM008)
#YYINV3_EXP_AM014 = 1.4571*X_014**2-1.5858*X_014+0.3395
#print(YYINV3_EXP_AM014)

# EQUAÇÃO - YY3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayyINV3_EXP_AM = 1.4571
byyINV3_EXP_AM = -1.5858
cyyINV3_EXP_AM = 0.3395
print(cyyINV3_EXP_AM)

# Calcular o discriminante
deltayyINV3_EXP_AM = byyINV3_EXP_AM**2 - 4*ayyINV3_EXP_AM*cyyINV3_EXP_AM

# Verificar a natureza das raízes
if deltayyINV3_EXP_AM > 0:
    x1yyINV3_EXP_AM = (-byyINV3_EXP_AM + math.sqrt(deltayyINV3_EXP_AM)) / (2*ayyINV3_EXP_AM)
    x2yyINV3_EXP_AM = (-byyINV3_EXP_AM - math.sqrt(deltayyINV3_EXP_AM)) / (2*ayyINV3_EXP_AM)
    print(f"Raízes reais: x1 = {x1yyINV3_EXP_AM}, x2 = {x2yyINV3_EXP_AM}")
elif deltayyINV3_EXP_AM == 0:
    x = -byyINV3_EXP_AM / (2*ayyINV3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYYINV3_EXP_AM = -byyINV3_EXP_AM / (2*ayyINV3_EXP_AM)
    print(parte_realYYINV3_EXP_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
    


    # CERTO #
# Out:
# 0.3395
# Raízes reais: x1 = 0.7953928207641846, x2 = 0.29293330647485183

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (EXPERIMENTAL)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO EXPONENCIAL"
#############################################################
# CERTO

# NÃO TEM VALOR PRA ESSA EQUAÇÃO #


# CERTO #
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
#  DADOS - EXPERIMENTAL
CONTEXP000_CS137_0662 = 9454
CONTEXP002_CS137_0662 = 9485
CONTEXP008_CS137_0662 = 8606
CONTEXP014_CS137_0662 = 8225
CONTEXP000_AM241_00595 = 594
CONTEXP002_AM241_00595 = 548
CONTEXP008_AM241_00595 = 592
CONTEXP014_AM241_00595 = 224

# TEORIA

# DADOS - TEORIA (PENCIL-BEAM)

CONTPBEAM000_CS137_0662 = 4403330
CONTPBEAM002_CS137_0662 = 4313390
CONTPBEAM008_CS137_0662 = 4026930
CONTPBEAM014_CS137_0662 = 3764660
CONTPBEAM000_AM241_00595 = 8056020
CONTPBEAM002_AM241_00595 = 7645430
CONTPBEAM008_AM241_00595 = 6531960
CONTPBEAM014_AM241_00595 = 5578480

# DADOS - TEORIA (ISOTRÓPICO)

CONTISO000_CS137_0662 = 3361
CONTISO002_CS137_0662 = 3200
CONTISO008_CS137_0662 = 3118
CONTISO014_CS137_0662 = 2807
CONTISO000_AM241_00595 = 7928
CONTISO002_AM241_00595 = 7477
CONTISO008_AM241_00595 = 6635
CONTISO014_AM241_00595 = 5901

print(PICO1_PLACS002_PBEAM0662)

XXX001_PBEAM_CS002=np.abs((CONTPBEAM002_CS137_0662-4*10**6)/(-457275))
print(XXX001_PBEAM_CS002)
XXX001_PBEAM_CS008=np.abs((CONTPBEAM008_CS137_0662-4*10**6)/(-457275))
print(XXX001_PBEAM_CS008)
XXX001_PBEAM_CS014=np.abs((CONTPBEAM014_CS137_0662-4*10**6)/(-457275))
print(XXX001_PBEAM_CS014)
# Out:
# 0.9795745492615816
# 0.685342518178339
# 0.05889235142966486
# 0.5146574818216609

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5 (FEIXE ISOTRÓPICO)
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################


"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
#############################################################
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO LINEAR"

#YINV1_EXP_EXPCS002=1.3065*X_002+0.5345
#print(YINV1_EXP_CS002)
#YINV1_EXP_CS008=1.3065*X_008+0.5345
#print(YINV1_EXP_CS008)
#YINV1_EXP_CS014=1.3065*X_014+0.5345
#print(YINV1_EXP_CS014)

XINV1_EXP_AM002=(INVPICO1_PLAAM002_EXP00595-0.5345)/1.3065
print(XINV1_EXP_AM002)

XINV1_EXP_AM008=(INVPICO1_PLAAM008_EXP00595-0.5345)/1.3065
print(XINV1_EXP_AM008)

XINV1_EXP_AM014=(INVPICO1_PLAAM014_EXP00595-0.5345)/1.3065
print(XINV1_EXP_AM014)
# Out:
# 0.42054466577835137
# 0.3588812693290305
# 1.6205784265485759

# %%
###################################################################################

# I/I0 X ESPESSURA - INVERSO

#########################################################################################################################################################################################################################################################

##################################################################################################################################################################################################

"EQUAÇÃO LOGARITMICA"
#############################################################

#YINV2_EXP_AM002=0.6413*np.log(X_002)+1.8995
#print(YINV2_EXP_AM002)
#YYINV2_EXP_AM008=0.9818*np.log(X_008)+1.8995
#print(YYINV2_EXP_AM008)
#YYINV2_EXP_AM014=0.9818*np.log(X_014)+1.8995
#print(YYINV2_EXP_AM014)

#XXINV02_EXP_AM002 = ((np.log(INVPICO1_PLAAM002_00595)-1.8995)/(0.6413))
#print(XXINV02_EXP_AM002)
#XXINV02_EXP_AM008 = ((np.log(INVPICO1_PLAAM008_00595)-1.8995)/(0.6413))
#print(XXINV02_EXP_AM008)
#XXINV02_EXP_AM014 = ((np.log(INVPICO1_PLAAM014_00595)-1.8995)/(0.6413))
#print(XXINV02_EXP_AM014)

XXINV2_EXP_AM002 = np.abs((np.log(PICO1_PLAAM002_EXP00595)-1.8995)/(0.6413))
print(XXINV2_EXP_AM002)
XXINV2_EXP_AM008 = np.abs((np.log(PICO1_PLAAM008_EXP00595)-1.8995)/(0.6413))
print(XXINV2_EXP_AM008)
XXINV2_EXP_AM014 = np.abs((np.log(PICO1_PLAAM014_EXP00595)-1.8995)/(0.6413))
print(XXINV2_EXP_AM014)
# Out:
# 3.087640780312848
# 2.9672114212983614
# 4.4826653165563775

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO QUADRATICA"
#############################################################

# EQUAÇÃO - Y3_AM

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayINV3_EXP_AM = 2.4013
byINV3_EXP_AM = -2.536
cyINV3_EXP_AM = 1.495
print(cyINV3_EXP_AM)

# Calcular o discriminante
deltayINV3_EXP_AM = byINV3_EXP_AM**2 - 4*ayINV3_EXP_AM*cyINV3_EXP_AM

# Verificar a natureza das raízes
if deltayINV3_EXP_AM > 0:
    x1yINV3_EXP_AM = (-byINV3_EXP_CS + math.sqrt(deltayINV3_EXP_AM)) / (2*ayINV3_EXP_AM)
    x2yINV3_EXP_AM = (-byINV3_EXP_CS - math.sqrt(deltay3_EXP_AM)) / (2*ayINV3_EXP_AM)
    print(f"Raízes reais: x1 = {x1yINV3_EXP_AM}, x2 = {x2yINV3_EXP_AM}")
elif deltayINV3_EXP_AM == 0:
    x = -byINV3_EXP_AM / (2*ayINV3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYINV3_EXP_AM= -byINV3_EXP_AM / (2*ayINV3_EXP_AM)
    print(parte_realYINV3_EXP_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
# Out:
# 1.495
# 0.5280473077083246

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################



"RESOLUÇÃO - (I/I0)" "EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
#############################################################

#
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO LINEAR"
#############################################################

#YYINV1_EXP_AM002=0.7455*X_002-0.2433
#print(YYINV1_EXP_AM002)
#YYINV1_EXP_AM008=0.7455*X_008-0.2433
#print(YYINV1_EXP_AM008)
#YYINV1_EXP_AM014=0.7455*X_014-0.2433
#print(YYINV1_EXP_AM014)
# Out:
# 'EQUAÇÃO LINEAR'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO LOGARITMICA"
#############################################################

# YY2_EXP_CS002=0.3616*np.log(X_002)+0.5334
# print(YY2_EXP_CS002)
# YY2_EXP_CS008=0.3616*np.log(X_008)+0.5334
# print(YY2_EXP_CS008)
# YY2_EXP_CS014=0.3616*np.log(X_014)+0.5334
# print(YY2_EXP_CS014)
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO QUADRÁTICA"


#############################################################

# YY3_EXP_CS002 = 1.4571*X_002**2-1.5858*X_002+0.3395
# print(YY3_EXP_CS002)
# YY3_EXP_CS008 = 1.4571*X_008**2-1.5858*X_008+0.3395
# print(YY3_EXP_CS008)
# YY3_EXP_CS014 = 1.4571*X_014**2-1.5858*X_014+0.3395
# print(YY3_EXP_CS014)

#YYINV3_EXP_CS002 = -0.0722*X_002**2+0.2343*X_002-0.0472
#print(YYINV3_EXP_CS002)
#YYINV3_EXP_CS008 = -0.00722*X_008**2+0.2343*X_008-0.0472
#print(YYINV3_EXP_CS008)
#YYINV3_EXP_CS014 = -0.00722*X_014**2+0.2343*X_014-0.0472
#print(YYINV3_EXP_CS014)

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayyINV3_EXP_AM = 1.4571
byyINV3_EXP_AM = -1.5858
#c = 0.9515-0.2
cyyINV3_EXP_AM = 0.3395
print(cyyINV3_EXP_AM)

# Calcular o discriminante
deltayyINV3_EXP_AM = byyINV3_EXP_AM**2 - 4*ayyINV3_EXP_AM*cyyINV3_AM

# Verificar a natureza das raízes
if deltayyINV3_EXP_AM > 0:
    x1yyINV3_EXP_AM = (-byyINV3_EXP_AM + math.sqrt(deltayyINV3_EXP_AM)) / (2*ayINV3_EXP_AM)
    x2yyINV3_EXP_AM = (-byyINV3_EXP_AM - math.sqrt(deltayyINV3_EXP_AM)) / (2*ayINV3_EXP_AM)
    print(f"Raízes reais: x1 = {x1yyINV3_AM}, x2 = {x2yyINV3_EXP_AM}")
elif deltayyINV3_EXP_AM == 0:
    x = -byyINV3_EXP_AM / (2*ayyINV3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYYINV3_EXP_AM = -byyINV3_EXP_AM / (2*ayyINV3_EXP_AM)
    print(parte_realYYINV3_EXP_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
# Out:
# 0.3395
# Raízes reais: x1 = 0.48264143552887745, x2 = 0.17775085198205415

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# I/I0 X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO EXPONENCIAL"
#############################################################
# CERTO

# NÃO #
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"RESOLUÇÃO""EQUAÇÃO LINEAR""EQUAÇÃO LOGARITMICA""EQUAÇÃO QUADRÁTICA"

"EQUAÇÃO EXPONENCIAL"
###################################################
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO LINEAR"
#############################################################


#YYINV1_EXP_AM002=0.7455*X_002-0.2433
#print(YYINV1_EXP_AM002)
#YYINV1_EXP_AM008=0.7455*X_008-0.2433
#print(YYINV1_AM008)
#YYINV1_EXP_AM014=0.7455*X_014-0.2433
#print(YYINV1_EXP_AM014)




XX3_EXP_AM002 = np.abs((np.log(PICO1_PLAAM002_EXP00595)+0.2433)/(0.7455))
print(XX3_EXP_AM002)
XX3_EXP_AM008 = np.abs((np.log(PICO1_PLAAM008_EXP00595)+0.2433)/(0.7455))
print(XX3_EXP_AM008)
XX3_EXP_AM014 = np.abs((np.log(PICO1_PLAAM014_EXP00595)+0.2433)/(0.7455))
print(XX3_EXP_AM014)
# Out:
# 0.2182373810668955
# 0.3218340919132941
# 0.9818018343495708

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO LOGARITMICA"
#############################################################
# CERTO

# R**2 = 0.4498
#YY2_EXP_AM002=0.3616*np.log(X_002)+0.5334
#print(YY2_EXP_AM002)
#YY2_EXP_AM008=0.3616*np.log(X_008)+0.5334
#print(YY2_EXP_AM008)
#YY2_AM014=0.3616*np.log(X_014)+0.5334
#print(YY2_EXP_AM014)

# NÃO #
# Out:
# 'EQUAÇÃO LOGARITMICA'

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO


###################################################################################


"EQUAÇÃO QUADRÁTICA"
#############################################################
# CERTO

# R**2 = 1
#YY3_EXP_AM002 = 1.4571*X_002**2-1.5858*X_002+0.3395
#print(YY3_EXP_AM002)
#YY3_EXP_AM008 = 1.4571*X_008**2-1.5858*X_008+0.3395
#print(YY3_EXP_AM008)
#YY3_EXP_AM014 = 1.4571*X_014**2-1.5858*X_014+0.3395
#print(YY3_EXP_AM014)

# EQUAÇÃO - YY3_CS

# Coeficientes da equação quadrática ax^2 + bx + c = 0
ayy3_EXP_AM = 1.4571
byy3_EXP_AM = -1.5858
cyy3_EXP_AM = 0.3395
print(cyy3_EXP_AM)

# Calcular o discriminante
deltayy3_EXP_AM = byy3_EXP_AM**2 - 4*ayy3_EXP_AM*cyy3_EXP_AM

# Verificar a natureza das raízes
if deltayy3_EXP_AM > 0:
    x1yy3_EXP_AM = (-byy3_EXP_AM + math.sqrt(deltayy3_EXP_AM)) / (2*ayy3_EXP_AM)
    x2yy3_EXP_AM = (-byy3_EXP_AM - math.sqrt(deltayy3_EXP_AM)) / (2*ayy3_EXP_AM)
    print(f"Raízes reais: x1 = {x1yy3_EXP_AM}, x2 = {x2yy3_EXP_AM}")
elif deltayy3_EXP_AM == 0:
    x = -byy3_EXP_AM / (2*ayy3_EXP_AM)
    print(f"Raiz real dupla: x = {x}")
else:
    parte_realYY3_EXP_AM = -byy3_EXP_AM / (2*ayy3_AM)
    print(parte_realYY3_AM)
    #parte_imaginaria = math.sqrt(abs(delta)) / (2*a)
    #print(f"Raízes complexas conjugadas: {parte_real} + {parte_imaginaria}j e {parte_real} - {parte_imaginaria}j")
# Out:
# 0.3395
# Raízes reais: x1 = 0.7953928207641846, x2 = 0.29293330647485183

# %%
# CALCULO ESPESSURA - AMERÍCIO 241 - 59.5
###################################################################################
# AJUSTE EQUAÇÕES - AM-241(59.5 KEV)
###################################################################################
# lN(I/I0) X ESPESSURA - INVERSO
###################################################################################


"EQUAÇÃO EXPONENCIAL"
#############################################################
# CERTO

# NÃO #
# Out:
# 'EQUAÇÃO EXPONENCIAL'

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N1 = len(x1)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals1 = y1 - (a1 * x1 + b1)


# Dados de exemplo
x1 = np.array([0.2, 0.8, 1.4])
y1 = np.array([0.00327367, -0.0939783,  -0.13925964])

#media de x
mean_x=np.mean(x1)

#media de y
mean_y=np.mean(y1)

# Variância de x
var_x = np.var(x1, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y1, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x1, y1, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a1 = cov_xy/var_x
print(a1)
b1 = mean_y - a1 * mean_x
print(b1)

# Desvio padrão de x e y
sd_x = np.std(x1, ddof=1)
print(sd_x)
sd_y = np.std(y1, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_1 = a1*sd_x/sd_y
print(f'Ceficiente de Pearson (R_1): {R_1}')
RR_1 = np.abs(R_1)
print(f'Ceficiente de Pearson (RR_1): {RR_1}')

# Resíduos
residuals1 = y1 - (a1 * x1 + b1)

# Número de observações
N1 = len(x1)

# Erro padrão residual (epsilon1)
epsilon1_1 = np.sqrt(np.sum(residuals1**2) / (N1 - 2))
print(epsilon1_1)

# Desvio padrão de x
# sd_x = np.std(x1, ddof=1)
# print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a1 = epsilon1_1 / (sd_x * np.sqrt(N1))
print(error_a1)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_1 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_1}")
MODabs_eps2eps2_1 = np.abs(eps2eps2_1)
print(f'valor absoluto de eps2eps2: {eps2eps2_1}')
NN1=(N1 / (N1 - 2))
print(f"NN: {NN1}")
epsilon2_1 = np.sqrt(NN1 * MODabs_eps2eps2_1)
print(f"epsilon2: {epsilon2_1}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb1=np.mean(x1**2)
print(bb1)
error_b1 = error_a1 * np.sqrt(bb1)
print(error_b1)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a1}')
print(f'Coeficiente linear (b): {b1}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_1}')
print(f'Erro padrão residual (epsilon2): {epsilon2_1}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a1}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b1}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N2 = len(x2)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals2 = y2 - (a2 * x2 + b2)


# Dados de exemplo
x2 = np.array([0.2, 0.8, 1.4])
y2 = np.array([-0.00327367,  0.0939783,   0.13925964])

#media de x
mean_x=np.mean(x2)

#media de y
mean_y=np.mean(y2)

# Variância de x
var_x = np.var(x2, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y2, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x2, y2, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a2 = cov_xy/var_x
print(a2)
b2 = mean_y - a2 * mean_x
print(b2)

# Desvio padrão de x e y
sd_x = np.std(x2, ddof=1)
print(sd_x)
sd_y = np.std(y2, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_2 = a2*sd_x/sd_y
print(f'Ceficiente de Pearson (R_2): {R_2}')
RR_2 = np.abs(R_2)
print(f'Ceficiente de Pearson (RR_2): {RR_2}')

# Resíduos
residuals2 = y2 - (a2 * x2 + b2)

# Número de observações
N2 = len(x2)

# Erro padrão residual (epsilon1)
epsilon1_2 = np.sqrt(np.sum(residuals2**2) / (N2 - 2))
print(epsilon1_2)

# Desvio padrão de x e y
#sd_x = np.std(x2, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a2 = epsilon1_2 / (sd_x * np.sqrt(N2))
print(error_a2)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_2 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_2}")
MODabs_eps2eps2_2 = np.abs(eps2eps2_2)
print(f'valor absoluto de eps2eps2: {eps2eps2_2}')
NN2=(N2 / (N2 - 2))
print(f"NN: {NN2}")
epsilon2_2 = np.sqrt(NN2 * MODabs_eps2eps2_2)
print(f"epsilon2: {epsilon2_2}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb2=np.mean(x2**2)
print(bb2)
error_b2 = error_a2 * np.sqrt(bb2)
print(error_b2)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a2}')
print(f'Coeficiente linear (b): {b2}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_2}')
print(f'Erro padrão residual (epsilon2): {epsilon2_2}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a2}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b2}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N3 = len(x3)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals3 = y3 - (a3 * x3 + b3)


# Dados de exemplo
x3 = np.array([0.2, 0.8, 1.4])
y3 = np.array([-0.08060403, -0.00337268, -0.97523327])

#media de x
mean_x=np.mean(x3)

#media de y
mean_y=np.mean(y3)

# Variância de x
var_x = np.var(x3, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y3, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x3, y3, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a3 = cov_xy/var_x
print(a3)
b3 = mean_y - a3 * mean_x
print(b3)

# Desvio padrão de x e y
sd_x = np.std(x3, ddof=1)
print(sd_x)
sd_y = np.std(y3, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_3 = a3*sd_x/sd_y
print(f'Ceficiente de Pearson (R_3): {R_3}')
RR_3 = np.abs(R_3)
print(f'Ceficiente de Pearson (RR_3): {RR_3}')

# Resíduos
residuals3 = y3 - (a3 * x3 + b3)

# Número de observações
N3 = len(x3)

# Erro padrão residual (epsilon1)
epsilon1_3 = np.sqrt(np.sum(residuals3**2) / (N3 - 2))
print(epsilon1_3)

# Desvio padrão de x
#sd_x = np.std(x3, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a3 = epsilon1_3 / (sd_x * np.sqrt(N3))
print(error_a3)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_3 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_3}")
MODabs_eps2eps2_3 = np.abs(eps2eps2_3)
print(f'valor absoluto de eps2eps2: {eps2eps2_3}')
NN3=(N3 / (N3 - 2))
print(f"NN: {NN3}")
epsilon2_3 = np.sqrt(NN3 * MODabs_eps2eps2_3)
print(f"epsilon2: {epsilon2_3}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb3=np.mean(x3**2)
print(bb3)
error_b3 = error_a3 * np.sqrt(bb3)
print(error_b3)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a3}')
print(f'Coeficiente linear (b): {b3}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_3}')
print(f'Erro padrão residual (epsilon2): {epsilon2_3}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a3}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b3}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N4 = len(x4)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals4 = y4 - (a4 * x4 + b4)


# Dados de exemplo
x4 = np.array([0.2, 0.8, 1.4])
y4 = np.array([0.08060403, 0.00337268, 0.97523327])

#media de x
mean_x=np.mean(x4)

#media de y
mean_y=np.mean(y4)

# Variância de x
var_x = np.var(x4, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y4, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x4, y4, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a4 = cov_xy/var_x
print(a4)
b4 = mean_y - a4 * mean_x
print(b4)

# Desvio padrão de x e y
sd_x = np.std(x4, ddof=1)
print(sd_x)
sd_y = np.std(y4, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_4 = a4*sd_x/sd_y
print(f'Ceficiente de Pearson (R_4): {R_4}')
RR_4 = np.abs(R_4)
print(f'Ceficiente de Pearson (RR_4): {RR_4}')

# Resíduos
residuals4 = y4 - (a4 * x4 + b4)

# Número de observações
N4 = len(x4)

# Erro padrão residual (epsilon1)
epsilon1_4 = np.sqrt(np.sum(residuals4**2) / (N4 - 2))
print(epsilon1_4)

# Desvio padrão de x
#sd_x = np.std(x4, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a4 = epsilon1_4 / (sd_x * np.sqrt(N4))
print(error_a4)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_4 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_4}")
MODabs_eps2eps2_4 = np.abs(eps2eps2_4)
print(f'valor absoluto de eps2eps2: {eps2eps2_4}')
NN4=(N4 / (N4 - 2))
print(f"NN: {NN4}")
epsilon2_4 = np.sqrt(NN4 * MODabs_eps2eps2_4)
print(f"epsilon2: {epsilon2_4}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb4=np.mean(x4**2)
print(bb4)
error_b4 = error_a4 * np.sqrt(bb4)
print(error_b4)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a4}')
print(f'Coeficiente linear (b): {b4}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_4}')
print(f'Erro padrão residual (epsilon2): {epsilon2_4}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a4}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b4}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N5 = len(x5)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals5 = y5 - (a5 * x5 + b5)


# Dados de exemplo
x5 = np.array([0.2, 0.8, 1.4])
y5 = np.array([0.020636934987259128, 0.08935677381232772, 0.15670352113437905])

#media de x
mean_x=np.mean(x5)

#media de y
mean_y=np.mean(y5)

# Variância de x
var_x = np.var(x5, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y5, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x5, y5, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a5 = cov_xy/var_x
print(a5)
b5 = mean_y - a5 * mean_x
print(b5)

# Desvio padrão de x e y
sd_x = np.std(x5, ddof=1)
print(sd_x)
sd_y = np.std(y5, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_5 = a5*sd_x/sd_y
print(f'Ceficiente de Pearson (R_5): {R_5}')
RR_5 = np.abs(R_5)
print(f'Ceficiente de Pearson (RR_5): {RR_5}')

# Resíduos
residuals5 = y5 - (a5 * x5 + b5)

# Número de observações
N5 = len(x5)

# Erro padrão residual (epsilon1)
epsilon1_5 = np.sqrt(np.sum(residuals5**2) / (N5 - 2))
print(epsilon1_5)

# Desvio padrão de x
#sd_x = np.std(x5, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a5 = epsilon1_5 / (sd_x * np.sqrt(N5))
print(error_a5)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_5 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_5}")
MODabs_eps2eps2_5 = np.abs(eps2eps2_5)
print(f'valor absoluto de eps2eps2: {eps2eps2_5}')
NN5=(N5 / (N5 - 2))
print(f"NN: {NN5}")
epsilon2_5 = np.sqrt(NN5 * MODabs_eps2eps2_5)
print(f"epsilon2: {epsilon2_5}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb5=np.mean(x5**2)
print(bb5)
error_b5 = error_a5 * np.sqrt(bb5)
print(error_b5)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a5}')
print(f'Coeficiente linear (b): {b5}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_5}')
print(f'Erro padrão residual (epsilon2): {epsilon2_5}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a5}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b5}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N6 = len(x6)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals6 = y6 - (a6 * x6 + b6)


# Dados de exemplo
x6 = np.array([0.2, 0.8, 1.4])
y6 = np.array([-0.020636934987259024, -0.08935677381232765, -0.1567035211343791])

#media de x
mean_x=np.mean(x6)

#media de y
mean_y=np.mean(y6)

# Variância de x
var_x = np.var(x6, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y6, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x6, y6, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a6 = cov_xy/var_x
print(a6)
b6 = mean_y - a6 * mean_x
print(b6)

# Desvio padrão de x e y
sd_x = np.std(x6, ddof=1)
print(sd_x)
sd_y = np.std(y6, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_6 = a6*sd_x/sd_y
print(f'Ceficiente de Pearson (R_6): {R_6}')
RR_6 = np.abs(R_6)
print(f'Ceficiente de Pearson (RR_6): {RR_6}')

# Resíduos
residuals6 = y6 - (a6 * x6 + b6)

# Número de observações
N6 = len(x6)

# Erro padrão residual (epsilon1)
epsilon1_6 = np.sqrt(np.sum(residuals6**2) / (N6 - 2))
print(epsilon1_6)

# Desvio padrão de x
#sd_x = np.std(x6, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a6 = epsilon1_6 / (sd_x * np.sqrt(N6))
print(error_a6)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_6 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_6}")
MODabs_eps2eps2_6 = np.abs(eps2eps2_6)
print(f'valor absoluto de eps2eps2: {eps2eps2_6}')
NN6=(N6 / (N6 - 2))
print(f"NN: {NN6}")
epsilon2_6 = np.sqrt(NN6 * MODabs_eps2eps2_6)
print(f"epsilon2: {epsilon2_6}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb6=np.mean(x6**2)
print(bb6)
error_b6 = error_a6 * np.sqrt(bb6)
print(error_b6)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a6}')
print(f'Coeficiente linear (b): {b6}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_6}')
print(f'Erro padrão residual (epsilon2): {epsilon2_6}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a6}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b6}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N7 = len(x7)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals7 = y7 - (a7 * x7 + b7)


# Dados de exemplo
x7 = np.array([0.2, 0.8, 1.4])
y7 = np.array([0.05231155432318324, 0.20971258664407322, 0.3675033001833097])
#media de x
mean_x=np.mean(x7)

#media de y
mean_y=np.mean(y7)

# Variância de x
var_x = np.var(x7, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y7, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x7, y7, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a7 = cov_xy/var_x
print(a7)
b7 = mean_y - a7 * mean_x
print(b7)

# Desvio padrão de x e y
sd_x = np.std(x7, ddof=1)
print(sd_x)
sd_y = np.std(y7, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_7 = a7*sd_x/sd_y
print(f'Ceficiente de Pearson (R_7): {R_7}')
RR_7 = np.abs(R_7)
print(f'Ceficiente de Pearson (RR_7): {RR_7}')

# Resíduos
residuals7 = y7 - (a7 * x7 + b7)

# Número de observações
N7 = len(x7)

# Erro padrão residual (epsilon1)
epsilon1_7 = np.sqrt(np.sum(residuals7**2) / (N7 - 2))
print(epsilon1_7)

# Desvio padrão de x
#sd_x = np.std(x7, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a7 = epsilon1_7 / (sd_x * np.sqrt(N7))
print(error_a7)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_7 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_7}")
MODabs_eps2eps2_7 = np.abs(eps2eps2_7)
print(f'valor absoluto de eps2eps2: {eps2eps2_7}')
NN7=(N7 / (N7 - 2))
print(f"NN: {NN7}")
epsilon2_7 = np.sqrt(NN7 * MODabs_eps2eps2_7)
print(f"epsilon2: {epsilon2_7}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb7=np.mean(x7**2)
print(bb7)
error_b7 = error_a7 * np.sqrt(bb7)
print(error_b7)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a7}')
print(f'Coeficiente linear (b): {b7}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_7}')
print(f'Erro padrão residual (epsilon2): {epsilon2_7}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a7}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b7}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N8 = len(x8)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals8 = y8 - (a8 * x8 + b8)


# Dados de exemplo
x8 = np.array([0.2, 0.8, 1.4])
y8 = np.array([-0.05231155432318328, -0.20971258664407325, -0.36750330018330973])
#media de x
mean_x=np.mean(x8)

#media de y
mean_y=np.mean(y8)

# Variância de x
var_x = np.var(x8, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y8, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x8, y8, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a8 = cov_xy/var_x
print(a8)
b8 = mean_y - a8 * mean_x
print(b8)

# Desvio padrão de x e y
sd_x = np.std(x8, ddof=1)
print(sd_x)
sd_y = np.std(y8, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_8 = a8*sd_x/sd_y
print(f'Ceficiente de Pearson (R_8): {R_8}')
RR_8 = np.abs(R_8)
print(f'Ceficiente de Pearson (RR_8): {RR_8}')

# Resíduos
residuals8 = y8 - (a8 * x8 + b8)

# Número de observações
N8 = len(x8)

# Erro padrão residual (epsilon1)
epsilon1_8 = np.sqrt(np.sum(residuals8**2) / (N8 - 2))
print(epsilon1_8)

# Desvio padrão de x
#sd_x = np.std(x8, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a8 = epsilon1_8 / (sd_x * np.sqrt(N8))
print(error_a8)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_8 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_8}")
MODabs_eps2eps2_8 = np.abs(eps2eps2_8)
print(f'valor absoluto de eps2eps2: {eps2eps2_8}')
NN8=(N8 / (N8 - 2))
print(f"NN: {NN8}")
epsilon2_8 = np.sqrt(NN8 * MODabs_eps2eps2_8)
print(f"epsilon2: {epsilon2_8}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb8=np.mean(x8**2)
print(bb8)
error_b8 = error_a8 * np.sqrt(bb8)
print(error_b8)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a8}')
print(f'Coeficiente linear (b): {b8}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_8}')
print(f'Erro padrão residual (epsilon2): {epsilon2_8}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a8}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b8}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N9 = len(x9)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals9 = y9 - (a9 * x9 + b9)


# Dados de exemplo
x9 = np.array([0.2, 0.8, 1.4])
y9 = np.array([0.04908773893728773, 0.07504677810738393, 0.18012225136322313])
#media de x
mean_x=np.mean(x9)

#media de y
mean_y=np.mean(y9)

# Variância de x
var_x = np.var(x9, ddof=1)
print(var_x)

# Variância de y
var_y = np.var(y9, ddof=1)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x9, y9, ddof=1)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a9 = cov_xy/var_x
print(a9)
b9 = mean_y - a9 * mean_x
print(b9)

# Desvio padrão de x e y
sd_x = np.std(x9, ddof=1)
print(sd_x)
sd_y = np.std(y9, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_9 = a9*sd_x/sd_y
print(f'Ceficiente de Pearson (R_9): {R_9}')
RR_9 = np.abs(R_9)
print(f'Ceficiente de Pearson (RR_9): {RR_9}')

# Resíduos
residuals9 = y9 - (a9 * x9 + b9)

# Número de observações
N9 = len(x9)

# Erro padrão residual (epsilon1)
epsilon1_9 = np.sqrt(np.sum(residuals9**2) / (N9 - 2))
print(epsilon1_9)

# Desvio padrão de x
#sd_x = np.std(x9, ddof=1)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a9 = epsilon1_9 / (sd_x * np.sqrt(N9))
print(error_a9)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_9 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_9}")
MODabs_eps2eps2_9 = np.abs(eps2eps2_9)
print(f'valor absoluto de eps2eps2: {eps2eps2_9}')
NN9=(N9 / (N9 - 2))
print(f"NN: {NN9}")
epsilon2_9 = np.sqrt(NN9 * MODabs_eps2eps2_9)
print(f"epsilon2: {epsilon2_9}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb9=np.mean(x9**2)
print(bb9)
error_b9 = error_a9 * np.sqrt(bb9)
print(error_b9)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a9}')
print(f'Coeficiente linear (b): {b9}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_9}')
print(f'Erro padrão residual (epsilon2): {epsilon2_9}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a9}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b9}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N10 = len(x10)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals10 = y10 - (a10 * x10 + b10)


# Dados de exemplo
x10 = np.array([0.2, 0.8, 1.4])
y10 = np.array([-0.04908773893728771, -0.07504677810738386, -0.18012225136322318])

#media de x
mean_x=np.mean(x10)

#media de y
mean_y=np.mean(y10)

# Variância de x
var_x = np.var(x10, ddof=0)
print(var_x)

# Variância de y
var_y = np.var(y10, ddof=0)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x10, y10, ddof=0)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a10 = cov_xy/var_x
print(a10)
b10 = mean_y - a10 * mean_x
print(b10)

# Desvio padrão de x e y
sd_x = np.std(x10, ddof=1)
print(sd_x)
sd_y = np.std(y10, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_10 = a10*sd_x/sd_y
print(f'Ceficiente de Pearson (R_10): {R_10}')
RR_10 = np.abs(R_10)
print(f'Ceficiente de Pearson (RR_10): {RR_10}')

# Resíduos
residuals10 = y10 - (a10 * x10 + b10)

# Número de observações
N10 = len(x10)

# Erro padrão residual (epsilon1)
epsilon1_10 = np.sqrt(np.sum(residuals10**2) / (N10 - 2))
print(epsilon1_10)

# Desvio padrão de x
#sd_x = np.std(x10, ddof=0)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a10 = epsilon1_10 / (sd_x * np.sqrt(N10))
print(error_a10)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_10 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_10}")
MODabs_eps2eps2_10 = np.abs(eps2eps2_10)
print(f'valor absoluto de eps2eps2: {eps2eps2_10}')
NN10=(N10 / (N10 - 2))
print(f"NN: {NN10}")
epsilon2_10 = np.sqrt(NN10 * MODabs_eps2eps2_10)
print(f"epsilon2: {epsilon2_10}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb10=np.mean(x10**2)
print(bb10)
error_b10 = error_a10 * np.sqrt(bb10)
print(error_b10)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a10}')
print(f'Coeficiente linear (b): {b10}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_10}')
print(f'Erro padrão residual (epsilon2): {epsilon2_10}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a10}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b10}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N11 = len(x11)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals11 = y11 - (a11 * x11 + b11)


# Dados de exemplo
x11 = np.array([0.2, 0.8, 1.4])
y11 = np.array([-0.05856915500990832, -0.17804212924351606, -0.2952789689526551])

#media de x
mean_x=np.mean(x11)

#media de y
mean_y=np.mean(y11)

# Variância de x
var_x = np.var(x11, ddof=0)
print(var_x)

# Variância de y
var_y = np.var(y11, ddof=0)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x11, y11, ddof=0)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a11 = cov_xy/var_x
print(a11)
b11 = mean_y - a11 * mean_x
print(b11)

# Desvio padrão de x e y
sd_x = np.std(x11, ddof=1)
print(sd_x)
sd_y = np.std(y11, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_11 = a11*sd_x/sd_y
print(f'Ceficiente de Pearson (R_11): {R_11}')
RR_11 = np.abs(R_11)
print(f'Ceficiente de Pearson (RR_11): {RR_11}')

# Resíduos
residuals11 = y11 - (a11 * x11 + b11)

# Número de observações
N11 = len(x11)

# Erro padrão residual (epsilon1)
epsilon1_11 = np.sqrt(np.sum(residuals11**2) / (N11 - 2))
print(epsilon1_11)

# Desvio padrão de x
#sd_x = np.std(x11, ddof=0)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a11 = epsilon1_11 / (sd_x * np.sqrt(N11))
print(error_a11)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_11 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_11}")
MODabs_eps2eps2_11 = np.abs(eps2eps2_11)
print(f'valor absoluto de eps2eps2: {eps2eps2_11}')
NN11=(N11 / (N11 - 2))
print(f"NN: {NN11}")
epsilon2_11 = np.sqrt(NN11 * MODabs_eps2eps2_11)
print(f"epsilon2: {epsilon2_11}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb11=np.mean(x11**2)
print(bb11)
error_b11 = error_a11 * np.sqrt(bb11)
print(error_b11)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a11}')
print(f'Coeficiente linear (b): {b11}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_11}')
print(f'Erro padrão residual (epsilon2): {epsilon2_11}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a11}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b11}')

# %%
import numpy as np

def linear_regression(x, y):


    # Calcular o número de pontos de dados
    N12 = len(x12)

    
     # Calcular os resíduos (diferenças entre os valores observados e preditos)
    residuals12 = y12 - (a12 * x12 + b12)


# Dados de exemplo
x12 = np.array([0.2, 0.8, 1.4])
y12 = np.array([0.00327367, -0.0939783,  -0.13925964])

#media de x
mean_x=np.mean(x12)

#media de y
mean_y=np.mean(y12)

# Variância de x
var_x = np.var(x12, ddof=0)
print(var_x)

# Variância de y
var_y = np.var(y12, ddof=0)
print(var_y)

# Covariância entre x e y
cov_xy = np.cov(x12, y12, ddof=0)[0, 1]
print(cov_xy)

# Calcular os coeficientes da regressão linear
    
##a = np.cov(x, y)[0, 1] / np.var(x)##
a12 = cov_xy/var_x
print(a12)
b12 = mean_y - a12 * mean_x
print(b12)

# Desvio padrão de x e y
sd_x = np.std(x12, ddof=1)
print(sd_x)
sd_y = np.std(y12, ddof=1)
print(sd_y)

# Coeficiente de Pearson - R

#sd_y=np.std(y1, ddof=0)
#print(sd_y)
R_12 = a12*sd_x/sd_y
print(f'Ceficiente de Pearson (R_12): {R_12}')
RR_12 = np.abs(R_12)
print(f'Ceficiente de Pearson (RR_12): {RR_12}')

# Resíduos
residuals12 = y12 - (a12 * x12 + b12)

# Número de observações
N12 = len(x12)

# Erro padrão residual (epsilon1)
epsilon1_12 = np.sqrt(np.sum(residuals12**2) / (N12 - 2))
print(epsilon1_12)

# Desvio padrão de x
#sd_x = np.std(x12, ddof=0)
#print(sd_x)

# Erro padrão do coeficiente angular (error_a)
error_a12 = epsilon1_12 / (sd_x * np.sqrt(N12))
print(error_a12)

# Erro padrão do coeficiente angular (epsilon2)
eps2eps2_12 = (var_y - (cov_xy**2) / (var_x))
print(f"eps2eps2: {eps2eps2_12}")
MODabs_eps2eps2_12 = np.abs(eps2eps2_12)
print(f'valor absoluto de eps2eps2: {eps2eps2_12}')
NN12=(N12 / (N12 - 2))
print(f"NN: {NN12}")
epsilon2_12 = np.sqrt(NN12 * MODabs_eps2eps2_12)
print(f"epsilon2: {epsilon2_12}")
#epsilon2 = np.sqrt((N / (N - 2)) * (var_y - (cov_xy**2) / np.var(x)))
#print(epsilon2)

# Erro padrão do coeficiente linear (error_b)

bb12=np.mean(x12**2)
print(bb12)
error_b12 = error_a12 * np.sqrt(bb12)
print(error_b12)

# Imprimindo os resultados

print(f'Coeficiente angular (a): {a12}')
print(f'Coeficiente linear (b): {b12}')

#print(f"Erro associado ao coeficiente angular: {error_a}")

print(f'Erro padrão residual (epsilon1): {epsilon1_12}')
print(f'Erro padrão residual (epsilon2): {epsilon2_12}')
print(f'Erro associado ao coeficiente angular (error_a): {error_a12}')
print(f'Erro associado ao coeficiente linear (error_b): {error_b12}')

# %%
############################################################################################
# RASCUNHO #
############################################################################################

# %%
print(PICO1_PLACS002_0662)
print(PICO1_PLACS008_0662)
print(PICO1_PLACS014_0662)
print(INVPICO1_PLACS002_0662)
print(INVPICO1_PLACS008_0662)
print(INVPICO1_PLACS014_0662)
print(PICO1_PLAAM002_00595)
print(PICO1_PLAAM008_00595)
print(PICO1_PLAAM014_00595)
print(INVPICO1_PLAAM002_00595)
print(INVPICO1_PLAAM008_00595)
print(INVPICO1_PLAAM014_00595)
print(PICO1_PLACS002_PBEAM0662)
print(PICO1_PLACS008_PBEAM0662)
print(PICO1_PLACS014_PBEAM0662)
print(INVPICO1_PLACS002_PBEAM0662)
print(INVPICO1_PLACS008_PBEAM0662)
print(INVPICO1_PLACS014_PBEAM0662)
print(PICO1_PLAAM002_PBEAM00595)
print(PICO1_PLAAM008_PBEAM00595)
print(PICO1_PLAAM014_ISO00595)
print(INVPICO1_PLAAM002_PBEAM00595)
print(INVPICO1_PLAAM008_PBEAM00595)
print(INVPICO1_PLAAM014_PBEAM00595)
print(PICO1_PLACS002_ISO0662)
print(PICO1_PLACS008_ISO0662)
print(PICO1_PLACS014_ISO0662)
print(INVPICO1_PLACS002_ISO0662)
print(INVPICO1_PLACS008_ISO0662)
print(INVPICO1_PLACS014_ISO0662)
print(PICO1_PLAAM002_ISO00595)
print(PICO1_PLAAM008_ISO00595)
print(PICO1_PLAAM014_ISO00595)
print(INVPICO1_PLAAM002_ISO00595)
print(INVPICO1_PLAAM008_ISO00595)
print(INVPICO1_PLAAM014_ISO00595)

# %%
# DADOS EXPERIMENTAIS #
yCS137_EXP0662 = [PICO1_PLACS002_0662, PICO1_PLACS008_0662, PICO1_PLACS014_0662]
print(yCS137_EXP0662)

yyCS137_EXP0662 = [INVPICO1_PLACS002_0662, INVPICO1_PLACS008_0662, INVPICO1_PLACS014_0662]
print(yyCS137_EXP0662)

yAM241_EXP00595 = [PICO1_PLAAM002_00595, PICO1_PLAAM008_00595, PICO1_PLAAM014_00595]
print(yAM241_EXP00595)

yyAM241_EXP00595 = [INVPICO1_PLAAM002_00595, INVPICO1_PLAAM008_00595, INVPICO1_PLAAM014_00595]
print(yyAM241_EXP00595)

yCS137_PBEAM0662 = [PICO1_PLACS002_PBEAM0662, PICO1_PLACS008_PBEAM0662, PICO1_PLACS014_PBEAM0662]
print(yCS137_PBEAM0662)

yyCS137_PBEAM0662 = [PICO1_PLACS002_PBEAM0662, PICO1_PLACS008_PBEAM0662, PICO1_PLACS014_PBEAM0662]
print(yCS137_PBEAM0662)

yAM241_PBEAM00595 = [PICO1_PLAAM002_PBEAM00595, PICO1_PLAAM008_PBEAM00595, PICO1_PLAAM014_PBEAM00595]
print(yAM241_PBEAM00595)

yyAM241_PBEAM00595 = [INVPICO1_PLAAM002_PBEAM00595, INVPICO1_PLAAM008_PBEAM00595, INVPICO1_PLAAM014_PBEAM00595]
print(yyAM241_PBEAM00595)

yCS137_ISO0662 = [PICO1_PLACS002_ISO0662, PICO1_PLACS008_ISO0662, PICO1_PLACS014_ISO0662]
print(yCS137_ISO0662)

yyCS137_ISO0662 = [INVPICO1_PLACS002_ISO0662, INVPICO1_PLACS008_ISO0662, INVPICO1_PLACS014_ISO0662]
print(yyCS137_ISO0662)

yAM241_ISO00595 = [PICO1_PLAAM002_ISO00595, PICO1_PLAAM008_ISO00595, PICO1_PLAAM014_ISO00595]
print(yAM241_ISO00595)

yyAM241_ISO00595 =[INVPICO1_PLAAM002_ISO00595, INVPICO1_PLAAM008_ISO00595, INVPICO1_PLAAM014_ISO00595]
print(yyAM241_ISO00595)

# %%
# DADOS EXPERIMENTAIS #
ln_yCS137_EXP0662 = np.log(yCS137_EXP0662)
print(ln_yCS137_EXP0662)

ln_yyCS137_EXP0662 = np.log(yyCS137_EXP0662)
print(ln_yyCS137_EXP0662)

ln_yAM241_00595 = np.log(yAM241_EXP00595)
print(ln_yAM241_00595)

ln_yyAM241_00595 = np.log(yyAM241_EXP00595)
print(ln_yyAM241_00595)

# %%
# DADOS EXPERIMENTAIS #
ln_yCS137_EXP0662 = np.log(yCS137_EXP0662)
print(ln_yCS137_EXP0662)

ln_yyCS137_EXP0662 = np.log(yyCS137_EXP0662)
print(ln_yyCS137_EXP0662)

ln_yAM241_00595 = np.log(yAM241_EXP00595)
print(ln_yAM241_00595)

ln_yyAM241_00595 = np.log(yyAM241_EXP00595)
print(ln_yyAM241_00595)

# %%
# DADOS

# %%
#print(ln_yCS_0662)
#print(ln_yyCS_0662)
#print(ln_yAM_00595)
#print(ln_yyAM_00595)
#print(ln_PBEAMyCS137_0662)
#print(ln_INVPBEAMyCS137_0662)
#print(ln_PBEAMyAM_00595)
#print(ln_INVPBEAMyAM241_00595)
#print(ln_ISOyCS137_0662)
#print(ln_INVISOyCS137_0662)
#print(ln_ISOyAM241_00595)
#print(ln_INVISOyAM241_00595)

# %%
#  DADOS - EXPERIMENTAL

#CONTEXP000_CS137_0662 = 9454
#CONTEXP002_CS137_0662 = 9485
#CONTEXP008_CS137_0662 = 8606
#CONTEXP014_CS137_0662 = 8225
#CONTEXP000_AM241_00595 = 594
#CONTEXP002_AM241_00595 = 548
#CONTEXP008_AM241_00595 = 592
#CONTEXP014_AM241_00595 = 224

# DADOS - TEORIA (PENCIL-BEAM)

#CONTPBEAM000_CS137_0662 = 4403330
#CONTPBEAM002_CS137_0662 = 4313390
#CONTPBEAM008_CS137_0662 = 4026930
#CONTPBEAM014_CS137_0662 = 3764660
#CONTPBEAM000_AM241_00595 = 8056020
#CONTPBEAM002_AM241_00595 = 7645430
#CONTPBEAM008_AM241_00595 = 6531960
#CONTPBEAM014_AM241_00595 = 5578480

# DADOS - TEORIA (ISOTRÓPICO)

#CONTISO000_CS137_0662 = 3361
#CONTISO002_CS137_0662 = 3200
#CONTISO008_CS137_0662 = 3118
#CONTISO014_CS137_0662 = 2807
#CONTISO000_AM241_00595 = 7928
#CONTISO002_AM241_00595 = 7477
#CONTISO008_AM241_00595 = 6635
#CONTISO014_AM241_00595 = 5901

# %%
# DADOS - TEORIA (PENCIL-BEAM)

print(CONTPBEAM000_CS137_0662)
print(CONTPBEAM002_CS137_0662)
print(CONTPBEAM008_CS137_0662)
print(CONTPBEAM014_CS137_0662)
print(CONTPBEAM000_AM241_00595)
print(CONTPBEAM002_AM241_00595)
print(CONTPBEAM008_AM241_00595)
print(CONTPBEAM014_AM241_00595)

# DADOS - TEORIA (ISOTRÓPICO)

print(CONTISO000_CS137_0662)
print(CONTISO002_CS137_0662)
print(CONTISO008_CS137_0662)
print(CONTISO014_CS137_0662)
print(CONTISO000_AM241_00595)
print(CONTISO002_AM241_00595)
print(CONTISO008_AM241_00595)
print(CONTISO014_AM241_00595)

# %%
print(PICO1_PLACS002_0662)
print(PICO1_PLACS008_0662)
print(PICO1_PLACS014_0662)
print(INVPICO1_PLACS002_0662)
print(INVPICO1_PLACS008_0662)
print(INVPICO1_PLACS014_0662)
print(PICO1_PLAAM002_00595)
print(PICO1_PLAAM008_00595)
print(PICO1_PLAAM014_00595)
print(INVPICO1_PLAAM002_00595)
print(INVPICO1_PLAAM008_00595)
print(INVPICO1_PLAAM014_00595)
print(PICO1_PLACS002_PBEAM0662)
print(PICO1_PLACS008_PBEAM0662)
print(PICO1_PLACS014_PBEAM0662)
print(INVPICO1_PLACS002_PBEAM0662)
print(INVPICO1_PLACS008_PBEAM0662)
print(INVPICO1_PLACS014_PBEAM0662)
print(PICO1_PLAAM002_PBEAM00595)
print(PICO1_PLAAM008_PBEAM00595)
print(PICO1_PLAAM014_ISO00595)
print(INVPICO1_PLAAM002_PBEAM00595)
print(INVPICO1_PLAAM008_PBEAM00595)
print(INVPICO1_PLAAM014_PBEAM00595)
print(PICO1_PLACS002_ISO0662)
print(PICO1_PLACS008_ISO0662)
print(PICO1_PLACS014_ISO0662)
print(INVPICO1_PLACS002_ISO0662)
print(INVPICO1_PLACS008_ISO0662)
print(INVPICO1_PLACS014_ISO0662)
print(PICO1_PLAAM002_ISO00595)
print(PICO1_PLAAM008_ISO00595)
print(PICO1_PLAAM014_ISO00595)
print(INVPICO1_PLAAM002_ISO00595)
print(INVPICO1_PLAAM008_ISO00595)
print(INVPICO1_PLAAM014_ISO00595)

# %%
FONTEPBEAM_CS137AM241 = pd.read_excel('C:/Users/T-Gamer/Desktop/Nova pasta (7)/FIMCESAR.xlsx')
FONTEPBEAM_CS137AM241.head()

# %%
# CALCULO FEIXE PENCIL BEAM

# %%
#CS-137 (PENCIL BEAM)

PICOPBEAM_PLACS002_0662 = CONTPBEAM000_CS137_0662/CONTPBEAM002_CS137_0662
print(PICOPBEAM_PLACS002_0662)

INVPICOPBEAM_PLACS002_0662 = CONTPBEAM002_CS137_0662/CONTPBEAM000_CS137_0662
print(INVPICOPBEAM_PLACS002_0662)

PICOPBEAM_PLACS008_0662 = CONTPBEAM000_CS137_0662/CONTPBEAM008_CS137_0662
print(PICOPBEAM_PLACS008_0662)

INVPICOPBEAM_PLACS008_0662 = CONTPBEAM008_CS137_0662/CONTPBEAM000_CS137_0662
print(INVPICOPBEAM_PLACS008_0662)

PICOPBEAM_PLACS014_0662 = CONTPBEAM000_CS137_0662/CONTPBEAM014_CS137_0662
print(PICOPBEAM_PLACS014_0662)

INVPICOPBEAM_PLACS014_0662 = CONTPBEAM014_CS137_0662/CONTPBEAM000_CS137_0662
print(INVPICOPBEAM_PLACS014_0662)

# %%
#AM-241 (PENCIL BEAM)

PICOPBEAM_PLAAM002_00595 = CONTPBEAM000_AM241_00595/CONTPBEAM002_AM241_00595
print(PICOPBEAM_PLAAM002_00595)

INVPICOPBEAM_PLAAM002_00595 = CONTPBEAM002_AM241_00595/CONTPBEAM000_AM241_00595
print(INVPICOPBEAM_PLAAM002_00595)

PICOPBEAM_PLAAM008_00595 = CONTPBEAM000_AM241_00595/CONTPBEAM008_AM241_00595
print(PICOPBEAM_PLAAM008_00595)

INVPICOPBEAM_PLAAM008_00595 = CONTPBEAM008_AM241_00595/CONTPBEAM000_AM241_00595
print(INVPICOPBEAM_PLAAM008_00595)

PICOPBEAM_PLAAM014_00595 = CONTPBEAM000_AM241_00595/CONTPBEAM014_AM241_00595
print(PICOPBEAM_PLAAM014_00595)

INVPICOPBEAM_PLAAM014_00595 = CONTPBEAM014_AM241_00595/CONTPBEAM000_AM241_00595
print(INVPICOPBEAM_PLAAM014_00595)

# %%
# DADOS - ENERGIA ATENUADA DO CÉSIO POR PLA (PICO 1 - 0662 ELETRONVOLTS)

YPBEAMyCS_0662 = [YPBEAMyCS137_002, YPBEAMyCS137_008, YPBEAMyCS137_014]
YPBEAMyyCS_0662 = [YPBEAMINVyCS137_002, YPBEAMINVyCS137_008, YPBEAMINVyCS137_014]
YPBEAMyAM_00595 = [YPBEAMyAM241_002, YPBEAMyAM241_008, YPBEAMyAM241_014]
YPBEAMyyAM_00595 = [YPBEAMINVyAM241_002, YPBEAMINVyAM241_008, YPBEAMINVyAM241_014]

# LOGARITMO NATURAL DA ENERGIA ATENUADA DO CÉSIO POR PLA (PICO 1 - 0662 ELETRONVOLTS)

lnPBEAM_yCS_0662 = np.log(YPBEAMyCS_0662)
print(lnPBEAM_yCS_0662)

lnPBEAM_yyCS_0662 = np.log(YPBEAMyyCS_0662)
print(lnPBEAM_yyCS_0662)

# LOGARITMO NATURAL DA ENERGIA ATENUADA DO AMERÍCIO POR PLA (PICO 1 - 0662 ELETRONVOLTS)

lnPBEAM_yAM_00595 = np.log(YPBEAMyAM_00595)
print(lnPBEAM_yAM_00595)

lnPBEAM_yyAM_00595 = np.log(YPBEAMyyAM_00595)
print(lnPBEAM_yyAM_00595)

# ATENUAÇÃO

mulnPBEAM_yCS_0662 = np.log(YPBEAMyCS_0662)/xCS_ESPCM
print(mulnPBEAM_yCS_0662)
mulnPBEAM_yyCS_0662 = np.log(YPBEAMyyCS_0662)/xCS_ESPCM
print(mulnPBEAM_yyCS_0662)
mulnPBEAM_yAM_00595 = np.log(YPBEAMyAM_00595)/xAM_ESPCM
print(mulnTEO_yAM_00595)
mulnPBEAM_yyAM_00595 = np.log(YPBEAMyyAM_00595)/xAM_ESPCM
print(mulnPBEAM_yyAM_00595)

# %%
# CALCULO FEIXE ISOTROPICO

# %%
# CÉSIO-137 (ISOTRÓPICO)

PICOISO_PLACS002_0662 = CONTISO000_CS137_0662/CONTISO002_CS137_0662
print(PICOISO_PLACS002_0662)

INVPICOISO_PLACS002_0662 = CONTISO002_CS137_0662/CONTISO000_CS137_0662
print(INVPICOISO_PLACS002_0662)

PICOISO_PLACS008_0662 = CONTISO000_CS137_0662/CONTISO008_CS137_0662
print(PICOISO_PLACS008_0662)

INVPICOISO_PLACS008_0662 = CONTISO008_CS137_0662/CONTISO000_CS137_0662
print(INVPICOISO_PLACS008_0662)

PICOISO_PLACS014_0662 = CONTISO000_CS137_0662/CONTISO014_CS137_0662
print(PICOISO_PLACS014_0662)

INVPICOISO_PLACS014_0662 = CONTISO014_CS137_0662/CONTISO000_CS137_0662
print(INVPICOISO_PLACS014_0662)

# %%
#AM-241 (ISOTRÓPICO)

PICOISO_PLAAM002_00595 = CONTISO000_AM241_00595/CONTISO002_AM241_00595
print(PICOISO_PLAAM002_00595)

INVPICOISO_PLAAM002_00595 = CONTISO002_AM241_00595/CONTISO000_AM241_00595
print(INVPICOISO_PLAAM002_00595)

PICOISO_PLAAM008_00595 = CONTISO000_AM241_00595/CONTISO008_AM241_00595
print(PICOISO_PLAAM008_00595)

INVPICOISO_PLAAM008_00595 = CONTISO008_AM241_00595/CONTISO000_AM241_00595
print(INVPICOISO_PLAAM008_00595)

PICOISO_PLAAM014_00595 = CONTISO000_AM241_00595/CONTISO014_AM241_00595
print(PICOISO_PLAAM014_00595)

INVPICOISO_PLAAM014_00595 = CONTISO014_AM241_00595/CONTISO000_AM241_00595
print(INVPICOISO_PLAAM014_00595)

# %%
# EFICIENCIA ABSOLUTA DO FOTOPICO (PBEAM)

# EFICIENCIA ABSOLUTA DO FOTOPICO (ISOTROPICO)

# %%
# TEORIA (PENCIL-BEAM)

#CONT000_CS137_662 = 4403330
#CONT002_CS137_662 = 4313390
#CONT008_CS137_662 = 4026930
#CONT014_CS137_662 = 3764660
#CONT000_AM241_595 = 8056020
#CONT002_AM241_595 = 7645430
#CONT008_AM241_595 = 6531960
#CONT014_AM241_595 = 5578480

#xCS_ESPCM = [CM_2, CM_8, CM_14]
#print(xCS_ESPCM)
#xAM_ESPCM =[CM_2, CM_8, CM_14]
#print(xAM_ESPCM)
#xCS_ESPMM = [MM_2, MM_8, MM_14]
#print(xCS_ESPMM)
#xAM_ESPMM =[MM_2, MM_8, MM_14]
#print(xAM_ESPMM)

#YTEOyCS137_000 = 
YISOyCS137_002 =  CONTISO002_CS137_0662/CONTISO000_CS137_0662
print(YISOyCS137_002)
YISOyCS137_008 =  CONTISO008_CS137_0662/CONTISO000_CS137_0662
print(YISOyCS137_008)
YISOyCS137_014 =  CONTISO014_CS137_0662/CONTISO000_CS137_0662
print(YISOyCS137_014)
#YTEOyAM241_000 =
YISOINVyCS137_002 = CONTISO000_CS137_0662/CONTISO002_CS137_0662
print(YISOINVyCS137_002)
YISOINVyCS137_008 = CONTISO000_CS137_0662/CONTISO008_CS137_0662
print(YPBEAMINVyCS137_008)
YISOINVyCS137_014 = CONTISO000_CS137_0662/CONTISO014_CS137_0662
print(YISOINVyCS137_014)

# I/I0 - I0/I (INVERSO) 

#YTEOyCS137_000 = 
YISOyAM241_002 = CONTISO002_AM241_00595/CONTISO000_AM241_00595
print(YISOyAM241_002)
YISOyAM241_008 = CONTISO008_AM241_00595/CONTISO000_AM241_00595
print(YISOyAM241_008)
YISOyAM241_014 = CONTISO014_AM241_00595/CONTISO000_AM241_00595
print(YISOyAM241_014)

#YTEOyAM241_000 =
YISOINVyAM241_002 = CONTISO000_AM241_00595/CONTISO002_AM241_00595
print(YPBEAMINVyAM241_002)
YISOINVyAM241_008 = CONTISO000_AM241_00595/CONTISO008_AM241_00595
print(YISOINVyAM241_008)
YISOINVyAM241_014 = CONTISO000_AM241_00595/CONTISO014_AM241_00595
print(YISOINVyAM241_014)


# DADOS - ENERGIA ATENUADA DO CÉSIO POR PLA (PICO 1 - 0662 ELETRONVOLTS)

YISOyCS_0662 = [YISOyCS137_002, YISOyCS137_008, YISOyCS137_014]
YISOyyCS_0662 = [YISOINVyCS137_002, YISOINVyCS137_008, YISOINVyCS137_014]
YISOyAM_00595 = [YISOyAM241_002, YISOyAM241_008, YPBEAMyAM241_014]
YISOyyAM_00595 = [YISOINVyAM241_002, YISOINVyAM241_008, YISOINVyAM241_014]

# LOGARITMO NATURAL DA ENERGIA ATENUADA DO CÉSIO POR PLA (PICO 1 - 0662 ELETRONVOLTS)

lnISO_yCS_0662 = np.log(YISOyCS_0662)
print(lnISO_yCS_0662)

lnISO_yyCS_0662 = np.log(YISOyyCS_0662)
print(lnISO_yyCS_0662)

# LOGARITMO NATURAL DA ENERGIA ATENUADA DO AMERÍCIO POR PLA (PICO 1 - 0662 ELETRONVOLTS)

lnISO_yAM_00595 = np.log(YISOyAM_00595)
print(lnISO_yAM_00595)

lnISO_yyAM_00595 = np.log(YISOyyAM_00595)
print(lnISO_yyAM_00595)

# ATENUAÇÃO

mulnISO_yCS_0662 = np.log(YISOyCS_0662)/xCS_ESPCM
print(mulnISO_yCS_0662)
mulnISO_yyCS_0662 = np.log(YISOyyCS_0662)/xCS_ESPCM
print(mulnISO_yyCS_0662)
mulnISO_yAM_00595 = np.log(YISOyAM_00595)/xAM_ESPCM
print(mulnISO_yAM_00595)
mulnISO_yyAM_00595 = np.log(YISOyyAM_00595)/xAM_ESPCM
print(mulnISO_yyAM_00595)

# %%
#TESTE DE REFERENCIA COM DADOS DO NIST

#CS-137

# NISTCS137 = NIST_CS137_662 - mulnTEO_yCS_0662
# print(NISTCS137)
# NNISTCS137 = mulnTEO_yCS_0662 - NIST_CS137_662
# print(NNISTCS137)
NISTISO_CS137 = NIST_CS137_0662 - mulnISO_yyCS_0662
print(NISTCS137)
NISTINVISO_CS137 = mulnISO_yyCS_0662 - NIST_CS137_0662
print(NISTINVISO_CS137)
# NIST_CS137 = np.abs(NIST_CS137_662 - 0.10318467)
# print(NIST_CS137)
# NIST_CS137 = np.abs(NIST_CS137_662 - mulnTEO_yCS_0662)
# print(NIST_CS137)

NISTABSISO_CS137 = np.abs(NIST_CS137_0662 - mulnISO_yyCS_0662)
print(NISTABSISO_CS137)
NISTINVABSISO_CS137 = np.abs(mulnISO_yyCS_0662 - NIST_CS137_0662)
print(NINVISTABSISO_CS137)

#AM-241

NISTISO_AM241 = NIST_AM241_00595 - mulnISO_yyAM_00595
print(NISTISO_AM241)
NISTISO_AM241 = mulnISO_yyAM_00595 - NIST_AM241_00595
print(NISTISO_AM241)

NISTABSISO_AM241 = np.abs(NIST_AM241_00595 - mulnISO_yyAM_00595)
print(NISTABSISO_AM241)
NISTINVABSISO_AM241 = np.abs(mulnPBEAM_yyAM_00595 - NIST_AM241_00595)
print(NISTINVABSISO_AM241)
